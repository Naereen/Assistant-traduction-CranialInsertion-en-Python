# %% [markdown]
# # 🛡 🔨 🤖 **Dataset, assemble!**
#
# I want to create a semi-large supervised (labelled) dataset of questions and answers, in their original language (English) and their translated language (French).
#
# Once I'll have a lot of pairs of small sentences in English (source language) and French (target language), I'll try to use a Google colab cloud GPU to finetune the translation model I have been using in April 2025.
#
# Hopefully, I'll be able to do that efficiently, quickly, and then the model could be saved and shared on my [HuggingFace's profile](https://huggingface.co/Naereen) so that anyone can use it.

# %%
# !pip install watermark sacremoses tensorflow transformers requests beautifulsoup4 pandas evaluate numpy sacrebleu
# %load_ext watermark
# %watermark -v -p numpy,pandas,tensorflow,transformers,requests,bs4,pandas,evaluate,sacrebleu
# Out:
# Collecting watermark
#   Downloading watermark-2.5.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=6.0 in /usr/local/lib/python3.11/dist-packages (from watermark) (7.34.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.11/dist-packages (from watermark) (8.6.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from watermark) (75.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacremoses) (2024.11.6)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sacremoses) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sacremoses) (4.67.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Collecting datasets>=2.0.0 (from evaluate)
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from evaluate)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.17-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.2)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.3.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Collecting dill (from evaluate)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting multiprocess (from evaluate)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.11.15)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=1.4->watermark) (3.21.0)
# Collecting jedi>=0.16 (from ipython>=6.0->watermark)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (4.9.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=6.0->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.0->watermark) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading watermark-2.5.0-py2.py3-none-any.whl (7.7 kB)
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 15.6 MB/s eta 0:00:00
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.0 MB/s eta 0:00:00
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 9.2 MB/s eta 0:00:00
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 15.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.1 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 18.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.9 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.9 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, sacremoses, portalocker, jedi, fsspec, dill, colorama, sacrebleu, multiprocess, watermark, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed colorama-0.4.6 datasets-3.5.0 dill-0.3.8 evaluate-0.4.3 fsspec-2024.12.0 jedi-0.19.2 multiprocess-0.70.16 portalocker-3.1.1 sacrebleu-2.5.1 sacremoses-0.1.1 watermark-2.5.0 xxhash-3.5.0
# Python implementation: CPython
# Python version       : 3.11.12
# IPython version      : 7.34.0
#
# numpy       : 2.0.2
# pandas      : 2.2.2
# tensorflow  : 2.18.0
# transformers: 4.50.3
# requests    : 2.32.3
# bs4         : 4.13.3
# evaluate    : 0.4.3
# sacrebleu   : 2.5.1

# %%
running_on_GPU = False
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    print("Running on CPU (20 to 30x slower for LLM/NLP/ML)")
else:
    running_on_GPU = True
    print("Running on GPU")
# Out:
# Running on GPU

# %% [markdown]
# > We encourage you to login to your Hugging Face account so you can upload and share your model with the community. When prompted, enter your token to login:

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## 1. Use segmented versions of the text from English/French articles of Cranial Insertion
#
# This would require to be able to do here the segmentation of the VO/VF (English/French) text of articles, and that would be too complicated.
#
# I've used JAM.pl (https://github.com/kraifo/PCP/blob/master/lib/JAM.pl) to try to do this as well as possible, offline.
# The `all-tmx.zip` file contains about 700 TMX files, each from 50 to 150 paragraphs long.
#
# Let's extract these, and charge them into a Pandas's DataFrame, and only later on we will load our data into a HuggingFace's DataSets.

# %%
# !ls all-tmx.zip
# !mkdir -p all-tmx
# !unzip -q all-tmx.zip -d all-tmx
# Out:
# all-tmx.zip

# %%
# !ls -larth all-tmx/ | tail
# !ls -larth all-tmx/ | wc
# Out:
# -rw-rw-r-- 1 root root  57K Apr 10 22:40 id-en-1691_id-fr-1693.full.en-fr.tmx
# -rw-rw-r-- 1 root root  42K Apr 10 22:40 id-en-1617_id-fr-1623.full.en-fr.tmx
# -rw-rw-r-- 1 root root  38K Apr 10 22:40 id-en-1589_id-fr-1595.full.en-fr.tmx
# -rw-rw-r-- 1 root root  39K Apr 10 22:40 id-en-1563_id-fr-1569.full.en-fr.tmx
# -rw-rw-r-- 1 root root  51K Apr 10 22:40 id-en-1470_id-fr-1479.full.en-fr.tmx
# -rw-rw-r-- 1 root root  39K Apr 10 22:40 id-en-1392_id-fr-1398.full.en-fr.tmx
# -rw-rw-r-- 1 root root  36K Apr 10 22:40 id-en-1248_id-fr-1256.full.en-fr.tmx
# -rw-rw-r-- 1 root root  45K Apr 10 22:40 id-en-1185_id-fr-1192.full.en-fr.tmx
# drwxr-xr-x 1 root root 4.0K Apr 11 00:45 ..
# drwxr-xr-x 2 root root  48K Apr 11 00:45 .
#     699    6284   54208

# %% [markdown]
# As claimed, we have about 700 .tmx file. Let's extract as many pair of English/French sentences as we can, from these files.

# %%
# prompt: for one of this TMX file, let say its filename is "all-tmx/id-en-1185_id-fr-1192.full.en-fr.tmx", I want to open it, load its content using the PythonTmx library (https://python-tmx.readthedocs.io/en/stable/), and generate two lists of aligned sentence, the first in English and the second in French. TMX here is Translation Memory eXchange (TMX) files, not Tiles Map files of PyGame.

from pathlib import Path
from lxml import etree
from typing import List, Tuple

def extract_sentences_from_tmx(tmx_filepath: str) -> Tuple[List[str], List[str]]:
    """
    Extracts aligned English and French sentences from a TMX file.

    Args:
        tmx_filepath: Path to the TMX file.

    Returns:
        A tuple containing two lists: English sentences and French sentences.
    """
    english_sentences = []
    french_sentences = []
    idx = 0
    try:
        tree = etree.parse(tmx_filepath)
        for tu in tree.xpath("//tu"):
            english_seg = tu.xpath(".//tuv[@xml:lang='en']/seg")
            french_seg = tu.xpath(".//tuv[@xml:lang='fr']/seg")

            if english_seg and french_seg:  # Ensure both segments exist
                for i in range(min(len(english_seg), len(french_seg))):
                    en_text = english_seg[i].text
                    fr_text = french_seg[i].text
                    if en_text and fr_text:
                        idx += 1
                        # print(f"# {idx}-th sentences:\n  English: {en_text}\n  French: {fr_text}")
                        english_sentences.append(en_text)
                        french_sentences.append(fr_text)
        print(f"==> for file {tmx_filepath},\n\twe found {idx} English/French sentences likely to be aligned.")
    except etree.XMLSyntaxError as e:
        print(f"Error parsing {tmx_filepath}: {e}")
    return english_sentences, french_sentences

# %% [markdown]
# Let's try this on one file:

# %%
# Example usage:
tmx_file = "all-tmx/id-en-1185_id-fr-1192.full.en-fr.tmx"  # Replace with your file
english_sents, french_sents = extract_sentences_from_tmx(tmx_file)
# Out:
# ==> for file all-tmx/id-en-1185_id-fr-1192.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.

# %% [markdown]
# Getting 45 most-likely correctly aligned pairs of sentence from a single pair of English/French article is already great!

# %%
# Print the first few sentences to verify
print("First 5 pair of English/French sentences:")
for i in range(5):
    print(f"- {i+1}-th sentence:")
    en_sent = english_sents[i]
    print(en_sent)
    fr_sent = french_sents[i]
    print(fr_sent)
# Out:
# First 5 pair of English/French sentences:
# - 1-th sentence:
# While I'm doing my investigation, don't forget we're also here to answer your rules questions. If you have a short question, you can tweet to use at [url=https://twitter.com/CranialTweet]@CranialTweet[/url], and if you have a longer question, you can e-mail us at moko@cranialinsertion.com. We might even use your question in a future article!
# Pendant que j'enquête, n'oubliez pas que nous sommes toujours là pour répondre à vos questions de règle. Si vos questions sont courtes, vous pouvez nous les tweeter à [url=https://twitter.com/CranialTweet]@CranialTweet[/url] et, si elles sont plus longues, envoyez-les-nous par mail à moko@cranialinsertion.com. Nous pourrions même utiliser votre question dans un prochain article !
# - 2-th sentence:
# [hr][q]I control a [c]Lambholt Pacifist[/c], and I enchant it with [c]Equestrian Skill[/c]. Can it attack?[/q]
# [hr][Q=Q : ]Je contrôle une [c=Lambholt Pacifist]Pacifiste de Lambholt[/c] et je l'enchante avec [c=Equestrian Skill]Talents équestres[/c]. Peut-elle attaquer ?[/q]
# - 3-th sentence:
# [a]Yes it can! The Pacifist can't attack unless you control a creature with a power of 4 or greater. Once the Skill is enchanting the Pacifist, the Pacifist is a 6/6 creature. Since you now control a creature with a power of 4 or greater, your Pacifist will be able to attack.[/a]
# [A=R : ]Oui elle le peut ! La Pacifiste ne peut attaquer à moins que tu ne contrôles une créature avec une force de 4 ou plus. Une fois que les Talents enchantent la Pacifiste, elle est une créature 6/6. Maintenant que tu contrôles une créature avec une force de 4 ou plus, ta Pacifiste va pouvoir attaquer.[/a]
# - 4-th sentence:
# [hr][q]My opponent casts [c]Compelling Deterrence[/c], while controlling a zombie, and targets my [c]Stormrider Spirit[/c]. Can I recast my Spirit before I have to discard it?[/q]
# [hr][Q=Q : ]Mon adversaire joue [c=Compelling Deterrence]Dissuasion irrésistible[/c] en contrôlant un zombie et cible mon [c=Stormrider Spirit]Esprit de chevaucheur de tempête[/c]. Puis-je rejouer mon Esprit avant de devoir le défausser ?[/q]
# - 5-th sentence:
# [a]Nope. You don't get priority while the Deterrence is resolving. You have to wait for the Deterrence to finish resolving completely before you get priority again to cast the Spirit. The Spirit will be bounced back to your hand, and (since they control a Zombie) you'll have to discard a card from your hand before you get priority again. If you had an empty hand, you'll end up discarding the Spirit before you can recast it.[/a]
# [A=R : ]Nope. Tu ne reçois pas la priorité pendant la résolution de la Dissuasion. Tu dois attendre que la Dissuasion finisse de se résoudre complètement avant de recevoir à nouveau la priorité pour pouvoir lancer ton Esprit. L'Esprit est alors remonté dans ta main et (vu que ton adversaire contrôle un zombie) tu vas devoir te défausser une carte immédiatement. Si tu avais une main vide, tu vas te retrouver à défausser l'Esprit avant de pouvoir le relancer.[/a]

# %% [markdown]
# Now, get a list of all the pairs of sentences, and save it as a Pandas DataFrame (then export it to a CSV, in order to speed up this step):

# %%
# prompt: Call the extract_sentences_from_tmx function on EACH .tmx file that are in the "all-tmx/" folder, and generate a list of all the english_sents, and french_sents called all_english_sents, all_fench_sents, concatenating all the results.

import os
from pathlib import Path

all_english_sents = []
all_french_sents = []

# Iterate through all .tmx files in the "all-tmx" directory
for filename in os.listdir("all-tmx"):
    if filename.endswith(".tmx"):
        tmx_file = os.path.join("all-tmx", filename)
        english_sents, french_sents = extract_sentences_from_tmx(tmx_file)
        all_english_sents.extend(english_sents)
        all_french_sents.extend(french_sents)

print(f"Length of all_english_sents: {len(all_english_sents)}")
print(f"Length of all_french_sents: {len(all_french_sents)}")
assert (len(all_english_sents) == len(all_french_sents) )
# Out:
# ==> for file all-tmx/id-en-981_id-fr-992.full.en-fr.tmx,
# 	we found 226 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4194_id-fr-4196.full.en-fr.tmx,
# 	we found 75 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2953_id-fr-2957.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1119_id-fr-1126.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1159_id-fr-1173.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1551_id-fr-1556.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1127_id-fr-1134.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4006_id-fr-4009.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3932_id-fr-3936.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3473_id-fr-3476.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-531_id-fr-532.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-545_id-fr-550.full.en-fr.tmx,
# 	we found 154 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3987_id-fr-3990.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1827_id-fr-1833.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1561_id-fr-1575.full.en-fr.tmx,
# 	we found 63 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2549_id-fr-2555.full.en-fr.tmx,
# 	we found 55 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3882_id-fr-3885.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2249_id-fr-2257.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2134_id-fr-2139.full.en-fr.tmx,
# 	we found 115 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-643_id-fr-650.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4328_id-fr-4330.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3886_id-fr-3889.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-702_id-fr-712.full.en-fr.tmx,
# 	we found 58 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1112_id-fr-1117.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1526_id-fr-1535.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4185_id-fr-4189.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4098_id-fr-4101.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4302_id-fr-4304.full.en-fr.tmx,
# 	we found 152 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3463_id-fr-3467.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2479_id-fr-2482.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2487_id-fr-2493.full.en-fr.tmx,
# 	we found 62 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1242_id-fr-1247.full.en-fr.tmx,
# 	we found 54 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-361_id-fr-379.full.en-fr.tmx,
# 	we found 56 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3440_id-fr-3444.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-902_id-fr-909.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2451_id-fr-2456.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3842_id-fr-3845.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1354_id-fr-1360.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4263_id-fr-4265.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4056_id-fr-4059.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1144_id-fr-1150.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3060_id-fr-3064.full.en-fr.tmx,
# 	we found 54 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3624_id-fr-3627.full.en-fr.tmx,
# 	we found 102 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3937_id-fr-3941.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4160_id-fr-4163.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4157_id-fr-4159.full.en-fr.tmx,
# 	we found 123 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-644_id-fr-657.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-691_id-fr-696.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4170_id-fr-4173.full.en-fr.tmx,
# 	we found 65 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2150_id-fr-2155.full.en-fr.tmx,
# 	we found 57 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-768_id-fr-781.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1248_id-fr-1256.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3182_id-fr-3186.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3132_id-fr-3135.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4229_id-fr-4231.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3503_id-fr-3507.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1663_id-fr-1672.full.en-fr.tmx,
# 	we found 59 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2977_id-fr-2982.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1064_id-fr-1075.full.en-fr.tmx,
# 	we found 92 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1003_id-fr-1015.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3791_id-fr-3793.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-388_id-fr-391.full.en-fr.tmx,
# 	we found 59 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3000_id-fr-3003.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2784_id-fr-2792.full.en-fr.tmx,
# 	we found 56 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1214_id-fr-1217.full.en-fr.tmx,
# 	we found 53 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4256_id-fr-4258.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1281_id-fr-1290.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4380_id-fr-4382.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2436_id-fr-2442.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4213_id-fr-4215.full.en-fr.tmx,
# 	we found 155 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-459_id-fr-471.full.en-fr.tmx,
# 	we found 55 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4153_id-fr-4156.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1521_id-fr-1527.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3314_id-fr-3317.full.en-fr.tmx,
# 	we found 29 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4241_id-fr-4243.full.en-fr.tmx,
# 	we found 65 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2934_id-fr-2937.full.en-fr.tmx,
# 	we found 99 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1388_id-fr-1409.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3401_id-fr-3405.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2940_id-fr-2945.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3324_id-fr-3328.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4182_id-fr-4184.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2348_id-fr-2355.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2624_id-fr-2629.full.en-fr.tmx,
# 	we found 127 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3040_id-fr-3043.full.en-fr.tmx,
# 	we found 96 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3450_id-fr-3453.full.en-fr.tmx,
# 	we found 54 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3656_id-fr-3659.full.en-fr.tmx,
# 	we found 33 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1098_id-fr-1107.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1196_id-fr-1201.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2236_id-fr-2241.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3814_id-fr-3817.full.en-fr.tmx,
# 	we found 109 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3616_id-fr-3619.full.en-fr.tmx,
# 	we found 63 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2177_id-fr-2181.full.en-fr.tmx,
# 	we found 60 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3686_id-fr-3689.full.en-fr.tmx,
# 	we found 114 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2774_id-fr-2780.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1037_id-fr-1041.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1703_id-fr-1708.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-680_id-fr-690.full.en-fr.tmx,
# 	we found 59 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4124_id-fr-4128.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1465_id-fr-1473.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2378_id-fr-2384.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3342_id-fr-3345.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3606_id-fr-3609.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-485_id-fr-492.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4060_id-fr-4065.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1890_id-fr-1895.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1583_id-fr-1587.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2740_id-fr-2743.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4190_id-fr-4192.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4079_id-fr-4085.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2371_id-fr-2372.full.en-fr.tmx,
# 	we found 56 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4197_id-fr-4199.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1030_id-fr-1036.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3850_id-fr-3853.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1236_id-fr-1241.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2472_id-fr-2474.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-936_id-fr-942.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3770_id-fr-3773.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-772_id-fr-806.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3795_id-fr-3798.full.en-fr.tmx,
# 	we found 33 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3367_id-fr-3370.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2142_id-fr-2148.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2841_id-fr-2844.full.en-fr.tmx,
# 	we found 56 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-917_id-fr-924.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3219_id-fr-3224.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4247_id-fr-4250.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2909_id-fr-2913.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3167_id-fr-3170.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3710_id-fr-3715.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3024_id-fr-3028.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2118_id-fr-2125.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4295_id-fr-4297.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2386_id-fr-2392.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1158_id-fr-1172.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1655_id-fr-1660.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4027_id-fr-4031.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3137_id-fr-3140.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2827_id-fr-2833.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3758_id-fr-3762.full.en-fr.tmx,
# 	we found 33 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3942_id-fr-3946.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3996_id-fr-4001.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2675_id-fr-2676.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1330_id-fr-1336.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2691_id-fr-2697.full.en-fr.tmx,
# 	we found 91 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3152_id-fr-3156.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2686_id-fr-2692.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4374_id-fr-4377.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-588_id-fr-591.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3638_id-fr-3641.full.en-fr.tmx,
# 	we found 31 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2651_id-fr-2654.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3102_id-fr-3106.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4238_id-fr-4240.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1410_id-fr-1415.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1438_id-fr-1445.full.en-fr.tmx,
# 	we found 63 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1930_id-fr-1934.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3348_id-fr-3352.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1855_id-fr-1860.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1589_id-fr-1595.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3498_id-fr-3502.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2645_id-fr-2650.full.en-fr.tmx,
# 	we found 57 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-918_id-fr-934.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1515_id-fr-1520.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4321_id-fr-4323.full.en-fr.tmx,
# 	we found 55 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4115_id-fr-4119.full.en-fr.tmx,
# 	we found 73 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3254_id-fr-3258.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2429_id-fr-2435.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1332_id-fr-1337.full.en-fr.tmx,
# 	we found 143 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3874_id-fr-3877.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2947_id-fr-2950.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4046_id-fr-4051.full.en-fr.tmx,
# 	we found 54 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-728_id-fr-746.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1715_id-fr-1720.full.en-fr.tmx,
# 	we found 61 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1275_id-fr-1280.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3754_id-fr-3756.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-35_id-fr-381.full.en-fr.tmx,
# 	we found 0 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-481_id-fr-487.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2699_id-fr-2702.full.en-fr.tmx,
# 	we found 53 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3878_id-fr-3881.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2996_id-fr-3001.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2057_id-fr-2064.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3085_id-fr-3090.full.en-fr.tmx,
# 	we found 63 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1753_id-fr-1757.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1373_id-fr-1379.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3866_id-fr-3869.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-393_id-fr-404.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3249_id-fr-3252.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4030_id-fr-4036.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3333_id-fr-3337.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4120_id-fr-4123.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3694_id-fr-3697.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-417_id-fr-423.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1709_id-fr-1714.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2457_id-fr-2461.full.en-fr.tmx,
# 	we found 60 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1638_id-fr-1644.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3019_id-fr-3023.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3967_id-fr-3972.full.en-fr.tmx,
# 	we found 32 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3541_id-fr-3546.full.en-fr.tmx,
# 	we found 28 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1171_id-fr-1184.full.en-fr.tmx,
# 	we found 19 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3774_id-fr-3776.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1577_id-fr-1582.full.en-fr.tmx,
# 	we found 57 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1924_id-fr-1929.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1765_id-fr-1770.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3105_id-fr-3112.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-564_id-fr-570.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2443_id-fr-2449.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-748_id-fr-753.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-911_id-fr-919.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3259_id-fr-3262.full.en-fr.tmx,
# 	we found 106 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4021_id-fr-4026.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-406_id-fr-408.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2407_id-fr-2413.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1648_id-fr-1654.full.en-fr.tmx,
# 	we found 67 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2031_id-fr-2036.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3192_id-fr-3193.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3858_id-fr-3861.full.en-fr.tmx,
# 	we found 55 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2156_id-fr-2162.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3230_id-fr-3233.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3778_id-fr-3780.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2806_id-fr-2812.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4070_id-fr-4074.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1324_id-fr-1328.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4209_id-fr-4212.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-944_id-fr-950.full.en-fr.tmx,
# 	we found 57 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4200_id-fr-4202.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3912_id-fr-3916.full.en-fr.tmx,
# 	we found 112 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3726_id-fr-3729.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1471_id-fr-1481.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3678_id-fr-3681.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3922_id-fr-3925.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3406_id-fr-3410.full.en-fr.tmx,
# 	we found 54 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3761_id-fr-3765.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4042_id-fr-4047.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3568_id-fr-3571.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4337_id-fr-4339.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3157_id-fr-3160.full.en-fr.tmx,
# 	we found 32 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2328_id-fr-2334.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3319_id-fr-3323.full.en-fr.tmx,
# 	we found 102 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2814_id-fr-2817.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2086_id-fr-2090.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4279_id-fr-4281.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3787_id-fr-3790.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3722_id-fr-3724.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3073_id-fr-3078.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2111_id-fr-2113.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1052_id-fr-1059.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3097_id-fr-3101.full.en-fr.tmx,
# 	we found 53 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1661_id-fr-1667.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-432_id-fr-436.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4270_id-fr-4272.full.en-fr.tmx,
# 	we found 56 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2767_id-fr-2769.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1679_id-fr-1684.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1185_id-fr-1192.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2543_id-fr-2548.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1944_id-fr-1950.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2861_id-fr-2866.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2605_id-fr-2609.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3067_id-fr-3070.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3951_id-fr-3955.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2972_id-fr-2975.full.en-fr.tmx,
# 	we found 133 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4206_id-fr-4207.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4225_id-fr-4227.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3172_id-fr-3176.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3008_id-fr-3013.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1422_id-fr-1428.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3742_id-fr-3745.full.en-fr.tmx,
# 	we found 104 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-392_id-fr-395.full.en-fr.tmx,
# 	we found 31 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1807_id-fr-1813.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3906_id-fr-3911.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2272_id-fr-2279.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-592_id-fr-600.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3376_id-fr-3378.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1991_id-fr-1993.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-451_id-fr-455.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-715_id-fr-722.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3391_id-fr-3395.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2834_id-fr-2838.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4356_id-fr-4357.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2256_id-fr-2262.full.en-fr.tmx,
# 	we found 61 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3746_id-fr-3749.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4037_id-fr-4041.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-996_id-fr-1004.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3371_id-fr-3375.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3870_id-fr-3872.full.en-fr.tmx,
# 	we found 132 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2793_id-fr-2797.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2335_id-fr-2341.full.en-fr.tmx,
# 	we found 104 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3272_id-fr-3279.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2098_id-fr-2104.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3830_id-fr-3833.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2713_id-fr-2719.full.en-fr.tmx,
# 	we found 25 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4016_id-fr-4020.full.en-fr.tmx,
# 	we found 59 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3601_id-fr-3604.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3269_id-fr-3273.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3284_id-fr-3289.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2280_id-fr-2286.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1129_id-fr-1145.full.en-fr.tmx,
# 	we found 59 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2216_id-fr-2221.full.en-fr.tmx,
# 	we found 113 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3288_id-fr-3291.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2631_id-fr-2637.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1392_id-fr-1398.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3664_id-fr-3668.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2037_id-fr-2044.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2705_id-fr-2711.full.en-fr.tmx,
# 	we found 109 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4352_id-fr-4355.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4318_id-fr-4320.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-658_id-fr-662.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3478_id-fr-3483.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4203_id-fr-4205.full.en-fr.tmx,
# 	we found 73 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-516_id-fr-521.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3304_id-fr-3308.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-569_id-fr-576.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2922_id-fr-2925.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1789_id-fr-1793.full.en-fr.tmx,
# 	we found 57 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1208_id-fr-1216.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2927_id-fr-2933.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3577_id-fr-3582.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3416_id-fr-3419.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2529_id-fr-2535.full.en-fr.tmx,
# 	we found 112 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2873_id-fr-2876.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1848_id-fr-1853.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3588_id-fr-3591.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4251_id-fr-4253.full.en-fr.tmx,
# 	we found 31 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1416_id-fr-1421.full.en-fr.tmx,
# 	we found 123 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3396_id-fr-3399.full.en-fr.tmx,
# 	we found 101 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1470_id-fr-1479.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4235_id-fr-4237.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2197_id-fr-2202.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3902_id-fr-3907.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3387_id-fr-3390.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-540_id-fr-542.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4289_id-fr-4291.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1069_id-fr-1081.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4298_id-fr-4300.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2853_id-fr-2859.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4142_id-fr-4148.full.en-fr.tmx,
# 	we found 63 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2010_id-fr-2014.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3822_id-fr-3825.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1424_id-fr-1433.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-818_id-fr-826.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4149_id-fr-4151.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3327_id-fr-3330.full.en-fr.tmx,
# 	we found 53 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3718_id-fr-3721.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1840_id-fr-1847.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1861_id-fr-1867.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1308_id-fr-1315.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2618_id-fr-2623.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-770_id-fr-793.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2800_id-fr-2804.full.en-fr.tmx,
# 	we found 106 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3706_id-fr-3709.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1356_id-fr-1365.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3690_id-fr-3693.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-620_id-fr-632.full.en-fr.tmx,
# 	we found 58 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-634_id-fr-642.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3982_id-fr-3986.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-837_id-fr-847.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3947_id-fr-3950.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2415_id-fr-2421.full.en-fr.tmx,
# 	we found 53 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-605_id-fr-616.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2203_id-fr-2208.full.en-fr.tmx,
# 	we found 62 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1450_id-fr-1458.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1263_id-fr-1268.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4368_id-fr-4370.full.en-fr.tmx,
# 	we found 108 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4174_id-fr-4177.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2915_id-fr-2920.full.en-fr.tmx,
# 	we found 53 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-698_id-fr-704.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4371_id-fr-4373.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4075_id-fr-4078.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4259_id-fr-4262.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4359_id-fr-4361.full.en-fr.tmx,
# 	we found 57 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1318_id-fr-1323.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1545_id-fr-1550.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3532_id-fr-3535.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1252_id-fr-1262.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2885_id-fr-2889.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3420_id-fr-3424.full.en-fr.tmx,
# 	we found 65 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1834_id-fr-1839.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3862_id-fr-3865.full.en-fr.tmx,
# 	we found 34 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3633_id-fr-3637.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-977_id-fr-984.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-727_id-fr-738.full.en-fr.tmx,
# 	we found 59 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-6_id-fr-1485.full.en-fr.tmx,
# 	we found 99 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3431_id-fr-3434.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-457_id-fr-461.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2569_id-fr-2574.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2662_id-fr-2668.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-365_id-fr-375.full.en-fr.tmx,
# 	we found 53 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1082_id-fr-1088.full.en-fr.tmx,
# 	we found 53 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1060_id-fr-1066.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1721_id-fr-1727.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2342_id-fr-2346.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1740_id-fr-1746.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3612_id-fr-3615.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2297_id-fr-2304.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-519_id-fr-527.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3280_id-fr-3281.full.en-fr.tmx,
# 	we found 65 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1728_id-fr-1733.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3917_id-fr-3920.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3957_id-fr-3961.full.en-fr.tmx,
# 	we found 64 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2959_id-fr-2963.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3962_id-fr-3965.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1617_id-fr-1623.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1637_id-fr-1649.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3126_id-fr-3130.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-366_id-fr-374.full.en-fr.tmx,
# 	we found 58 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3596_id-fr-3599.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1496_id-fr-1503.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ...
# ==> for file all-tmx/id-en-1868_id-fr-1875.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-756_id-fr-767.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4334_id-fr-4336.full.en-fr.tmx,
# 	we found 31 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2581_id-fr-2586.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2587_id-fr-2592.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4249_id-fr-4255.full.en-fr.tmx,
# 	we found 121 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2165_id-fr-2170.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2210_id-fr-2215.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3264_id-fr-3268.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3048_id-fr-3052.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4219_id-fr-4222.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3091_id-fr-3095.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3035_id-fr-3039.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3730_id-fr-3732.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3927_id-fr-3931.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1499_id-fr-1514.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-959_id-fr-974.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1504_id-fr-1510.full.en-fr.tmx,
# 	we found 55 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1151_id-fr-1155.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2978_id-fr-2988.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4129_id-fr-4132.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3115_id-fr-3119.full.en-fr.tmx,
# 	we found 108 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1977_id-fr-1983.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2638_id-fr-2644.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4133_id-fr-4136.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3196_id-fr-3199.full.en-fr.tmx,
# 	we found 106 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3513_id-fr-3516.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3147_id-fr-3150.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4110_id-fr-4114.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1269_id-fr-1276.full.en-fr.tmx,
# 	we found 55 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-811_id-fr-821.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1997_id-fr-2002.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4273_id-fr-4278.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4216_id-fr-4218.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-499_id-fr-503.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2223_id-fr-2228.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2680_id-fr-2687.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1631_id-fr-1635.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-665_id-fr-667.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2867_id-fr-2871.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3592_id-fr-3595.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2556_id-fr-2562.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1735_id-fr-1741.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4311_id-fr-4316.full.en-fr.tmx,
# 	we found 44 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1896_id-fr-1902.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3838_id-fr-3841.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2902_id-fr-2906.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2024_id-fr-2030.full.en-fr.tmx,
# 	we found 114 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2190_id-fr-2196.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1777_id-fr-1783.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3177_id-fr-3180.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3557_id-fr-3563.full.en-fr.tmx,
# 	we found 144 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2536_id-fr-2542.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4011_id-fr-4014.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-209_id-fr-380.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2242_id-fr-2248.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1747_id-fr-1752.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2515_id-fr-2521.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-619_id-fr-625.full.en-fr.tmx,
# 	we found 33 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2045_id-fr-2050.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1696_id-fr-1702.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2089_id-fr-2097.full.en-fr.tmx,
# 	we found 55 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3294_id-fr-3298.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2575_id-fr-2579.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-382_id-fr-386.full.en-fr.tmx,
# 	we found 65 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-555_id-fr-559.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1602_id-fr-1606.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1226_id-fr-1235.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2465_id-fr-2470.full.en-fr.tmx,
# 	we found 55 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-769_id-fr-791.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-604_id-fr-612.full.en-fr.tmx,
# 	we found 21 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3660_id-fr-3663.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2264_id-fr-2271.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1592_id-fr-1601.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1101_id-fr-1113.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2305_id-fr-2308.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3426_id-fr-3430.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3971_id-fr-3975.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-845_id-fr-848.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3750_id-fr-3753.full.en-fr.tmx,
# 	we found 123 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3818_id-fr-3821.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-676_id-fr-682.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4137_id-fr-4139.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3359_id-fr-3366.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1348_id-fr-1353.full.en-fr.tmx,
# 	we found 58 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1614_id-fr-1620.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1396_id-fr-1405.full.en-fr.tmx,
# 	we found 66 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2051_id-fr-2056.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2989_id-fr-2994.full.en-fr.tmx,
# 	we found 46 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3435_id-fr-3439.full.en-fr.tmx,
# 	we found 71 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1910_id-fr-1916.full.en-fr.tmx,
# 	we found 45 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2522_id-fr-2527.full.en-fr.tmx,
# 	we found 53 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3620_id-fr-3623.full.en-fr.tmx,
# 	we found 40 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3826_id-fr-3829.full.en-fr.tmx,
# 	we found 31 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3854_id-fr-3856.full.en-fr.tmx,
# 	we found 32 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-580_id-fr-583.full.en-fr.tmx,
# 	we found 47 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3583_id-fr-3587.full.en-fr.tmx,
# 	we found 49 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4106_id-fr-4109.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2781_id-fr-2787.full.en-fr.tmx,
# 	we found 29 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1795_id-fr-1806.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1539_id-fr-1544.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-958_id-fr-965.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2393_id-fr-2399.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1027_id-fr-1049.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3558_id-fr-3566.full.en-fr.tmx,
# 	we found 51 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3214_id-fr-3217.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2073_id-fr-2079.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2363_id-fr-2370.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4232_id-fr-4234.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-364_id-fr-376.full.en-fr.tmx,
# 	we found 48 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3682_id-fr-3685.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3244_id-fr-3248.full.en-fr.tmx,
# 	we found 37 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3459_id-fr-3462.full.en-fr.tmx,
# 	we found 30 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4082_id-fr-4087.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1951_id-fr-1955.full.en-fr.tmx,
# 	we found 60 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2126_id-fr-2131.full.en-fr.tmx,
# 	we found 39 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2669_id-fr-2673.full.en-fr.tmx,
# 	we found 57 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3338_id-fr-3341.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4305_id-fr-4307.full.en-fr.tmx,
# 	we found 50 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4344_id-fr-4349.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-863_id-fr-870.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3992_id-fr-3995.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3647_id-fr-3651.full.en-fr.tmx,
# 	we found 43 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-4286_id-fr-4288.full.en-fr.tmx,
# 	we found 35 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-876_id-fr-884.full.en-fr.tmx,
# 	we found 41 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1917_id-fr-1923.full.en-fr.tmx,
# 	we found 33 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-2105_id-fr-2110.full.en-fr.tmx,
# 	we found 52 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1367_id-fr-1372.full.en-fr.tmx,
# 	we found 42 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3738_id-fr-3741.full.en-fr.tmx,
# 	we found 36 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-3548_id-fr-3551.full.en-fr.tmx,
# 	we found 103 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1295_id-fr-1305.full.en-fr.tmx,
# 	we found 56 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1434_id-fr-1440.full.en-fr.tmx,
# 	we found 38 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1530_id-fr-1538.full.en-fr.tmx,
# 	we found 72 English/French sentences likely to be aligned.
# ==> for file all-tmx/id-en-1937_id-fr-1942.full.en-fr.tmx,
# 	we found 28 English/French sentences likely to be aligned.
# Length of all_english_sents: 34292
# Length of all_french_sents: 34292

# %%
# prompt: Now convert these two list of 34292 sentences/paragraphs in English or French, to a single Pandas DataFrame, that would have only two columns, named "english" and "french".
# Then save this DataFrame to a CSV file named "all-sentences-from-tmx.csv".
import pandas as pd

# Assuming all_english_sents and all_french_sents are already defined from the previous code
# Create a Pandas DataFrame
df_cranial_sentences = pd.DataFrame({'english': all_english_sents, 'french': all_french_sents})

# Save the DataFrame to a CSV file
df_cranial_sentences.to_csv("all-cranial-sentences-from-tmx.csv", index=False)

# %% [markdown]
# We can read the file, if we don't want to work again on generating it:

# %%
import pandas as pd
try:
    df_cranial_sentences = pd.read_csv("all-cranial-sentences-from-tmx.csv")
except:
    print(f"Couldn't load the CSV file 'all-cranial-sentences-from-tmx.csv', oupsie.")
    df_cranial_sentences = pd.DataFrame()  # empty DataFrame, to avoid bugs in the next parts.
df_cranial_sentences
# Out:
#                                                  english  \
# 0      that mustache.[/cright]Howdy, folks! Welcome b...
# 1      Lots of things would be better. Especially thi...
# 2      So here's the plan. We're going to go back to ...
# 3                                                   [hr]
# 4      [Q]You control [c=Ali from Cairo|ARN]Ali from ...
# ...                                                  ...
# 34287  [hr][q]I was watching coverage of the Pro Tour...
# 34288  [a]Nope, that was just something special for t...
# 34289  [hr][q]I was looking through Gatherer the othe...
# 34290  [a]Yep, it's true! The Welcome Deck 2016 cards...
# 34291  [hr]So I've learned two things in my investiga...
#
#                                                   french
# 0      Salut les gens ! Bienvenue pour une autre sema...
# 1      Beaucoup de choses seraient améliorées. Surtou...
# 2      Donc, voilà le plan. Nous retournons en 1993, ...
# 3                                                   [hr]
# 4      [Q=Q :]Tu contrôles [c=Ali from Cairo|ARN]Ali ...
# ...                                                  ...
# 34287  [hr][Q=Q : ]En regardant le Pro Tour il y a qu...
# 34288  [A=R : ]Non, c'était quelque chose de spécial ...
# 34289  [hr][Q=Q : ]En regardant Gatherer, j'ai remarq...
# 34290  [A=R : ]Oui, c'est bien le cas. Les cartes Wel...
# 34291  [hr]Mes investigations m'ont permis d'apprendr...
#
# [34292 rows x 2 columns]

# %% [markdown]
# I checked manually the content of this file, and it seems to be well aligned!

# %% [markdown]
# ------
#
# ## 2. Use SQLite and the [MTG JSON](https://mtgjson.com/downloads/all-files/#allprintings) database, to get the English/French text of all the Magic the Gathering cards
#
# The MTGjson.com project gives a database, which is downloaded as a SQLite file, and usable with simple SQL command, to work on the entire database of ALL the cards.

# %%
# prompt: Download the SQLite file at "https://mtgjson.com/api/v5/AllPrintings.sqlite" and save it so I can use it in Python code
import requests
import os

# Download the SQLite file
url = "https://mtgjson.com/api/v5/AllPrintings.sqlite"
filename = "AllPrintings.sqlite"

if not os.path.exists(filename):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raise an exception for bad status codes

        with open(filename, 'wb') as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
        print(f"Downloaded {filename} successfully.")

    except requests.exceptions.RequestException as e:
        print(f"Error downloading the file: {e}")
else:
    print(f"{filename} already exists. Skipping download.")
# Out:
# Downloaded AllPrintings.sqlite successfully.

# %%
# !ls -larth *.sqlite
# !du -h *.sqlite
# Out:
# -rw-r--r-- 1 root root 472M Apr 11 05:09 AllPrintings.sqlite
# 472M	AllPrintings.sqlite

# %% [markdown]
# We are ready to execute some SQLite code!

# %%
# prompt: import the sqlite database in "AllPrintings.sqlite" into a Panas dataframe and display it nicely
import pandas as pd
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('AllPrintings.sqlite')

def run_query(query):
  return pd.read_sql_query(query, conn)

# %% [markdown]
# Now I want to obtain a card's text in English and its translation in French, for each differently-named card.

# %%
# Query the database and load into a Pandas DataFrame
query = """
SELECT DISTINCT cards.name as name_en, cFD.multiverseId, cFD.name as name_fr,
       cards.text as text_en, cFD.text as text_fr
FROM cards
JOIN cardForeignData as cFD ON cards.uuid = cFD.uuid
WHERE cFD.multiverseId IS NOT NULL
  AND cFD.language = 'French'
ORDER BY cFD.multiverseId;
"""
df = run_query(query)

# Display the DataFrame nicelyn
# pd.set_option("display.max_rows", None, "display.max_columns", None) # Show all rows and columns
display(df)
# Out:
#                  name_en  multiverseId                 name_fr  \
# 0            Aether Snap         75971           Coup d'Aether
# 1            Aether Vial         75972          Fiole d'Aether
# 2         Ageless Entity         75973         Entité sans âge
# 3        Angel's Feather         75974            Plume d'ange
# 4        Arcane Spyglass         75975  Longue-vue des arcanes
# ...                  ...           ...                     ...
# 46604     Treasure Vault        692899         Salle au trésor
# 46605  Underground River        692900     Rivière souterraine
# 46606      Unholy Grotto        692901            Grotte impie
# 46607  Vineglimmer Snarl        692902         Lacis pâlevigne
# 46608     Yavimaya Coast        692903     Côte de la Yavimaya
#
#                                                  text_en  \
# 0      Remove all counters from all permanents and ex...
# 1      At the beginning of your upkeep, you may put a...
# 2      Whenever you gain life, put that many +1/+1 co...
# 3      Whenever a player casts a white spell, you may...
# 4      {2}, {T}, Sacrifice a land: Draw a card and pu...
# ...                                                  ...
# 46604  {T}: Add {C}.\n{X}{X}, {T}, Sacrifice this lan...
# 46605  {T}: Add {C}.\n{T}: Add {U} or {B}. This land ...
# 46606  {T}: Add {C}.\n{B}, {T}: Put target Zombie car...
# 46607  As this land enters, you may reveal a Forest o...
# 46608  {T}: Add {C}.\n{T}: Add {G} or {U}. This land ...
#
#                                                  text_fr
# 0      Retirez tous les marqueurs de tous les permane...
# 1      Au début de votre entretien, vous pouvez mettr...
# 2      À chaque fois que vous gagnez des points de vi...
# 3      À chaque fois qu'un joueur joue un sort blanc,...
# 4      {2}, {T}, Sacrifiez un terrain : Piochez une c...
# ...                                                  ...
# 46604  {T} : Ajoutez {C}.\n{X}{X}, {T}, sacrifiez ce ...
# 46605  {T} : Ajoutez {C}.\n{T} : Ajoutez {U} ou {B}. ...
# 46606  {T} : Ajoutez {C}.\n{B}, {T} : Mettez une cart...
# 46607  Au moment où ce terrain arrive, vous pouvez ré...
# 46608  {T} : Ajoutez {C}.\n{T} : Ajoutez {G} ou {U}. ...
#
# [46609 rows x 5 columns]

# %%
# prompt: I want to extract this as a list of pairs text_en, text_fr.

# Query to extract English and French text pairs
query = """
SELECT cards.text as text_en, cFD.text as text_fr
FROM cards
JOIN cardForeignData as cFD ON cards.uuid = cFD.uuid
WHERE cFD.language = 'French'
  AND cards.text IS NOT NULL
  AND cFD.text IS NOT NULL;
"""

df = run_query(query)

# Create a list of pairs
text_pairs = []
for index, row in df.iterrows():
    text_pairs.append((row['text_en'], row['text_fr']))

# Example: Accessing the first pair
if text_pairs:
    print(f"First pair: English - \n« {text_pairs[0][0]} »\nFrench - \n« {text_pairs[0][1]} »")
# Out:
# First pair: English -
# « First strike (This creature deals combat damage before creatures without first strike.)\nWhen this creature enters, you gain 1 life for each card in your graveyard. »
# French -
# « Initiative (Cette créature inflige des blessures de combat avant les créatures sans l'initiative.)\nQuand l'Élu de l'Ancêtre arrive en jeu, vous gagnez 1 point de vie pour chaque carte dans votre cimetière. »

# %%
len(text_pairs)
# Out:
# 44694

# %% [markdown]
# Similarly, let's save this list of pair of rules text from English/French cards to a CSV file, to be able to use it faster if we need it again.

# %%
# prompt: Now convert this list "text_pairs" of 44694 of pair of sentences in English and French, to a single Pandas DataFrame, that would have only two columns, named "english" and "french". Then save this DataFrame to a CSV file named "all-pairs-from-all-the-cards.csv".

import pandas as pd
# Create a Pandas DataFrame from the text_pairs list
df_mtg = pd.DataFrame(text_pairs, columns=['english', 'french'])

# Save the DataFrame to a CSV file
df_mtg.to_csv("all-pairs-from-all-the-cards.csv", index=False)

df_mtg
# Out:
#                                                  english  \
# 0      First strike (This creature deals combat damag...
# 1      Flying\nWhen this creature enters, you gain 3 ...
# 2      Target creature gets +3/+3 and gains flying un...
# 3      Whenever a creature you control enters, you ga...
# 4         Defender (This creature can't attack.)\nFlying
# ...                                                  ...
# 44689  {2}, {T}: Copy target activated or triggered a...
# 44690  Kicker {3}\nIf this creature was kicked, it en...
# 44691  Kicker {3}\nIndestructible\nWhen this artifact...
# 44692  {T}: Add {C}.\n{4}: Put two +1/+1 counters on ...
# 44693  {T}: Add {C}.\n{1}, {T}: Put a charge counter ...
#
#                                                   french
# 0      Initiative (Cette créature inflige des blessur...
# 1      Vol (Cette créature ne peut être bloquée que p...
# 2      La créature ciblée gagne +3/+3 et acquiert le ...
# 3      À chaque fois qu'une créature arrive en jeu so...
# 4      Défenseur, vol (Cette créature ne peut pas att...
# ...                                                  ...
# 44689  {2}, {T} : Copiez une capacité activée ou décl...
# 44690  Kick {3}\nSi la Construction myriadaire a été ...
# 44691  Kick {3}\nIndestructible\nQuand la Relique du ...
# 44692  {T} : Ajoutez {C}.\n{4} : Mettez deux marqueur...
# 44693  {T} : Ajoutez {C}.\n{1}, {T} : Mettez un marqu...
#
# [44694 rows x 2 columns]

# %% [markdown]
# -----------------------
#
# ## 3. Use the paragraphs from the Comprehensive Rules as a third source of English/French aligned sentences

# %%
# prompt: Open two SQLite cursors to the two databases named "rules_en_5.db" and "rules_fr_5.db".
# Define two functions that can execute SQL code on one of these two database, respectively for the English or the French one.

import sqlite3

# Connect to the two SQLite databases
conn_en = sqlite3.connect('rules_en_5.db')
conn_fr = sqlite3.connect('rules_fr_5.db')

# Create cursors for each database
cursor_en = conn_en.cursor()
cursor_fr = conn_fr.cursor()

def execute_sql_en(sql_query):
  """Executes an SQL query on the English database."""
  return pd.read_sql_query(sql_query, conn_en)
  try:
    cursor_en.execute(sql_query)
    return cursor_en.fetchall()  # Or any other method to retrieve results
  except sqlite3.Error as e:
    print(f"An error occurred: {e}")
    return None

def execute_sql_fr(sql_query):
  """Executes an SQL query on the French database."""
  return pd.read_sql_query(sql_query, conn_fr)
  try:
    cursor_fr.execute(sql_query)
    return cursor_fr.fetchall()  # Or any other method to retrieve results
  except sqlite3.Error as e:
    print(f"An error occurred: {e}")
    return None

# %% [markdown]
# Now we can explore the two databases I obtained and uploaded alongside this notebook.
# They should contain (lengthy) paragraphs of the Comprehensive Rules of Magic: the Gathering, in English and in French.
# The English version should be identical to the most recent version on <https://yawgatog.com/resources/magic-rules>, and the French version was manually updated by the authors of the Mythic.Tools (<https://www.mythic.tools/>) phone app. Many thanks to them!

# %%
df_rules_en = execute_sql_en("SELECT rules_text FROM rules;")
df_rules_fr = execute_sql_fr("SELECT rules_text FROM rules;")

# %%
# prompt: Merge these two Pandas DataFrame into a single one that have two columns, "english" from df_rules_en, and "french" from the othe

import pandas as pd
# Assuming df_rules_en and df_rules_fr are already defined from the previous code
df_rules = pd.DataFrame({'english': df_rules_en['rules_text'], 'french': df_rules_fr['rules_text']})

df_rules.to_csv("all-pairs-from-comprehensive-rules.csv", index=False)
df_rules
# Out:
#                                                 english  \
# 0                                               General
# 1     These Magic rules apply to any Magic game with...
# 2     A two-player game is a game that begins with o...
# 3     A multiplayer game is a game that begins with ...
# 4     To play, each player needs their own deck of t...
# ...                                                 ...
# 3187  A Conspiracy Draft game is a multiplayer game....
# 3188  At the start of the game, before decks are shu...
# 3189  Conspiracy cards with hidden agenda are put in...
# 3190  The owner of a conspiracy card is the player w...
# 3191  Once the starting player has been determined, ...
#
#                                                  french
# 0                                           Généralités
# 1     Ces règles de Magic s'appliquent à toutes les ...
# 2     Une partie à deux joueurs est une partie qui c...
# 3     Une partie multi-joueurs est une partie qui co...
# 4     Afin de jouer, chaque joueur a besoin de son p...
# ...                                                 ...
# 3187  Une partie de Draft Conspiracy est une partie ...
# 3188  Au début de la partie, avant que les decks ne ...
# 3189  Les cartes de conspiration avec la capacité d'...
# 3190  Le propriétaire d'une carte de conspiration es...
# 3191  Une fois que le joueur qui commence a été déte...
#
# [3192 rows x 2 columns]

# %% [markdown]
# This gives us about 3,000 more English/French text pairs!

# %% [markdown]
# -------------------
#
# ## We can combine these three DataFrames into a single one.

# %%
df_combined = pd.concat([df_cranial_sentences, df_mtg, df_rules], ignore_index=True)
df_combined
# Out:
#                                                  english  \
# 0      that mustache.[/cright]Howdy, folks! Welcome b...
# 1      Lots of things would be better. Especially thi...
# 2      So here's the plan. We're going to go back to ...
# 3                                                   [hr]
# 4      [Q]You control [c=Ali from Cairo|ARN]Ali from ...
# ...                                                  ...
# 82173  A Conspiracy Draft game is a multiplayer game....
# 82174  At the start of the game, before decks are shu...
# 82175  Conspiracy cards with hidden agenda are put in...
# 82176  The owner of a conspiracy card is the player w...
# 82177  Once the starting player has been determined, ...
#
#                                                   french
# 0      Salut les gens ! Bienvenue pour une autre sema...
# 1      Beaucoup de choses seraient améliorées. Surtou...
# 2      Donc, voilà le plan. Nous retournons en 1993, ...
# 3                                                   [hr]
# 4      [Q=Q :]Tu contrôles [c=Ali from Cairo|ARN]Ali ...
# ...                                                  ...
# 82173  Une partie de Draft Conspiracy est une partie ...
# 82174  Au début de la partie, avant que les decks ne ...
# 82175  Les cartes de conspiration avec la capacité d'...
# 82176  Le propriétaire d'une carte de conspiration es...
# 82177  Une fois que le joueur qui commence a été déte...
#
# [82178 rows x 2 columns]

# %% [markdown]
# We can export this as a SQLite database, a CSV file, an Excel file, just in case I want to speed this up.

# %%
# prompt: Save or export this latest largest DataFrame df_combined to a SQLite database "all-pairs-from-3-sources.sqlite", to a CSV file "all-pairs-from-3-sources.csv", and to an Excel file "all-pairs-from-3-sources.xlsx", please.

# Export the DataFrame to various formats
df_combined.to_sql("all_pairs", sqlite3.connect("all-pairs-from-3-sources.sqlite"), if_exists="replace", index=False)
df_combined.to_csv("all-pairs-from-3-sources.csv", index=False)
df_combined.to_excel("all-pairs-from-3-sources.xlsx", index=False)
# Out:
# -rw-r--r-- 1 root root 472M Apr 11 01:13 AllPrintings.sqlite
# -rw-r--r-- 1 root root  15M Apr 11 01:17 all-sentences-from-tmx.csv
# -rw-r--r-- 1 root root  16M Apr 11 01:18 all-pairs-from-all-the-cards.csv
# -rw-r--r-- 1 root root  36M Apr 11 01:34 all-pairs-from-3-sources.sqlite
# -rw-r--r-- 1 root root  32M Apr 11 01:34 all-pairs-from-3-sources.csv
# -rw-r--r-- 1 root root 9.6M Apr 11 01:35 all-pairs-from-3-sources.xlsx
# 82178

# %%
# !ls -larth *.sqlite *.csv *.xlsx
len(df_combined)

# %% [markdown]
# ## Conclusion: we've successfully built a database of 82,000 lines of English/French pairs
#
# We now have about 32 Mb of data (82K lines) about Magic the Gathering, consisting of pairs of English original text and their French translation.
#
# These translations are either coming from:
#
# 1. the official translation of the cards' texts, obtained from MTGjson.com (same database as the one on <https://Scryfall.com>),
# 2. the unofficial translation of fan-written articles about Magic: the Gathering, from the <https://www.cranial-insertion.com/> judges blog,
# 3. the semi-unofficial translation of the Comprehensive Rules of Magic: the Gathering, from various online sources.

# %% [markdown]
# We can also combine the three `df_cranial_sentences, df_mtg, df_rules` manually into a larger DataFrame:

# %%
df_combined = pd.concat([df_cranial_sentences, df_mtg, df_rules], ignore_index=True)

# Display basic stats after appending
print("Number of lines in combined DataFrame:", len(df_combined))
print(df_combined.describe())
df_combined
# Out:
# Number of lines in combined DataFrame: 82178
#        english french
# count    82178  82178
# unique   56073  63527
# top       [hr]   [hr]
# freq      2593   2528
#                                                  english  \
# 0      that mustache.[/cright]Howdy, folks! Welcome b...
# 1      Lots of things would be better. Especially thi...
# 2      So here's the plan. We're going to go back to ...
# 3                                                   [hr]
# 4      [Q]You control [c=Ali from Cairo|ARN]Ali from ...
# ...                                                  ...
# 82173  A Conspiracy Draft game is a multiplayer game....
# 82174  At the start of the game, before decks are shu...
# 82175  Conspiracy cards with hidden agenda are put in...
# 82176  The owner of a conspiracy card is the player w...
# 82177  Once the starting player has been determined, ...
#
#                                                   french
# 0      Salut les gens ! Bienvenue pour une autre sema...
# 1      Beaucoup de choses seraient améliorées. Surtou...
# 2      Donc, voilà le plan. Nous retournons en 1993, ...
# 3                                                   [hr]
# 4      [Q=Q :]Tu contrôles [c=Ali from Cairo|ARN]Ali ...
# ...                                                  ...
# 82173  Une partie de Draft Conspiracy est une partie ...
# 82174  Au début de la partie, avant que les decks ne ...
# 82175  Les cartes de conspiration avec la capacité d'...
# 82176  Le propriétaire d'une carte de conspiration es...
# 82177  Une fois que le joueur qui commence a été déte...
#
# [82178 rows x 2 columns]

# %% [markdown]
# -----------------------
#
# ## Fine-tune [Helsinki-NLP/opus-mt-tc-big-en-fr](https://huggingface.co/Helsinki-NLP/opus-mt-tc-big-en-fr) on these data
#
# I'm going to fine-tune the model I was using since a few days: <https://huggingface.co/Helsinki-NLP/opus-mt-tc-big-en-fr>.
# It is specialized on fast translation of non-technical English to French.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

original_model_name = "Helsinki-NLP/opus-mt-tc-big-en-fr"

# %%
# %%time
tokenizer = AutoTokenizer.from_pretrained(f"{original_model_name}")
tokenizer
# Out:
# tokenizer_config.json:   0%|          | 0.00/337 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/820k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.33M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# CPU times: user 705 ms, sys: 40.2 ms, total: 745 ms
# Wall time: 2.28 s
# MarianTokenizer(name_or_path='Helsinki-NLP/opus-mt-tc-big-en-fr', vocab_size=53017, model_max_length=512, is_fast=False, padding_side='right', truncation_side='right', special_tokens={'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>'}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	43311: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	50387: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	53016: AddedToken("<pad>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# )

# %%
# %%time
model = AutoModelForSeq2SeqLM.from_pretrained(f"{original_model_name}")
model
# Out:
# config.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/461M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# CPU times: user 4.4 s, sys: 1.3 s, total: 5.7 s
# Wall time: 5.98 s
# MarianMTModel(
#   (model): MarianModel(
#     (shared): Embedding(53017, 1024, padding_idx=53016)
#     (encoder): MarianEncoder(
#       (embed_tokens): Embedding(53017, 1024, padding_idx=53016)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(1024, 1024)
#       (layers): ModuleList(
#         (0-5): 6 x MarianEncoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): ReLU()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (decoder): MarianDecoder(
#       (embed_tokens): Embedding(53017, 1024, padding_idx=53016)
#       (embed_positions): MarianSinusoidalPositionalEmbedding(1024, 1024)
#       (layers): ModuleList(
#         (0-5): 6 x MarianDecoderLayer(
#           (self_attn): MarianAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MarianAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=53017, bias=False)
# )

# %% [markdown]
# We can use the pre-trained model to translate some Magic: the Gathering text:

# %%
from transformers import pipeline

translator =  pipeline ('translation' , model=model, tokenizer=tokenizer)
def en2fr(text):
    return translator(text)[0]['translation_text']
# Out:
# Device set to use cuda:0

# %%
from IPython.display import display, Markdown

def print_md(text):
    display(Markdown(text))

# %%
example_english_text = "When this creature enters, create three 4/4 Elephant tokens with trample. Then populate."
print_md(f"Example of English rules text: « {example_english_text} », getting translated:")

example_french_text = en2fr(example_english_text)
print_md(f"==> {example_french_text}")
# Out:
# Example of English rules text: « When this creature enters, create three 4/4 Elephant tokens with trample. Then populate. », getting translated:
# ==> Lorsque cette créature entre, créez trois jetons Éléphant 4/4 avec piétinement.

# %% [markdown]
# It's already not so bad, but I'm sure we can improve by trying to fine-tune this model on MTG cards data!

# %%
example_english_text = """[a]I'm afraid you'll have to remove all six counters. Bounty of the Hunt tracks how many counters each creature received "this way", which means how many counters it received due to following the instructions of Bounty of the Hunt as modified by any applicable replacement effects. Since each target creature received two counters this way, you'll have to remove two counters from each of them.[/a]"""
print_md(f"Example of English rules text: « {example_english_text} », getting translated:")

example_french_text = en2fr(example_english_text)
print_md(f"==> {example_french_text}")
# Out:
# Example of English rules text: « [a]I'm afraid you'll have to remove all six counters. Bounty of the Hunt tracks how many counters each creature received "this way", which means how many counters it received due to following the instructions of Bounty of the Hunt as modified by any applicable replacement effects. Since each target creature received two counters this way, you'll have to remove two counters from each of them.[/a] », getting translated:
# ==> [a]J'ai peur que vous deviez retirer les six marqueurs. Bounty of the Hunt suit le nombre de marqueurs que chaque créature a reçu "de cette façon", ce qui signifie le nombre de marqueurs qu'elle a reçu en suivant les instructions de Bounty of the Hunt telles que modifiées par les effets de remplacement applicables. Puisque chaque créature cible a reçu deux marqueurs de cette façon, vous devrez retirer deux marqueurs de chacun d'eux.[/a]

# %% [markdown]
# Let's compare quickly what the initial version of the translation model can do on some of our specialized text:

# %%
number_of_random_samples = 3

for idx, (name, df) in enumerate(zip(
        ["Cranial Insertion EN/FR", "MTG Cards Text EN/FR", "MTG Comprehensive Rules EN/FR"],
        [df_cranial_sentences, df_mtg, df_rules]
    )):
    print_md(f"\n\n## §{idx+1}. For some sentences from the « {name} » part of our database\n")

    # Get some random lines from this df
    some_random_lines = df.sample(n=number_of_random_samples)
    some_random_lines = some_random_lines.values.tolist()

    # Display the some random lines
    for line in some_random_lines:
        print_md(f"#### 1. In English:\n{line[0]}")
        print_md(f"#### 2. En français :\n{line[1]}")
        translation_from_model = en2fr(line[0])
        print_md(f"#### 3. Et en français traduit par le modèle initial :\n{translation_from_model}")
# Out:
# ## §1. For some sentences from the « Cranial Insertion EN/FR » part of our database
# #### 1. In English:
# [Q] Is [c]Notion Thief[/c] really awesome with [c]Duskmantle Seer[/c] or not?[/Q]
# #### 2. En français :
# [Q=Q : ][c=Notion Thief]Voleur de notion[/c] est-il vraiment top avec [c=Duskmantle Seer]Voyant de Manteaubrune[/c] ?[/Q]
# #### 3. Et en français traduit par le modèle initial :
# [Q] Est-ce que [c]Notion Thief[/c] est vraiment génial avec [c]Duskmantle Seer[/c] ou pas ?[/Q]
# #### 1. In English:
# [A]Maybe -- when a creature changes controllers, it gets a fresh case of summoning sickness. So most creatures won't be able to attack right away, but ones with haste will. And if you wait a turn for summoning sickness to wear off, you'll be able to attack either way.[/A]
# #### 2. En français :
# [A=R : ]Mai ça dépend ! Quand une créature change de contrôleur, elle devient affectée par le mal d'invocation. Donc la plupart des créatures ne seront pas capables d'attaquer dans l'immédiat, mais certaines qui ont la célérité, le pourront elles. Si tu attends un tour, afin que le mal d'invocation cesse, tu seras alors en mesure d'attaquer.[/A]
# #### 3. Et en français traduit par le modèle initial :
# [A] Peut-être que quand une créature change de contrôleur, elle reçoit un nouveau cas de maladie d'invocation. Ainsi, la plupart des créatures ne pourront pas attaquer tout de suite, mais elles le feront avec hâte. Et si vous attendez un tour pour que la maladie d'invocation s'estompe, vous pourrez attaquer de toute façon.[/A]
# #### 1. In English:
# [center][size=1]Ach, Hans, run!
# #### 2. En français :
# [center][size=1]Argh, Hans, cours !
# #### 3. Et en français traduit par le modèle initial :
# [centre][taille1]Ach, Hans, courez !
# ## §2. For some sentences from the « MTG Cards Text EN/FR » part of our database
# #### 1. In English:
# As this creature enters, choose odd or even. (Zero is even.)\nThis creature has protection from each mana value of the chosen quality.
# #### 2. En français :
# Quand l'Aventurière de Bourg-sur-Lave arrive sur le champ de bataille, choisissez pair ou impair. (Zéro est pair.)\nL'Aventurière de Bourg-sur-Lave a la protection contre chaque coût converti de mana de la valeur choisie.
# #### 3. Et en français traduit par le modèle initial :
# Lorsque cette créature entre, choisissez impair ou pair. (Zéro est pair.)nCette créature a la protection de chaque valeur de mana de la qualité choisie.
# #### 1. In English:
# {2}{W}, {T}, Sacrifice this artifact: Destroy target artifact or enchantment.
# #### 2. En français :
# {2}{W}, {T}, sacrifiez la Capsule du dissipateur : Détruisez l'artefact ou l'enchantement ciblé.
# #### 3. Et en français traduit par le modèle initial :
# Sacrifiez cet artefact : Détruisez l'artefact ou l'enchantement ciblé.
# #### 1. In English:
# Equipped creature has haste and shroud. (It can't be the target of spells or abilities.)\nEquip {0}
# #### 2. En français :
# La créature équipée a la célérité et le linceul. (Elle ne peut pas être la cible de sorts ou de capacités.)Équipement {0}
# #### 3. Et en français traduit par le modèle initial :
# La créature équipée a la hâte et le linceul. (Elle ne peut pas être la cible de sorts ou de capacités.)
# ## §3. For some sentences from the « MTG Comprehensive Rules EN/FR » part of our database
# #### 1. In English:
# The infect rules function no matter what zone an object with infect deals damage from.
# #### 2. En français :
# Les règles de l'infection fonctionnent quelle que soit la zone depuis laquelle un objet avec l'infection inflige des blessures.
# #### 3. Et en français traduit par le modèle initial :
# Les règles d'infection fonctionnent quelle que soit la zone dans laquelle un objet infecté inflige des dégâts.
# #### 1. In English:
# If an object would move from one zone to another, determine what event is moving the object. If the object is moving to a public zone and its owner will be able to look at it in that zone, its owner looks at it to see if it has any abilities that would affect the move. If the object is moving to the battlefield, each other player who will be able to look at it in that zone does so. Then any appropriate replacement effects, whether they come from that object or from elsewhere, are applied to that event. If any effects or rules try to do two or more contradictory or mutually exclusive things to a particular object, that object’s controller—or its owner if it has no controller—chooses which effect to apply, and what that effect does. (Note that multiple instances of the same thing may be mutually exclusive; for example, two simultaneous “destroy” effects.) Then the event moves the object. Example: [[Exquisite Archangel]] has an ability which reads “If you would lose the game, instead exile this creature and your life total becomes equal to your starting life total.” A spell deals 5 damage to a player with 5 life and 5 damage to an [[Exquisite Archangel]] under that player’s control. As state-based actions are performed, that player’s life total becomes equal to their starting life total, and that player chooses whether [[Exquisite Archangel]] moves to its owner’s graveyard or to exile.
# #### 2. En français :
# Si un objet devait changer de zone, déterminez quel est l'événement qui le déplace. Si l'objet se déplace vers une zone publique et que son propriétaire peut le voir dans cette zone, il le fait et regarde si l'objet a des capacités qui affecteraient son mouvement. Si l'objet se déplace vers le champ de bataille, chaque autre joueur qui pourrait le voir dans cette zone le fait. Ensuite, tous les effets de remplacement, qu'ils proviennent de l'objet ou non, sont appliqués à cet événement. Si des effets ou des règles tentent d'effectuer des actions contradictoires ou mutuellement exclusives sur un objet, le contrôleur de l'objet (ou, à défaut, son propriétaire) choisit quel effet s'applique, et ce que fait cet effet. (Notez que deux occurrences d'une action identique peuvent être mutuellement exclusives, comme par exemple deux effets de destruction.) Ensuite, l'événement déplace l'objet. Exemple : l'[[Archange admirable]] a une capacité qui dit « Si vous deviez perdre la partie, à la place exilez l'[[Archange admirable]] et votre total de points de vie devient égal à votre total de points de vie de départ. » Un sort inflige 5 blessures à un joueur avec 5 points de vie et 5 blessures à l'[[Archange admirable]] qu'il contrôle. Quand on applique les actions basées sur un état, le total de points de vie de ce joueur revient à celui de départ, et ce joueur choisit s'il exile ou met dans le cimetière de son propriétaire l'[[Archange admirable]].
# #### 3. Et en français traduit par le modèle initial :
# Si un objet se déplace d’une zone à une autre, déterminez quel événement déplace l’objet. Si l’objet se déplace vers une zone publique et que son propriétaire sera capable de le regarder dans cette zone, son propriétaire le regarde pour voir s’il a des capacités qui affecteraient le mouvement. Si l’objet se déplace vers le champ de bataille, chaque autre joueur qui sera capable de le regarder dans cette zone le fera.
# #### 1. In English:
# Free-for-All Variant
# #### 2. En français :
# Option chacun pour soi
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# #### 3. Et en français traduit par le modèle initial :
# Variante libre-pour-tous

# %% [markdown]
# I will try to fine-tune the model on the three databases first, and come back and change this choice if needed.

# %% [markdown]
# ### Formatting the data for training

# %%
use_cranial = True
use_mtg     = True
use_rules   = True

# %%
# prompt: df_combined should be a pd.concat of df_cranial_sentences if use_cranial, od df_mtg if use_mtg, and of df_rules if use_rules
import pandas as pd

df_combined = pd.DataFrame()  # Initialize an empty DataFrame

if use_cranial:
    df_combined = pd.concat([df_combined, df_cranial_sentences], ignore_index=True)

if use_mtg:
    df_combined = pd.concat([df_combined, df_mtg], ignore_index=True)

if use_rules:
    df_combined = pd.concat([df_combined, df_rules], ignore_index=True)

# %%
# Display basic stats after appending
print("Number of lines in combined DataFrame:", len(df_combined))
print(df_combined.describe())
# Out:
# Number of lines in combined DataFrame: 82178
#        english french
# count    82178  82178
# unique   56073  63527
# top       [hr]   [hr]
# freq      2593   2528

# %%
# prompt: convert the large DataFrame df_combined to a simple list of pairs
# Assuming df_combined is already defined from the previous code
# Convert the DataFrame to a list of pairs
text_pairs_list = df_combined[['english', 'french']].values.tolist()

# %%
# Print the first pairs for verification
print_md(text_pairs_list[0][0])
print_md(text_pairs_list[0][1])
# Out:
# that mustache.[/cright]Howdy, folks! Welcome back to another action-packed week of Cranial Insertion. This one's a little more packed than usual. The writers are off for a week, so you're stuck with me again. I'm Moko, the zombie mail-sorting chimpanzee and Vintage aficionado, and also the only one on the team small enough to crawl through air ducts to steal top-secret prototypes. We're celebrating [b]Magic: The Gathering[/b]'s twentieth anniversary this week - the very first release was on August 5th, 1993. What better way to celebrate than by hopping into a stolen [c]Time Machine[/c] and heading back through [b]Magic[/b]'s past, looking at rules questions through the ages?
# Salut les gens ! Bienvenue pour une autre semaine de Cranial Insertion, bourrée d’action. Celle là est un peu plus dense que d’habitude. Les auteurs sont au repos pour une semaine, donc vous êtes coincés avec moi une fois de plus ! Je suis Moko, le Chimpanzé-Zombie trieur de mails, et fan incontournable du Vintage, et également le seul de l’équipe assez petit pour ramper dans les conduits d’aération pour voler des prototypes ultra-secrets. Nous fêtons cette semaine le vingtième anniversaire de [b]Magic : l’Assemblée[/b] – la toute première sortie était en fait le 05 Août 1993. Quelle meilleure façon de fêter cela qu’en sautant dans une  [c=Time Machine]Machine à remonter le temps[/c] volée, et de rentrer dans le passé de [b]Magic[/b] en regardant des questions de règles à travers les âges ?

# %% [markdown]
# Now that we have all these text pairs, we can use them to generate two datasets: one for training and one for testing.

# %%
source = [ text_pair[0] for text_pair in text_pairs_list ]
print(f"Length of the sources = {len(source)}")
target = [ text_pair[1] for text_pair in text_pairs_list ]
print(f"Length of the targets = {len(target)}")
# Out:
# Length of the sources = 82178
# Length of the targets = 82178

# %% [markdown]
# Let's use, as usual, 20% for testing, 80% for training.
# The rest is generic code I've copied from this StackOverflow question <https://stackoverflow.com/questions/75970711/how-to-properly-fine-tune-translational-transformer-models>:

# %%
assert(len(source) == len(target))
len(source), len(target)
# Out:
# (82178, 82178)

# %%
# %%time
from datasets import Dataset, DatasetDict
from sklearn.model_selection import train_test_split

# Combine your source and target lists into a list of dictionaries
raw_data = [{'en': s, 'fr': t} for s, t in zip(source, target)]

# Split the combined data into training and a temporary test+validation set
train_raw, temp_raw = train_test_split(raw_data, test_size=0.2, random_state=42) # Adjust test_size as needed

# Split the temporary set into validation and test sets
val_raw, test_raw = train_test_split(temp_raw, test_size=0.5, random_state=42) # 0.5 of the temp set is 10% of the original

# Create Dataset objects from the raw data dictionaries
train_dataset = Dataset.from_list([{'translation': item} for item in train_raw])
val_dataset = Dataset.from_list([{'translation': item} for item in val_raw])
test_dataset = Dataset.from_list([{'translation': item} for item in test_raw])

# Create the DatasetDict
raw_datasets = DatasetDict({
    'train': train_dataset,
    'validation': val_dataset,
    'test': test_dataset
})

print(raw_datasets)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 65742
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 8218
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 8218
#     })
# })
# CPU times: user 402 ms, sys: 175 ms, total: 577 ms
# Wall time: 576 ms

# %% [markdown]
# The max length should not be too high, but not too low also:

# %%
max_length = 256  # shouldn't be too high

# %% [markdown]
# This was the previous code, I'll keep it for a bit, until the fine-tuning (additionnal training) of at least one model works.

# %%
# %%time
"""
    from sklearn.model_selection import train_test_split

    max_length = 256  # shouldn't be too high
    test_size = 0.20

    X_train, X_val, y_train, y_val = train_test_split(source, target, test_size=test_size)
    X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=max_length, return_tensors="pt")
    y_train_tokenized = tokenizer(y_train, padding=True, truncation=True, max_length=max_length, return_tensors="pt")
    X_val_tokenized   = tokenizer(X_val, padding=True, truncation=True, max_length=max_length, return_tensors="pt")
    y_val_tokenized   = tokenizer(y_val, padding=True, truncation=True, max_length=max_length, return_tensors="pt")

    import torch
    class ForDataset(torch.utils.data.Dataset):
        def __init__(self, inputs, targets):
            self.inputs = inputs
            self.targets = targets

        def __len__(self):
            return len(self.targets)

        def __getitem__(self, index):
            input_ids = torch.tensor(self.inputs["input_ids"][index]).squeeze()
            target_ids = torch.tensor(self.targets["input_ids"][index]).squeeze()

            return {"input_ids": input_ids, "labels": target_ids}

    train_dataset = ForDataset(X_train_tokenized, y_train_tokenized)
    test_dataset  = ForDataset(X_val_tokenized, y_val_tokenized)
"""
# Out:
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 10.3 µs
# '\n    from sklearn.model_selection import train_test_split\n\n    max_length = 256  # shouldn\'t be too high\n    test_size = 0.20\n\n    X_train, X_val, y_train, y_val = train_test_split(source, target, test_size=test_size)\n    X_train_tokenized = tokenizer(X_train, padding=True, truncation=True, max_length=max_length, return_tensors="pt")\n    y_train_tokenized = tokenizer(y_train, padding=True, truncation=True, max_length=max_length, return_tensors="pt")\n    X_val_tokenized   = tokenizer(X_val, padding=True, truncation=True, max_length=max_length, return_tensors="pt")\n    y_val_tokenized   = tokenizer(y_val, padding=True, truncation=True, max_length=max_length, return_tensors="pt")\n\n    import torch\n    class ForDataset(torch.utils.data.Dataset):\n        def __init__(self, inputs, targets):\n            self.inputs = inputs\n            self.targets = targets\n\n        def __len__(self):\n            return len(self.targets)\n\n        def __getitem__(self, index):\n            input_ids = torch.tensor(self.inputs["input_ids"][index]).squeeze()\n            target_ids = torch.tensor(self.targets["input_ids"][index]).squeeze()\n\n            return {"input_ids": input_ids, "labels": target_ids}\n\n    train_dataset = ForDataset(X_train_tokenized, y_train_tokenized)\n    test_dataset  = ForDataset(X_val_tokenized, y_val_tokenized)\n'

# %% [markdown]
# We can quickly explore both the `raw_datasets`:

# %%
print(raw_datasets)

from pprint import pprint
pprint(raw_datasets["train"][0])
pprint(raw_datasets["validation"][0])
pprint(raw_datasets["test"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 65742
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 8218
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 8218
#     })
# })
# {'translation': {'en': '[hr]', 'fr': '[hr]'}}
# {'translation': {'en': '[cright=Gideon Jura]"No! Not that! Not '
#                        '[i]planeswalkers![/i]"[/cright][Q]I block with a morph '
#                        'and flip it face-up. Does my opponent have a chance to '
#                        'respond before damage (provided no flip trigger)?[/Q]',
#                  'fr': '[cright=Gideon Jura]"Non ! Non pas ça !'}}
# {'translation': {'en': "Haste\\n{1}{R}, {T}: Target creature can't block this "
#                        'turn.',
#                  'fr': 'Célérité\\n{1}{R}, {T} : Une créature ciblée ne peut '
#                        'pas bloquer ce tour-ci.'}}

# %% [markdown]
# That should be satisfying!
#
# > A `DataCollator` in the Hugging Face `transformers` library is a utility class that prepares batches of data for training or evaluation.  It takes a list of examples (dictionaries containing features like input IDs, attention masks, labels, etc.) and combines them into a single batch.  Crucially, it handles the padding and tensorization of these examples, ensuring that all examples in a batch have the same sequence length. This is essential because models require inputs of consistent shape.
# >
# > Different `DataCollator` classes exist depending on the specific task and model.  For example, there's a `DataCollatorWithPadding`, which is commonly used.  It pads shorter sequences to the maximum length within the batch (dynamic padding), which is more efficient than padding all sequences to the maximum length in the dataset.
# >
# > In essence, the `DataCollator` simplifies the process of creating training batches and ensures that the input format is correct for the model, thus saving you the effort of manually handling these details.

# %%
# DataCollator
from transformers import DataCollatorForSeq2Seq
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model, max_length=max_length, return_tensors="pt")

# %% [markdown]
# ## Finish preprocessing the dataset

# %%
max_input_length = max_length
max_target_length = max_length
source_lang = "en"
target_lang = "fr"

def preprocess_function(examples):
    inputs  = [ ex[source_lang] for ex in examples["translation"] ]
    targets = [ ex[target_lang] for ex in examples["translation"] ]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets, FIXED: this was something I wasn't doing at first!
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
# %%time
tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/65742 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:3980: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/8218 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8218 [00:00<?, ? examples/s]
# CPU times: user 50.2 s, sys: 190 ms, total: 50.4 s
# Wall time: 50.2 s

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 65742
#     })
#     validation: Dataset({
#         features: ['translation', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 8218
#     })
#     test: Dataset({
#         features: ['translation', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 8218
#     })
# })

# %% [markdown]
# ### Metric

# %%
# !pip install evaluate numpy sacrebleu
# Out:
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.11/dist-packages (2.5.1)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.12.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.30.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (3.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.11.15)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)

# %% [markdown]
# We can use the "SacreBLEU" metric. I didn't try to understand that. Gemini helped for the code, as well as the tutorials from HuggingFace.

# %%
import numpy as np
import evaluate

metric = evaluate.load("sacrebleu")
# Out:
# Downloading builder script:   0%|          | 0.00/8.15k [00:00<?, ?B/s]

# %% [markdown]
# Some post-processing and the computation of the metrics we want to track while training our model:

# %%
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]
    return preds, labels

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)

    result = {k: round(v, 4) for k, v in result.items()}
    return result

# %% [markdown]
# ### Training (ie. fine-tuning)
#
# I've preferred to disable the integration with Weights and Biases (wandb), with this code:

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %% [markdown]
# Let's add callbacks, to save the model to [my HuggingFace profile (@Naereen)](https://huggingface.co/Naereen) regularly.
#
# ⚠ it wasn't working, so I've disabled them.

# %%
# from transformers.keras_callbacks import KerasMetricCallback
# metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=test_dataset)

from transformers.keras_callbacks import PushToHubCallback
push_to_hub_callback = PushToHubCallback(
    output_dir="./english-to-french-translation-for-Magic-the-Gathering",
    tokenizer=tokenizer,
)

callbacks = [
    # metric_callback,
    push_to_hub_callback,
]
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/Naereen/english-to-french-translation-for-Magic-the-Gathering into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/Naereen/english-to-french-translation-for-Magic-the-Gathering into local empty directory.
# Download file model.safetensors:   0%|          | 15.6k/880M [00:00<?, ?B/s]
# Download file training_args.bin: 100%|##########| 5.43k/5.43k [00:00<?, ?B/s]
# Download file target.spm:   4%|3         | 32.0k/801k [00:00<?, ?B/s]
# Download file source.spm:   4%|4         | 32.0k/784k [00:00<?, ?B/s]
# Clean file training_args.bin:  18%|#8        | 1.00k/5.43k [00:00<?, ?B/s]
# Clean file target.spm:   0%|          | 1.00k/801k [00:00<?, ?B/s]
# Clean file source.spm:   0%|          | 1.00k/784k [00:00<?, ?B/s]
# Clean file model.safetensors:   0%|          | 1.00k/880M [00:00<?, ?B/s]

# %% [markdown]
# We are ready to define our Seq2SeqTrainingArguments and our Seq2SeqTrainer.
# I've kept the hyper-parameters from this StackOverflow post I took inspiration from <https://stackoverflow.com/questions/75970711/how-to-properly-fine-tune-translational-transformer-models>, as well as the documentation here <https://huggingface.co/learn/llm-course/en/chapter7/4#fine-tuning-the-model> on HuggingFace's course on LLM and their fine-tuning.

# %%
# prompt: jupyter widget to select the value of num_train_epochs as an integer, default to 5

import ipywidgets as widgets
from IPython.display import display

# Create a slider widget
num_train_epochs_slider = widgets.IntSlider(
    value=3,
    min=1,
    max=20,
    step=1,
    description='num_train_epochs:',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)

# Display the widget
display(num_train_epochs_slider)
# Out:
# IntSlider(value=3, description='num_train_epochs:', max=20, min=1)

# %%
# Access the selected value using num_train_epochs_slider.value
num_train_epochs = num_train_epochs_slider.value
print(f"Selected num_train_epochs: {num_train_epochs}")
# Out:
# Selected num_train_epochs: 3

# %% [markdown]
# This was just a fancy thing. Let's get down to business!

# %%
# %%time
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer
# from transformers import TrainingArguments, Trainer

training_args = Seq2SeqTrainingArguments(
# training_args = TrainingArguments(

    output_dir="english-to-french-translation-for-Magic-the-Gathering",

    eval_strategy="epoch",

    save_strategy="epoch",

    learning_rate=3e-5,

    per_device_train_batch_size=32,

    per_device_eval_batch_size=64,

    weight_decay=0.01,

    save_total_limit=3,

    num_train_epochs=num_train_epochs,

    predict_with_generate=True,

    load_best_model_at_end=True,

    report_to="none",  # Disable all integrations,

    fp16=True,

    push_to_hub=True,

    warmup_steps=500,  # Adjust this value

    lr_scheduler_type="linear",

    seed=42,  # for reproducibility

    # Or your determined value
    #max_source_length=max_length,
    #max_target_length=max_length,

)

trainer = Seq2SeqTrainer(
# trainer = Trainer(
    model=model,

    args=training_args,

    train_dataset=tokenized_datasets["train"],

    eval_dataset=tokenized_datasets["validation"],

    tokenizer=tokenizer,

    data_collator=data_collator,

    compute_metrics=compute_metrics,

    # callbacks=callbacks,
)
# Out:
# CPU times: user 1.08 s, sys: 115 ms, total: 1.19 s
# Wall time: 1.48 s
# <timed exec>:47: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# We should be able to train (ie. fine-tune) our model, one a certain numbe of epochs.
# It should take quite some time, on a free Google's T4 GPU running on Google Colab notebooks' cloud.
#
# Before we run the training, let's evaluate the model, on both its training dataset, and its testing dataset (the part that will *not* be used during training).

# %%
# %%time
evaluation_before_finetuning = trainer.evaluate(max_length=max_length)

from pprint import pprint
pprint(evaluation_before_finetuning)
# Out:
#     <div>
#
#       <progress value='129' max='129' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [129/129 04:11]
#     </div>
# {'eval_bleu': 39.2849,
#  'eval_gen_len': 51.8153,
#  'eval_loss': 1.651272177696228,
#  'eval_model_preparation_time': 0.0033,
#  'eval_runtime': 301.7038,
#  'eval_samples_per_second': 27.239,
#  'eval_steps_per_second': 0.428}
# CPU times: user 5min 3s, sys: 812 ms, total: 5min 4s
# Wall time: 5min 1s

# %%
import pandas as pd
pd.DataFrame([evaluation_before_finetuning])
# Out:
#    eval_loss  eval_model_preparation_time  eval_bleu  eval_gen_len  \
# 0   1.651272                       0.0033    39.2849       51.8153
#
#    eval_runtime  eval_samples_per_second  eval_steps_per_second
# 0      301.7038                   27.239                  0.428

# %% [markdown]
# > A BLEU score of 46.2% is not too bad, which reflects the fact that our model is already good at translating English sentences to French ones.
# > (sentence taken from <https://huggingface.co/learn/llm-course/en/chapter7/4#fine-tuning-the-model-with-the-trainer-api>, I had no idea what BLUE was until an hour ago).
#
# I was getting 46% on the dataset *without the articles from Cranial Insertion*, let's try to use them this time.

# %% [markdown]
# ### Testing the current performance (mainly, the BLUE metric) on the 10% of "test" tokenized dataset

# %%
# %%time

evaluation_before_finetuning_on_testdataset = trainer.evaluate(tokenized_datasets["test"], max_length=max_length)

# pprint(evaluation_before_finetuning_on_testdataset)
pd.DataFrame([evaluation_before_finetuning_on_testdataset])
# Out:
#     <div>
#
#       <progress value='258' max='129' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [129/129 12:11]
#     </div>
# CPU times: user 5min 2s, sys: 403 ms, total: 5min 2s
# Wall time: 4min 58s
#    eval_loss  eval_model_preparation_time  eval_bleu  eval_gen_len  \
# 0    1.64886                       0.0033    39.5565       51.4305
#
#    eval_runtime  eval_samples_per_second  eval_steps_per_second
# 0      298.8335                     27.5                  0.432

# %% [markdown]
# > A BLEU score of 46.5% is not too bad, which reflects the fact that our model is already good at translating English sentences to French ones.
# > (sentence taken from <https://huggingface.co/learn/llm-course/en/chapter7/4#fine-tuning-the-model-with-the-trainer-api>, I had no idea what BLUE was until an hour ago).

# %%
pd.DataFrame([
    evaluation_before_finetuning,
    evaluation_before_finetuning_on_testdataset,
])
# Out:
#    eval_loss  eval_model_preparation_time  eval_bleu  eval_gen_len  \
# 0   1.651272                       0.0033    39.2849       51.8153
# 1   1.648860                       0.0033    39.5565       51.4305
#
#    eval_runtime  eval_samples_per_second  eval_steps_per_second
# 0      301.7038                   27.239                  0.428
# 1      298.8335                   27.500                  0.432

# %% [markdown]
# We have very similar result: BLEU metric is about 46% on our corpus of validation or test, which both consist of ~4800 pairs of English and French sentences.

# %%
len(tokenized_datasets["validation"]), len(tokenized_datasets["test"])
# Out:
# (8218, 8218)

# %% [markdown]
# ## LET's GO! For the fine-tuning, we are ready

# %%
# prompt: string of current date in standard full format
import datetime

def current_date_string():
    now = datetime.datetime.now()
    return now.strftime("%Y-%m-%d__%H:%M:%S")

print(current_date_string())
# Out:
# 2025-04-11__05:35:33

# %%
print_md(f"""## Starting to train for {num_train_epochs} epochs...
This should take {round(num_train_epochs * 3.5, 3)} minutes ? based on a rought estimate""")
# Out:
# ## Starting to train for 3 epochs...
# This should take 10.5 minutes ? based on a rought estimate

# %%
# %%time
before = current_date_string()
trainer.train()
after = current_date_string()

url_of_commit = trainer.push_to_hub(tags="translation",
                                    commit_message=f"Training complete (started at {before}, finished at {after})")

trainer.save_model('final_model')
url_of_commit
# Out:
#     <div>
#
#       <progress value='2056' max='6165' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2056/6165 04:32 < 09:05, 7.53 it/s, Epoch 1/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='341' max='129' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [129/129 34:13]
#     </div>

# %% [markdown]
# Now that the fine-tuning has been finished, let's evaluate the gain we obtained on our corpus, in terms of performance (mainly, BLUE metric).

# %% [markdown]
# We can check the metrics from before and now after the fine-tuning:

# %%
# %%time
print_md("## Before training, performance on the « validation » dataset ...")
pd.DataFrame([evaluation_before_finetuning])

print_md("## After training, performance on the « validation » dataset ...")
evaluation_after_finetuning = trainer.evaluate(tokenized_datasets["validation"], max_length=max_length)

pd.DataFrame([evaluation_after_finetuning])
# Out:
# {'eval_bleu': 15.936,
#  'eval_gen_len': 255.0,
#  'eval_loss': 7.785130023956299,
#  'eval_model_preparation_time': 0.0029,
#  'eval_runtime': 3.8141,
#  'eval_samples_per_second': 0.524,
#  'eval_steps_per_second': 0.262}
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# {'epoch': 3.0,
#  'eval_bleu': 15.936,
#  'eval_gen_len': 255.0,
#  'eval_loss': 7.785130023956299,
#  'eval_model_preparation_time': 0.0029,
#  'eval_runtime': 7.0326,
#  'eval_samples_per_second': 0.284,
#  'eval_steps_per_second': 0.142}

# %%
# %%time
print_md("## Before training, performance on the « test » dataset ...")
pd.DataFrame([evaluation_before_finetuning_on_testdataset])

print_md("## After training, performance on the « test » dataset ...")
evaluation_after_finetuning_on_testdataset = trainer.evaluate(tokenized_datasets["test"], max_length=max_length)

pd.DataFrame([evaluation_after_finetuning_on_testdataset])
# Out:
#    eval_loss  eval_model_preparation_time  eval_bleu  eval_gen_len  \
# 0    7.78513                       0.0029     15.936         255.0
# 1    7.78513                       0.0029     15.936         255.0
#
#    eval_runtime  eval_samples_per_second  eval_steps_per_second  epoch
# 0        3.8141                    0.524                  0.262    NaN
# 1        7.0326                    0.284                  0.142    3.0

# %% [markdown]
# Hopefully, this fine-tuning improved the BLUE metric on both the « validation » and « test » datasets.

# %% [markdown]
# -----
#
# ## Testing manually the final fine-tuned model, on some sentences

# %%
from transformers import pipeline

final_model     = AutoModelForSeq2SeqLM.from_pretrained("./final_model")
final_tokenizer = AutoTokenizer.from_pretrained("./final_model")

final_translator =  pipeline ('translation' , model=final_model, tokenizer=final_tokenizer)
def final_en2fr(text):
    return final_translator(text)[0]['translation_text']
# Out:
# Device set to use cuda:0

# %% [markdown]
# Let's try again the first two examples:

# %%
# %%time
example_english_text = "When this creature enters, create three 4/4 Elephant tokens with trample, then populate."
print_md(f"Example of English rules text: « {example_english_text} », getting translated:")

example_french_text = en2fr(example_english_text)
print_md(f"Initial translation ==> {example_french_text}")

example_french_text_final = final_en2fr(example_english_text)
print_md(f"Second translation ==> {example_french_text_final}")
# Out:
# Example of English rules text: « When this creature enters, create three 4/4 Elephant tokens with trample, then populate. », getting translated:
# ==> Lorsque cette créature entre, créez trois jetons Éléphant 4/4 avec piétinement, puis peuplez.
# CPU times: user 316 ms, sys: 1.2 ms, total: 317 ms
# Wall time: 377 ms

# %%
# %%time
example_english_text = """[a]I'm afraid you'll have to remove all six counters. Bounty of the Hunt tracks how many counters each creature received "this way", which means how many counters it received due to following the instructions of Bounty of the Hunt as modified by any applicable replacement effects. Since each target creature received two counters this way, you'll have to remove two counters from each of them.[/a]"""
print_md(f"Example of English rules text: « {example_english_text} », getting translated:")

example_french_text = en2fr(example_english_text)
print_md(f"Initial translation ==> {example_french_text}")

example_french_text_final = final_en2fr(example_english_text)
print_md(f"Second translation ==> {example_french_text_final}")
# Out:
# Example of English rules text: « [a]I'm afraid you'll have to remove all six counters. Bounty of the Hunt tracks how many counters each creature received "this way", which means how many counters it received due to following the instructions of Bounty of the Hunt as modified by any applicable replacement effects. Since each target creature received two counters this way, you'll have to remove two counters from each of them.[/a] », getting translated:
# ==> [a]J'ai peur que vous deviez retirer les six marqueurs. Bounty of the Hunt suit le nombre de marqueurs que chaque créature a reçu "de cette façon", ce qui signifie le nombre de marqueurs qu'elle a reçu en suivant les instructions de Bounty of the Hunt telles que modifiées par les effets de remplacement applicables. Puisque chaque créature cible a reçu deux marqueurs de cette façon, vous devrez retirer deux marqueurs de chacun d'eux.[/a]
# CPU times: user 1.21 s, sys: 0 ns, total: 1.21 s
# Wall time: 1.29 s

# %% [markdown]
# OK so the finetuning worked, but we do not observe any changes in the translation obtained by this model...

# %% [markdown]
# ## Compare the translations after and before fine-tuning

# %%
number_of_random_samples = 3

for idx, (name, df) in enumerate(zip(
        ["Cranial Insertion EN/FR", "MTG Cards Text EN/FR", "MTG Comprehensive Rules EN/FR"],
        [df_cranial_sentences, df_mtg, df_rules]
    )):
    print_md(f"\n\n## §{idx+1}. For some sentences from the « {name} » part of our database\n")

    # Get some random lines from this df
    some_random_lines = df.sample(n=number_of_random_samples)
    some_random_lines = some_random_lines.values.tolist()

    # Display the some random lines
    for line in some_random_lines:
        print_md(f"#### 1. In English:\n{line[0]}")
        print_md(f"#### 2. En français :\n{line[1]}")
        translation_from_model = en2fr(line[0])
        print_md(f"#### 3. Et en français traduit par le modèle initial :\n{translation_from_model}")
        translation_from_final_model = final_en2fr(line[0])
        print_md(f"#### 4. Et en français traduit par le modèle final :\n{translation_from_final_model}")

# %% [markdown]
# Let see if I'm now happy with the results...
# Anyway, it's time to go to bed 😴!

# %%
current_date_string()
# Out:
# '2025-04-11__04:36:56'
