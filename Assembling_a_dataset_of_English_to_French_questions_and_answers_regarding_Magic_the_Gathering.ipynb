# %% [markdown]
# # 🛡 🔨 🤖 **Dataset, assemble!**
#
# I want to create a semi-large supervised (labelled) dataset of questions and answers, in their original language (English) and their translated language (French).
#
# Once I'll have a lot of pairs of small sentences in English (source language) and French (target language), I'll try to use a Google colab cloud GPU to finetune the translation model I have been using in April 2025.
#
# Hopefully, I'll be able to do that efficiently, quickly, and then the model could be saved and shared on my [HuggingFace's profile](https://huggingface.co/Naereen) so that anyone can use it.

# %%
# !pip install watermark sacremoses tensorflow transformers requests beautifulsoup4
# %load_ext watermark
# %watermark -v -p numpy,pandas,tensorflow,transformers,requests,beautifulsoup4
# Out:
# Collecting watermark
#   Downloading watermark-2.5.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: ipython>=6.0 in /usr/local/lib/python3.11/dist-packages (from watermark) (7.34.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.11/dist-packages (from watermark) (8.6.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from watermark) (75.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacremoses) (2024.11.6)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sacremoses) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sacremoses) (4.67.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=1.4->watermark) (3.21.0)
# Collecting jedi>=0.16 (from ipython>=6.0->watermark)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.0->watermark) (4.9.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=6.0->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.0->watermark) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading watermark-2.5.0-py2.py3-none-any.whl (7.7 kB)
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 11.7 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.6 MB/s eta 0:00:00
# Installing collected packages: sacremoses, jedi, watermark
# Successfully installed jedi-0.19.2 sacremoses-0.1.1 watermark-2.5.0
# Python implementation: CPython
# Python version       : 3.11.11
# IPython version      : 7.34.0
#
# numpy         : 2.0.2
# pandas        : 2.2.2
# tensorflow    : 2.18.0
# transformers  : 4.50.3
# requests      : 2.32.3
# beautifulsoup4: not installed

# %% [markdown]
# ## Fetch all the content of English articles from Cranial Insertion

# %%
url_list_of_articles_english = "https://www.cranial-insertion.com/archive?lang=en"

# %%
# prompt: use requests to get the content of a HTML page on this URL
import requests
from bs4 import BeautifulSoup

response = requests.get(url_list_of_articles_english)
soup = BeautifulSoup(response.content, "html.parser")

# %%
from pprint import pprint
# Now you can work with the parsed HTML content in the 'soup' object.
all_recent_english_articles = []
all_recent_french_articles = []

for i, table in enumerate(soup.find("div", id="content").find_all("table")):
    print(f"\n# {i+1}-th article in the list on {url_list_of_articles_english}:")
    article_title = table.find("a", class_="plainlink").find("span").find("b").text
    article_id = table.find("a", class_="plainlink").get("href").split("/")[-1]
    article_link = f"https://www.cranial-insertion.com/article/{article_id}"
    article_edit_link = f"https://www.cranial-insertion.com/staff/articles/{article_id}/edit"
    article = {
        'article_title': article_title,
        'article_id': article_id,
        'article_link': article_link,
        'article_edit_link': article_edit_link,
    }
    pprint(article)

    # now get the translation in French
    article_fr_id = None
    for translation in table.find_all("td")[1].find("span").find_all("a"):
        if translation.text == "French" or translation.text == "Français":
            article_fr_id = translation.get("href").split("/")[-1]
            break

    article_fr_link = f"https://www.cranial-insertion.com/article/{article_fr_id}"
    article_fr_edit_link = f"https://www.cranial-insertion.com/staff/articles/{article_fr_id}/edit"
    article_fr = {
        #'article_title': article_fr_title,
        'article_id': article_fr_id,
        'article_link': article_fr_link,
        'article_edit_link': article_fr_edit_link,
    }
    pprint(article_fr)

    if article_fr_id:
        all_recent_english_articles.append(article)
        all_recent_french_articles.append(article_fr)

nb_english_articles = len(all_recent_english_articles)
nb_french_articles = len(all_recent_french_articles)
assert(nb_english_articles == nb_french_articles)
nb_articles = nb_french_articles
print(f"\n\n==> We have the metadata about {nb_articles} articles, that should be enough.")
# Out:
# # 1-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4380/edit',
#  'article_id': '4380',
#  'article_link': 'https://www.cranial-insertion.com/article/4380',
#  'article_title': 'Cloudy With a Chance of Dragonstorms'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/None/edit',
#  'article_id': None,
#  'article_link': 'https://www.cranial-insertion.com/article/None'}
#
# # 2-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4376/edit',
#  'article_id': '4376',
#  'article_link': 'https://www.cranial-insertion.com/article/4376',
#  'article_title': 'All in Jeopardy'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4379/edit',
#  'article_id': '4379',
#  'article_link': 'https://www.cranial-insertion.com/article/4379'}
#
# # 3-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4374/edit',
#  'article_id': '4374',
#  'article_link': 'https://www.cranial-insertion.com/article/4374',
#  'article_title': 'Happy Platinum Anniversary!'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4377/edit',
#  'article_id': '4377',
#  'article_link': 'https://www.cranial-insertion.com/article/4377'}
#
# # 4-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4371/edit',
#  'article_id': '4371',
#  'article_link': 'https://www.cranial-insertion.com/article/4371',
#  'article_title': 'A Very Green Day'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4373/edit',
#  'article_id': '4373',
#  'article_link': 'https://www.cranial-insertion.com/article/4373'}
#
# # 5-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4368/edit',
#  'article_id': '4368',
#  'article_link': 'https://www.cranial-insertion.com/article/4368',
#  'article_title': "Trample pig, trample pig, don't attack wolf shout!"}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4370/edit',
#  'article_id': '4370',
#  'article_link': 'https://www.cranial-insertion.com/article/4370'}
#
# # 6-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4365/edit',
#  'article_id': '4365',
#  'article_link': 'https://www.cranial-insertion.com/article/4365',
#  'article_title': 'Digging Into My Backlog'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4367/edit',
#  'article_id': '4367',
#  'article_link': 'https://www.cranial-insertion.com/article/4367'}
#
# # 7-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4362/edit',
#  'article_id': '4362',
#  'article_link': 'https://www.cranial-insertion.com/article/4362',
#  'article_title': 'The Greatest Snowman'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4363/edit',
#  'article_id': '4363',
#  'article_link': 'https://www.cranial-insertion.com/article/4363'}
#
# # 8-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4359/edit',
#  'article_id': '4359',
#  'article_link': 'https://www.cranial-insertion.com/article/4359',
#  'article_title': 'Keep Portland Weirdly About Magic'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4361/edit',
#  'article_id': '4361',
#  'article_link': 'https://www.cranial-insertion.com/article/4361'}
#
# # 9-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4356/edit',
#  'article_id': '4356',
#  'article_link': 'https://www.cranial-insertion.com/article/4356',
#  'article_title': "We're Going the Distance"}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4357/edit',
#  'article_id': '4357',
#  'article_link': 'https://www.cranial-insertion.com/article/4357'}
#
# # 10-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4352/edit',
#  'article_id': '4352',
#  'article_link': 'https://www.cranial-insertion.com/article/4352',
#  'article_title': "Moko's Sing-Along Rules Blog"}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4355/edit',
#  'article_id': '4355',
#  'article_link': 'https://www.cranial-insertion.com/article/4355'}
#
# # 11-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4350/edit',
#  'article_id': '4350',
#  'article_link': 'https://www.cranial-insertion.com/article/4350',
#  'article_title': "Georgia, the Spotlight's on You"}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4354/edit',
#  'article_id': '4354',
#  'article_link': 'https://www.cranial-insertion.com/article/4354'}
#
# # 12-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4346/edit',
#  'article_id': '4346',
#  'article_link': 'https://www.cranial-insertion.com/article/4346',
#  'article_title': 'Innistrad Redux'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4348/edit',
#  'article_id': '4348',
#  'article_link': 'https://www.cranial-insertion.com/article/4348'}
#
# # 13-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4344/edit',
#  'article_id': '4344',
#  'article_link': 'https://www.cranial-insertion.com/article/4344',
#  'article_title': 'Resolving Resolutions'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4349/edit',
#  'article_id': '4349',
#  'article_link': 'https://www.cranial-insertion.com/article/4349'}
#
# # 14-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4340/edit',
#  'article_id': '4340',
#  'article_link': 'https://www.cranial-insertion.com/article/4340',
#  'article_title': "Don't Copy Me Bro"}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4343/edit',
#  'article_id': '4343',
#  'article_link': 'https://www.cranial-insertion.com/article/4343'}
#
# # 15-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4337/edit',
#  'article_id': '4337',
#  'article_link': 'https://www.cranial-insertion.com/article/4337',
#  'article_title': "Natedogg's 2024 in Review"}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4339/edit',
#  'article_id': '4339',
#  'article_link': 'https://www.cranial-insertion.com/article/4339'}
#
# # 16-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4334/edit',
#  'article_id': '4334',
#  'article_link': 'https://www.cranial-insertion.com/article/4334',
#  'article_title': "We Put The 'Ice' in 'Solstice'"}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4336/edit',
#  'article_id': '4336',
#  'article_link': 'https://www.cranial-insertion.com/article/4336'}
#
# # 17-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4331/edit',
#  'article_id': '4331',
#  'article_link': 'https://www.cranial-insertion.com/article/4331',
#  'article_title': 'Year End Mailbag'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4333/edit',
#  'article_id': '4333',
#  'article_link': 'https://www.cranial-insertion.com/article/4333'}
#
# # 18-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4328/edit',
#  'article_id': '4328',
#  'article_link': 'https://www.cranial-insertion.com/article/4328',
#  'article_title': 'The Season of Gifting'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4330/edit',
#  'article_id': '4330',
#  'article_link': 'https://www.cranial-insertion.com/article/4330'}
#
# # 19-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4324/edit',
#  'article_id': '4324',
#  'article_link': 'https://www.cranial-insertion.com/article/4324',
#  'article_title': 'Quizgiving III'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4327/edit',
#  'article_id': '4327',
#  'article_link': 'https://www.cranial-insertion.com/article/4327'}
#
# # 20-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4321/edit',
#  'article_id': '4321',
#  'article_link': 'https://www.cranial-insertion.com/article/4321',
#  'article_title': 'Questions on Broadway'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4323/edit',
#  'article_id': '4323',
#  'article_link': 'https://www.cranial-insertion.com/article/4323'}
#
# # 21-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4318/edit',
#  'article_id': '4318',
#  'article_link': 'https://www.cranial-insertion.com/article/4318',
#  'article_title': 'Building Up Our Foundations'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4320/edit',
#  'article_id': '4320',
#  'article_link': 'https://www.cranial-insertion.com/article/4320'}
#
# # 22-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4314/edit',
#  'article_id': '4314',
#  'article_link': 'https://www.cranial-insertion.com/article/4314',
#  'article_title': 'Prelude to Foundations'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4317/edit',
#  'article_id': '4317',
#  'article_link': 'https://www.cranial-insertion.com/article/4317'}
#
# # 23-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4311/edit',
#  'article_id': '4311',
#  'article_link': 'https://www.cranial-insertion.com/article/4311',
#  'article_title': 'Vote Vote Vote!'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4316/edit',
#  'article_id': '4316',
#  'article_link': 'https://www.cranial-insertion.com/article/4316'}
#
# # 24-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4309/edit',
#  'article_id': '4309',
#  'article_link': 'https://www.cranial-insertion.com/article/4309',
#  'article_title': 'Halloween Costume Ideas'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4312/edit',
#  'article_id': '4312',
#  'article_link': 'https://www.cranial-insertion.com/article/4312'}
#
# # 25-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4305/edit',
#  'article_id': '4305',
#  'article_link': 'https://www.cranial-insertion.com/article/4305',
#  'article_title': 'This is a (Play)test'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4307/edit',
#  'article_id': '4307',
#  'article_link': 'https://www.cranial-insertion.com/article/4307'}
#
# # 26-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4302/edit',
#  'article_id': '4302',
#  'article_link': 'https://www.cranial-insertion.com/article/4302',
#  'article_title': 'So you think you can take a Judge Test?'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4304/edit',
#  'article_id': '4304',
#  'article_link': 'https://www.cranial-insertion.com/article/4304'}
#
# # 27-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4298/edit',
#  'article_id': '4298',
#  'article_link': 'https://www.cranial-insertion.com/article/4298',
#  'article_title': 'Fear of Questions and Answers'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4300/edit',
#  'article_id': '4300',
#  'article_link': 'https://www.cranial-insertion.com/article/4300'}
#
# # 28-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4295/edit',
#  'article_id': '4295',
#  'article_link': 'https://www.cranial-insertion.com/article/4295',
#  'article_title': 'Little House of Horrors'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4297/edit',
#  'article_id': '4297',
#  'article_link': 'https://www.cranial-insertion.com/article/4297'}
#
# # 29-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4292/edit',
#  'article_id': '4292',
#  'article_link': 'https://www.cranial-insertion.com/article/4292',
#  'article_title': 'Duskmourn: House of Q & A'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4294/edit',
#  'article_id': '4294',
#  'article_link': 'https://www.cranial-insertion.com/article/4294'}
#
# # 30-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4289/edit',
#  'article_id': '4289',
#  'article_link': 'https://www.cranial-insertion.com/article/4289',
#  'article_title': 'Halloween Creep'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4291/edit',
#  'article_id': '4291',
#  'article_link': 'https://www.cranial-insertion.com/article/4291'}
#
# # 31-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4286/edit',
#  'article_id': '4286',
#  'article_link': 'https://www.cranial-insertion.com/article/4286',
#  'article_title': 'Fall Color Pie'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4288/edit',
#  'article_id': '4288',
#  'article_link': 'https://www.cranial-insertion.com/article/4288'}
#
# # 32-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4282/edit',
#  'article_id': '4282',
#  'article_link': 'https://www.cranial-insertion.com/article/4282',
#  'article_title': 'Bear Cubs and Internet Chatrooms'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4284/edit',
#  'article_id': '4284',
#  'article_link': 'https://www.cranial-insertion.com/article/4284'}
#
# # 33-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4279/edit',
#  'article_id': '4279',
#  'article_link': 'https://www.cranial-insertion.com/article/4279',
#  'article_title': 'A Few of My Favorite Cards'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4281/edit',
#  'article_id': '4281',
#  'article_link': 'https://www.cranial-insertion.com/article/4281'}
#
# # 34-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4273/edit',
#  'article_id': '4273',
#  'article_link': 'https://www.cranial-insertion.com/article/4273',
#  'article_title': 'Back to School, 7th Edition'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4278/edit',
#  'article_id': '4278',
#  'article_link': 'https://www.cranial-insertion.com/article/4278'}
#
# # 35-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4270/edit',
#  'article_id': '4270',
#  'article_link': 'https://www.cranial-insertion.com/article/4270',
#  'article_title': 'From North Dakota to Maryland'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4272/edit',
#  'article_id': '4272',
#  'article_link': 'https://www.cranial-insertion.com/article/4272'}
#
# # 36-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4267/edit',
#  'article_id': '4267',
#  'article_link': 'https://www.cranial-insertion.com/article/4267',
#  'article_title': 'Bunnies, Bunnies, It Must be Bunnies!'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4269/edit',
#  'article_id': '4269',
#  'article_link': 'https://www.cranial-insertion.com/article/4269'}
#
# # 37-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4263/edit',
#  'article_id': '4263',
#  'article_link': 'https://www.cranial-insertion.com/article/4263',
#  'article_title': 'Rabbits and Squirrels and Birds, Oh My!'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4265/edit',
#  'article_id': '4265',
#  'article_link': 'https://www.cranial-insertion.com/article/4265'}
#
# # 38-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4259/edit',
#  'article_id': '4259',
#  'article_link': 'https://www.cranial-insertion.com/article/4259',
#  'article_title': 'Baltimore Here I Come'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4262/edit',
#  'article_id': '4262',
#  'article_link': 'https://www.cranial-insertion.com/article/4262'}
#
# # 39-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4256/edit',
#  'article_id': '4256',
#  'article_link': 'https://www.cranial-insertion.com/article/4256',
#  'article_title': 'Midsummer Cleaning'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4258/edit',
#  'article_id': '4258',
#  'article_link': 'https://www.cranial-insertion.com/article/4258'}
#
# # 40-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4249/edit',
#  'article_id': '4249',
#  'article_link': 'https://www.cranial-insertion.com/article/4249',
#  'article_title': 'Summer Time Quiz'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4255/edit',
#  'article_id': '4255',
#  'article_link': 'https://www.cranial-insertion.com/article/4255'}
#
# # 41-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4251/edit',
#  'article_id': '4251',
#  'article_link': 'https://www.cranial-insertion.com/article/4251',
#  'article_title': 'Killing Me Softly'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4253/edit',
#  'article_id': '4253',
#  'article_link': 'https://www.cranial-insertion.com/article/4253'}
#
# # 42-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4247/edit',
#  'article_id': '4247',
#  'article_link': 'https://www.cranial-insertion.com/article/4247',
#  'article_title': 'A Third of Modern Horizons'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4250/edit',
#  'article_id': '4250',
#  'article_link': 'https://www.cranial-insertion.com/article/4250'}
#
# # 43-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4244/edit',
#  'article_id': '4244',
#  'article_link': 'https://www.cranial-insertion.com/article/4244',
#  'article_title': 'Modernest Horizons'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4246/edit',
#  'article_id': '4246',
#  'article_link': 'https://www.cranial-insertion.com/article/4246'}
#
# # 44-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4241/edit',
#  'article_id': '4241',
#  'article_link': 'https://www.cranial-insertion.com/article/4241',
#  'article_title': '3rd Modern Event Horizon'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4243/edit',
#  'article_id': '4243',
#  'article_link': 'https://www.cranial-insertion.com/article/4243'}
#
# # 45-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4238/edit',
#  'article_id': '4238',
#  'article_link': 'https://www.cranial-insertion.com/article/4238',
#  'article_title': 'Modern Horizons Flashback'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4240/edit',
#  'article_id': '4240',
#  'article_link': 'https://www.cranial-insertion.com/article/4240'}
#
# # 46-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4235/edit',
#  'article_id': '4235',
#  'article_link': 'https://www.cranial-insertion.com/article/4235',
#  'article_title': "Avacyn's Memorial Day Sale"}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4237/edit',
#  'article_id': '4237',
#  'article_link': 'https://www.cranial-insertion.com/article/4237'}
#
# # 47-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4232/edit',
#  'article_id': '4232',
#  'article_link': 'https://www.cranial-insertion.com/article/4232',
#  'article_title': 'Question and Answer Roundup'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4234/edit',
#  'article_id': '4234',
#  'article_link': 'https://www.cranial-insertion.com/article/4234'}
#
# # 48-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4229/edit',
#  'article_id': '4229',
#  'article_link': 'https://www.cranial-insertion.com/article/4229',
#  'article_title': 'Happy 41st Birthday to Me!'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4231/edit',
#  'article_id': '4231',
#  'article_link': 'https://www.cranial-insertion.com/article/4231'}
#
# # 49-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4225/edit',
#  'article_id': '4225',
#  'article_link': 'https://www.cranial-insertion.com/article/4225',
#  'article_title': 'Horsing Around'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4227/edit',
#  'article_id': '4227',
#  'article_link': 'https://www.cranial-insertion.com/article/4227'}
#
# # 50-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4221/edit',
#  'article_id': '4221',
#  'article_link': 'https://www.cranial-insertion.com/article/4221',
#  'article_title': 'NRG St. Paul - Tournament Report'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4224/edit',
#  'article_id': '4224',
#  'article_link': 'https://www.cranial-insertion.com/article/4224'}
#
# # 51-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4219/edit',
#  'article_id': '4219',
#  'article_link': 'https://www.cranial-insertion.com/article/4219',
#  'article_title': "It's High Noon!"}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4222/edit',
#  'article_id': '4222',
#  'article_link': 'https://www.cranial-insertion.com/article/4222'}
#
# # 52-th article in the list on https://www.cranial-insertion.com/archive?lang=en:
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4216/edit',
#  'article_id': '4216',
#  'article_link': 'https://www.cranial-insertion.com/article/4216',
#  'article_title': 'Meet The Outlaws'}
# {'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4218/edit',
#  'article_id': '4218',
#  'article_link': 'https://www.cranial-insertion.com/article/4218'}
# We have the metadata about 51 articles, that should be enough.

# %% [markdown]
# Now for each article, get its content:

# %%
try:
    with open("cranial-insertion.com.cookies", 'r') as file:
        cranial_insertion_cookie = file.read()
    print("Cranial Insertion cookie successfully loaded from local file 'cranial-insertion.com.cookies', it can now be used (it's a secret)")
except FileNotFoundError:
    from google.colab import userdata
    cranial_insertion_cookie = userdata.get('CI_COOKIE')
    print("Cranial Insertion cookie successfully loaded from Google Colab secrets, it can now be used (it's a secret)")
# Out:
# Cranial Insertion cookie successfully loaded from Google Colab secrets, it can now be used (it's a secret)

# %%
def get_article_text(article_id=article_id, latest_article_edit_url=None):
    if not latest_article_edit_url:
        latest_article_edit_url = f"https://www.cranial-insertion.com/staff/articles/{article_id}/edit"
    print(f"Reading the article at URL {latest_article_edit_url} ...")

    cookies = {
        'loggedin': cranial_insertion_cookie,
        'siteLang': 'fr',
    }
    #print(f"Using French language and my editor cookie...")

    response = requests.get(latest_article_edit_url, cookies=cookies)
    soup = BeautifulSoup(response.text, 'html.parser')
    print(f"The web page has been read and it's title is « {soup.title} » !")

    latest_article_text = soup.find(id="thisArticleText").get_text()
    latest_article_title = soup.find(id="thisArticleTitle").get('value')
    latest_article_date = soup.find(id="thisArticlePubdate").get('value')

    return latest_article_text, latest_article_title, latest_article_date, soup

# %% [markdown]
# ### We can now download the raw content of each of these 51 articles, in both languages

# %%
content_articles = []

for en_article, fr_article in zip(all_recent_english_articles, all_recent_french_articles):
    latest_article_text, latest_article_title, latest_article_date, soup = get_article_text(article_id=en_article['article_id'])
    content_en = {
        'article_id': en_article['article_id'],
        'article_title': latest_article_title,
        'article_link': en_article['article_link'],
        'article_edit_link': en_article['article_edit_link'],
        'article_text': latest_article_text,
        'article_date': latest_article_date,
    }

    latest_article_text, latest_article_title, latest_article_date, soup = get_article_text(article_id=fr_article['article_id'])
    content_fr = {
        'article_id': fr_article['article_id'],
        'article_title': latest_article_title,
        'article_link': fr_article['article_link'],
        'article_edit_link': fr_article['article_edit_link'],
        'article_text': latest_article_text,
        'article_date': latest_article_date,
    }

    content_articles.append({
        'en': content_en,
        'fr': content_fr,
    })

    # TODO: remove this break if everything works fine
    break

pprint(content_articles)
# Out:
# Reading the article at URL https://www.cranial-insertion.com/staff/articles/4376/edit ...
# The web page has been read and it's title is « <title>Cranial Insertion | Manage Articles</title> » !
# Reading the article at URL https://www.cranial-insertion.com/staff/articles/4379/edit ...
# The web page has been read and it's title is « <title>Cranial Insertion | Manage Articles</title> » !
# [{'en': {'article_date': '03/31/2025',
#          'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4376/edit',
#          'article_id': '4376',
#          'article_link': 'https://www.cranial-insertion.com/article/4376',
#          'article_text': '[cright=Living Death]"Alex, the answer is "What '
#                          'would be an\n'
#                          'example of an oximoron?"[/cright]\n'
#                          '\n'
#                          'Today we have a collection of questions found on the '
#                          'IRC Chatroom #magicjudges-rules and the Facebook '
#                          'group Ask the Judge - [b]Magic[/b]: The Gathering '
#                          'Rules and Policy Questions. Feel free to join us in '
#                          'either or both groups.\n'
#                          '\n'
#                          'If you have any [b]Magic[/b] questions burning at '
#                          'the back of your brain, you can send them to us. We '
#                          'may even use them in a future article. If you have a '
#                          'short question, you can send it to us via our '
#                          'Twitter account at '
#                          '[url=https://twitter.com/CranialTweet]@CranialTweet[/url], '
#                          'and you can send us longer questions at '
#                          '[email]moko@cranialinsertion.com[/email].\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] I have two [c]Squire[/c]s on the battlefield and '
#                          'I have [c]Custodi Soulbinders[/c] and four copies of '
#                          '[c]Bear Cub[/c] in my graveyard. If I cast [c]Living '
#                          'Death[/c], how many +1/+1 counters will Soulbinders '
#                          'enter with?[/Q]\n'
#                          '\n'
#                          '[A] Custodi Soulbinders will enter with zero +1/+1 '
#                          'counters. Souldbinders and the Bears will enter '
#                          "simultaneously. Soulbinders' first ability is a "
#                          'replacement effect that checks to see how many '
#                          'creatures are on the battlefield just before it '
#                          'enters. At that point there are no creatures on the '
#                          'board, so it gets no counters as it enters.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] My commander is [c]Grimgrin, Corpse-Born[/c]. '
#                          'Grimgrin was [c]Murder[/c]ed last turn and I choose '
#                          'to move him to the command zone. I control '
#                          '[c]Rooftop Storm[/c]. If I try to cast Grimgrin from '
#                          'the command zone, will he cost [m]2[/m] or will he '
#                          'be free?[/Q]\n'
#                          '\n'
#                          '[A] He will cost [m]2[/m]. \n'
#                          'Commander "tax" is an additional cost that must be '
#                          'paid in addition to the normal cost for casting your '
#                          'commander. Rooftop Storm gives you the option of '
#                          'replacing the normal cost of casting your Zombies '
#                          'with [m]0[/m]. This has no effect on additional '
#                          'costs.  [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] My opponent exiled [c]Wheel of Fate[/c] with '
#                          '[c]Reckless Impulse[/c]. She now claims she can cast '
#                          "Wheel of Fate because it's in exile. Is that "
#                          'true?[/Q]\n'
#                          '\n'
#                          '[A] Your opponent is wrong. The part of suspend that '
#                          'lets you cast a card with no mana cost is casting it '
#                          "without paying its mana cost, not that it's casting "
#                          'it from exile.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] I control four [c]Bear Cub[/c]s, [c]Agrus Kos, '
#                          'Eternal Soldier[/c], and [c]Thundering Raiju[/c]. '
#                          'None of my creatures are currently modified. I '
#                          'attack with the Raiju and have its attack trigger '
#                          "target Agrus. When Agrus's ability triggers because "
#                          'he became targeted, I pay the cost. After all these '
#                          'triggers resolve, how much damage will Raiju deal to '
#                          'each opponent?[/Q]\n'
#                          '\n'
#                          '[A] The Answer is between 15-19 damage, depending on '
#                          'when you let the trigger targeting Raiju resolve.\n'
#                          '\n'
#                          "When Agrus's trigger resolves, it creates five "
#                          "copies of Raiju's trigger, one for each Bear and one "
#                          'for Raiju, making a total of six Raiju triggers. The '
#                          'last trigger to resolve has to be the one targeting '
#                          'Agrus, and the other five resolve before it in the '
#                          'order of your choosing. \n'
#                          '\n'
#                          'For our first example, we will have the trigger '
#                          'targeting Raiju resolve first, then the four '
#                          'triggers targeting Bears, and finally the one '
#                          'targeting Agrus.\n'
#                          '\n'
#                          'Raiju gets a +1/+1 counter, no damage is dealt as '
#                          'Raiju only checks modified creatures other than '
#                          'himself. Total damage 0.\n'
#                          'Bear #1 gets a +1/+1 counter, 1 damage is dealt as '
#                          'there is only one modified creature other than '
#                          'Raiju. Total damage 1.\n'
#                          'Bear #2 gets a +1/+1 counter, 2 damage is dealt as '
#                          'there are now two modified creatures. Total damage '
#                          '3.\n'
#                          'Bear #3 gets a +1/+1 counter, 3 damage is dealt. '
#                          'Total damage 6.\n'
#                          'Bear #4 gets a counter, 4 damage is dealt. Total '
#                          'damage of 10.\n'
#                          'Agrus get a a counter, 5 damage is dealt. Total '
#                          'damage of 15.\n'
#                          '\n'
#                          "Now let's have the four Bears' triggers resolve "
#                          'first, then Raiju, followed by Agrus.\n'
#                          'Bear #1, 1 damage is dealt. Total damage 1.\n'
#                          'Bear #2, 2 damage is dealt. Total damage 3.\n'
#                          'Bear #3, 3 damage id dealt. Total damage 6.\n'
#                          'Bear #4, 4 damage is dealt. Total damage is 10.\n'
#                          'Raiju, 4 damage is dealt. Total damage is 14.\n'
#                          'Agrus, 5 damage is dealt. Total damage is 19.\n'
#                          '\n'
#                          'The later the trigger targeting Raiju resolves, the '
#                          'more the total damage.\n'
#                          ' [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[cleft=Grafdigger\'s Cage]Alex, the answer is "What '
#                          'is used to \n'
#                          'keep the dead from escaping their '
#                          'graves?"[/cleft][Q] Does [c]Grafdigger\'s Cage[/c] '
#                          'stop [c]Abhorrent Oculus[/c] from '
#                          'manifest-dreading?[/Q]\n'
#                          '\n'
#                          '[A] Well, in the important ways, yes. They still '
#                          '"manifest dread", but some parts they can\'t '
#                          'complete. Manifest Dread is "Look at the top two '
#                          'cards of your library. Manifest one of them, then '
#                          'put the cards you looked at that were not manifested '
#                          'this way into your graveyard." Since you can\'t put '
#                          'a creature from your library into play, both cards '
#                          'looked at are put into the graveyard.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] Last turn my opponent stole my [c]Bear Cub[/c] '
#                          'by casting [c]Sower of Temptation[/c]. This turn I '
#                          'used [c]Ovinize[/c] to make the Sower lose all its '
#                          "abilities. I did this because I think I'll get my "
#                          'Bear Cub back, since the Sower no longer has the '
#                          '"steal your creature" ability. My opponent '
#                          'disagrees. Who is right?[/Q]\n'
#                          '\n'
#                          '[A] Your opponent is correct. Removing the enters '
#                          'ability (that creates an effect with a duration) '
#                          "after the ability has resolved, doesn't stop it from "
#                          'functioning.\n'
#                          '\n'
#                          'If it helps, an example that seems more intuitive '
#                          'would be the following: My opponent used '
#                          '[c]Rootwater Matriarch[/c] to steel my [c]Hill '
#                          'Giant[/c] enchanted with [c]Spirit Link[/c]. Killing '
#                          "the Matriarch won't get the Hill Giant back, even "
#                          'though that removes where the steal ability came '
#                          'from. The duration is based on whether or not the '
#                          'Hill Giant is still enchanted.\n'
#                          '\n'
#                          "So with the original question, removing Sower's "
#                          "abilities doesn't stop the steal effect. You have to "
#                          'remove the Sower to gain the creature back because '
#                          'that ends the duration of the effect.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] So continuing with the last question, what if '
#                          'instead of [c]Ovinize[/c]ing the [c]Sower of '
#                          'Temptation[/c] I phased it out with [c]Reality '
#                          'Ripple[/c]?[/Q]\n'
#                          '\n'
#                          '[A] You would get your creature back. If a creature '
#                          "phases out, it's treated as though it's no longer on "
#                          'the battlefield. The duration of its effect has been '
#                          'met, so the effect ends and the stolen creature '
#                          'returns to its last controller, usually its '
#                          'owner.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          "[Q] I block my opponent's attacking [c]Bear Cub[/c] "
#                          'with [c]Manor Gargoyle[/c]. After combat ends, the '
#                          'opponent then casts [c]Disfigure[/c] targeting my '
#                          'Gargoyle. They claim they just killed my Gargoyle. '
#                          'Is this true?[/Q]\n'
#                          '\n'
#                          '[A] It is not true, your Gargoyle lives through '
#                          'this. Many new players make this same wrong '
#                          "assumption. Damage doesn't reduce toughness. You "
#                          'have a 2/2 Gargoyle with 2 damage marked on it. '
#                          "Because it's indestructible, the state based action "
#                          'that tries to destroy it for having equal or more '
#                          'damage than it has toughness fails to do anything. '
#                          'If they want to get your Gargoyle into the '
#                          'graveyard, they need to give it enough '
#                          '[c=Dismember]-X/-X to make its toughness 0 or '
#                          'less[/c], or force you to [c=Diabolic '
#                          'Edict]sacrifice it[/c].[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] If [c]Ragavan, Nimble Pilferer[/c] is my '
#                          'commander, can I cast him for his dash cost from the '
#                          'command zone?[/Q]\n'
#                          '\n'
#                          '[A] Yes, you can. Dash can be used from any zone, so '
#                          'long as you are allowed to cast that card from that '
#                          'same zone normally. [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] Following up with the last question, do I have '
#                          'to pay commander tax if I dash out my '
#                          'commander?[/Q]\n'
#                          '\n'
#                          '[A] Yes, you do. Suppose you cast Ragavan normally '
#                          'on turn one, then later he died and returned to the '
#                          'command zone. When you go to dash him he now costs '
#                          '[m]3[/m][m]R[/m] to dash. Then if he dies again and '
#                          'returns to the command zone, the next time you go to '
#                          'cast him he costs either [m]4[/m][m]R[/m] to cast '
#                          'normally or [m]5[/m][m]R[/m] to dash.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] I have eight cards in my hand. I go to my '
#                          'cleanup step and discard [c]Blazing Rootwalla[/c] to '
#                          'get down to maximum hand size. Can I cast the '
#                          "Rootwalla even though I'm in my cleanup step?[/Q]\n"
#                          '\n'
#                          '[A] Yes, you can. During most cleanup steps, no '
#                          'players get priority. However, if an ability '
#                          'triggers during the cleanup step, or a state based '
#                          'action applies during a cleanup step, then the '
#                          'active player gains priority and may cast spells and '
#                          'activate abilities. \n'
#                          '\n'
#                          'This is when you can cast the Rootwalla, as '
#                          'discarding it to madness puts a trigger on the '
#                          'stack.\n'
#                          '\n'
#                          'A normal priority pass will begin from here and '
#                          'until all players pass in succession with an empty '
#                          'stack, players may add new items to the stack when '
#                          'they have priority. Once all players pass with an '
#                          'empty stack, this cleanup step ends and a new one '
#                          'begins. If that new cleanup ends normally, then the '
#                          "game will move on to the next player's turn.[/A]\n"
#                          '\n'
#                          '[hr]\n'
#                          '[Q] While resolving [c]Burning Inquiry[/c] I '
#                          'discarded [c]Basking Rootwalla[/c] and two '
#                          '[c]Mountain[/c]s. My opponent controls a [c]Rest in '
#                          "Peace[/c]. My opponent claims I can't cast the "
#                          'Rootwalla for its Madness cost as it got exiled by '
#                          'Rest in Peace when I discarded it. Is this '
#                          'true?[/Q]\n'
#                          '\n'
#                          '[A] Your opponent is wrong. You can cast your '
#                          "Rootwalla for its madness cost. The Rootwalla hasn't "
#                          'been exiled by Rest in Peace yet. This is because '
#                          "madness doesn't quite work the way most people think "
#                          'it does. If a card with madness gets discarded, it '
#                          "goes to exile instead of being put into its owner's "
#                          'graveyard. Then the next time a player would get '
#                          'priority, a trigger allowing its owner to cast it '
#                          'for its madness cost is put on the stack. When this '
#                          'trigger resolves, the owner may cast the card, but '
#                          "if they don't then the card is put into their "
#                          'graveyard. \n'
#                          '\n'
#                          'To get back to the original question, Rest in Peace '
#                          'can only exile a discarded Madness card after the '
#                          'owner has decided not to cast it for madness and '
#                          'choses to let it go to the graveyard.\n'
#                          '[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] My opponent pays [m]3[/m][m]U[/m] to gain level '
#                          "2 on their [c]Stormchaser's Talent[/c]. Before it "
#                          'becomes level 2, I [c]Boomerang[/c] it to their '
#                          'hand. The opponent says they still get to return an '
#                          "instant or sorcery to their hand, I say they don't, "
#                          'who is right?[/Q]\n'
#                          '\n'
#                          '[A] You are correct, they do not. Gaining a level is '
#                          'an ability that uses the stack and can be responded '
#                          "to. Stormchaser's level 2 ability is a trigger that "
#                          'triggers upon it becoming level 2 and happens only '
#                          "after it becomes level 2. If it's not on the "
#                          'battlefield when its level 2 ability resolves, there '
#                          'is no ability to trigger (nor a permanent to become '
#                          'level 2). [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[cright=Bear Cub|PO2]Alex, the answer is "What is '
#                          'another\n'
#                          'name for Ursine Child?"[/cright][Q] I enchanted my '
#                          "opponent's [c]Bear Cub[/c] with my [c]Sigil of "
#                          'Sleep[/c]. If the Bear Cub goes unblocked attacking '
#                          'me, who chooses which creature I control gets '
#                          "returned to its owner's hand?[/Q]\n"
#                          '\n'
#                          '[A] You get to choose as you control the Sigil of '
#                          'Sleep.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] I attack with [c]Geist of Saint Traft[/c] while '
#                          'I control [c]Anointed Procession[/c]. When combat '
#                          'ends, will both Angel tokens get exiled or do I get '
#                          'to keep one?[/Q]\n'
#                          '\n'
#                          "[A] Both still get exiled. Saint Traft's triggered "
#                          'ability still made both tokens and tracks them to be '
#                          "exiled at the end of combat. Procession doesn't make "
#                          'tokens, it just changes how many tokens other cards '
#                          'and abilities make.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] I attack with [c]Geist of Saint Traft[/c], but '
#                          'before blocks, I cast [c]Eyes in the Skies[/c] '
#                          'choosing to populate the Angel token. When combat '
#                          'ends, will both Angel tokens get exiled or do I get '
#                          'to keep one?[/Q]\n'
#                          '\n'
#                          '[A] You get to keep the one made by Eyes in the '
#                          'Skies. Unlike Anointed Procession from the last '
#                          'question, Eyes in the Skies makes the token and the '
#                          'token has no link to the ability that made the '
#                          'original Angel token. This includes that the second '
#                          'Angel token is not attacking, is not tapped, and it '
#                          "won't get exiled at the end of combat.[/A]\n"
#                          '\n'
#                          '[hr]\n'
#                          "[Q] I don't understand what [c]Emrakul, the World "
#                          'Anew[/c] has protection from. Can you clarify '
#                          'this?[/Q]\n'
#                          '\n'
#                          '[A] Emrakul has protection from spells and '
#                          'separately protection from permanents cast "this '
#                          'turn". This turn is whichever turn it currently is, '
#                          "even if it's been many turns since Emrakul herself "
#                          'was cast. \n'
#                          '\n'
#                          'So for example, if I cast [c]Visara the Dreadful[/c] '
#                          'and gave her some [c]Lightning Greaves[/c] the same '
#                          "turn I cast her, she can't target and destroy "
#                          'Emrakul that turn. However, if I pass to my '
#                          "opponent's turn, Visara can now kill Emrakul as it's "
#                          'no longer the same turn Visara was cast. If I used '
#                          "[c]Goryo's Vengeance[/c] to reanimate Visara, then "
#                          'Visara could kill Emrakul that same turn as Visara '
#                          "wasn't cast at all.\n"
#                          '\n'
#                          "Emrakul's protection ability acts similar to having "
#                          'protection from Auras. Auras when cast target what '
#                          'they will enchant, so Emrakul is safe from most '
#                          'Auras. However, on later turns, an Aura could be '
#                          'moved from its original target, to enchant Emrakul. '
#                          'For example, you could move [c]Pacifism[/c] from a '
#                          '1/1 Goblin token to Emrakul using [c]Crown of the '
#                          'Ages[/c]. \n'
#                          '[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] I cast [c]Season of Weaving[/c] choosing the two '
#                          'paws mode (to copy my [c]Arcanis the Omnipotent[/c]) '
#                          'and the three paws mode. Will I have to put one '
#                          'Arcanis into my graveyard due to the legend rule '
#                          'before bouncing all nonland and nontoken '
#                          'permanents?[/Q]\n'
#                          '\n'
#                          '[A] You will not and you can not. The legend rule is '
#                          "a state based action. It's never checked in the "
#                          'middle of resolving a spell. You will put the '
#                          'original Arcanis into your hand before Season of '
#                          "Weaving fully resolves. The legend rule doesn't come "
#                          'into play during this situation.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] If I cast [c]Righteous Confluence[/c] choosing '
#                          "mode two once to exile my opponent's [c]Leyline of "
#                          'Sanctity[/c] and mode three twice to gain 10 total '
#                          'life, and the opponent responds by '
#                          '[c]Boomerang[/c]ing the Leyline back to their hand, '
#                          'do I still gain 10 life?[/Q]\n'
#                          '\n'
#                          '[A] You do not. Righteous Confluence had only one '
#                          'target, Leyline of Sanctity, and that target has '
#                          'disappeared. If a spell loses all of its targets by '
#                          'the time it goes to resolve, it fizzles and none of '
#                          'its effects happen. [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q] I just cast [c]Cultivate[/c] putting a '
#                          '[c]Swamp[/c] onto the battlefield and a '
#                          "[c]Forest[/c] into my hand. I haven't played a land "
#                          'from my hand yet this turn. Can I still play the '
#                          'Forest as my land drop for the turn, or did the '
#                          'Swamp use up my land drop for the turn?[/Q]\n'
#                          '\n'
#                          '[A] You may still play the Forest. Putting a land '
#                          "onto the battlefield with a spell or ability doesn't "
#                          'use up your one land drop per turn.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '\n'
#                          'Each Question in my last article had a hidden '
#                          'reference to a different pop-culture pig. With ten '
#                          'different questions there were ten different pigs. '
#                          'The spoiler below has the answer key to those '
#                          'references.\n'
#                          '[spoiler]\n'
#                          "Question 1) Charlotte's Web - Wilbur the Pig and "
#                          'Charlotte the Spider\n'
#                          "Question 2) Jim Henson's Muppets - Miss Piggy, "
#                          'Kermit the Frog, and Fozzie Bear.\n'
#                          'Question 3) The Three Little Pigs and the Big Bad '
#                          'Wolf\n'
#                          'Question 4) Angry Birds Video Game (Birds vs Pigs)\n'
#                          'Question 5) Looney Tunes - Bugs Bunny, Porky Pig, '
#                          'and Daffy Duck\n'
#                          'Question 6) Babe the 1995 Movie - Babe the Pig, '
#                          'Sheep for Babe to herd, and Farmer Arthur Hoggett\n'
#                          'Question 7) Legend of Zelda - Link an Elf Warrior, '
#                          'Zelda an Elf Noble, and Ganon (pig form of '
#                          'Ganondorf)\n'
#                          'Question 8) The Lion King - Timon the Meerkat, '
#                          'Pumbaa the Warthog, and some Hyenas for them to '
#                          'fight.\n'
#                          'Question 9) Toy Story - Woody the Cowboy, Buzz the '
#                          'Spaceman, Rex the T-Rex, and Hamm the Piggy Bank.\n'
#                          'Question 10) Winnie the Pooh - Pooh the Bear, Tigger '
#                          'the Tiger, and Piglet the Pig.[/spoiler]\n'
#                          '\n'
#                          '- Justin Hovdenes AKA Hovey\n'
#                          'Level 2 Magic Judge\n'
#                          'Rapid City, SD',
#          'article_title': 'All in Jeopardy'},
#   'fr': {'article_date': '03/31/2025',
#          'article_edit_link': 'https://www.cranial-insertion.com/staff/articles/4379/edit',
#          'article_id': '4379',
#          'article_link': 'https://www.cranial-insertion.com/article/4379',
#          'article_text': '[cright=Living Death]"Alex, la réponse est\n'
#                          '“Quel serait un bon exemple d’oxymore '
#                          '?”[/cright]Aujourd’hui nous avons une collection de '
#                          'questions trouvées sur le salon de chat IRC '
#                          '#magicjudges-rules et le groupe Facebook “Ask the '
#                          'Judge - Magic: The Gathering Rules and Policy '
#                          'Questions”. N’hésitez pas à rejoindre ces espaces.\n'
#                          '\n'
#                          'Si vous avez une question [b]Magic[/b] qui vous '
#                          'turlupine, vous pouvez nous l’envoyer. Nous '
#                          'pourrions même l’utiliser dans un futur article. Si '
#                          'vous avez une question courte, vous pouvez l’envoyer '
#                          'à [email]moko@cranialinsertion.com[/email].\n'
#                          '\n'
#                          '(NDLT : Jeopardy est un jeu télévisé américain où on '
#                          'nous donne une réponse, et on doit trouver la '
#                          "question dont c'est la réponse.)\n"
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Je contrôle deux [c=Squire]Écuyers[/c] sur '
#                          'le champ de bataille et j’ai [c=Custodi '
#                          "Soulbinders]Lieurs d'âme des Custodi[/c] et 4 copies "
#                          'd’[c=Bear Cub]Ourson[/c] dans mon cimetière. Si je '
#                          'lance [c=Living Death]Mort vivante[/c], avec combien '
#                          'de marqueurs +1/+1 arrivent les Lieurs sur le champ '
#                          'de bataille ?[/Q]\n'
#                          '\n'
#                          "[A=R :] Lieurs d'âme des Custodi arrivera avec zéro "
#                          'marqueur +1/+1. Ton Lieurs et tes Oursons vont '
#                          'arriver simultanément. La première capacité de '
#                          'Lieurs génère un effet de remplacement, qui vérifie '
#                          'combien de créatures sont sur le champ de bataille '
#                          'juste avant qu’ils arrive. À ce moment-là il n’y a '
#                          'aucune créature sur le champ de bataille, donc il ne '
#                          'reçoit aucun marqueur en arrivant.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Mon commandant est [c=Grimgrin, '
#                          'Corpse-Born]Grimgrin, né des cadavres[/c]. Grimgrin '
#                          'a été [c=Murder]Homicidé[/c] au dernier tour et j’ai '
#                          'choisi de le mettre dans la zone de commandement. Je '
#                          'contrôle [c=Rooftop Storm]Orage sur le toit[/c]. Si '
#                          'je tente de lancer Grimgrin depuis la zone de '
#                          'commandement, coûtera-t-il [m]2[/m] ou sera-t-il '
#                          'gratuit ?[/Q]\n'
#                          '\n'
#                          '[A=R :] Il coûtera [m]2[/m].\n'
#                          'La “taxe de commandant” est un coût additionnel qui '
#                          'est payé en plus du coût normal de lancement de ton '
#                          'commandant. Orage sur le toit te donne l’option de '
#                          'remplacer le coût normal de lancement de tes zombies '
#                          'par [m]0[/m]. Cela n’a aucun effet sur les coûts '
#                          'additionnels.  [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Mon adversaire a exilé [c=Wheel of Fate]Roue '
#                          'du destin[/c] avec [c=Reckless Impulse]Impulsion '
#                          'téméraire[/c]. Elle prétend qu’elle peut lancer Roue '
#                          'du destin parce qu’elle est en exil. Est-ce vrai '
#                          '?[/Q]\n'
#                          '\n'
#                          '[A=R :] Ton adversaire a tort. La partie de la '
#                          'suspension qui te permet de lancer une carte qui n’a '
#                          'pas de coût de mana n’est pas le fait que tu lances '
#                          'depuis l’exil, c’est la partie qui te fait lancer un '
#                          'sort sans payer son coût de mana qui le permet.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Je contrôle quatre [c=Bear Cub]Oursons[/c], '
#                          '[c=Agrus Kos, Eternal Soldier]Agrus Kos, soldat '
#                          'éternel[/c], et [c=Thundering Raiju]Raiju '
#                          'fulminant[/c]. Aucune de mes créatures n’est '
#                          'actuellement modifiée. J’attaque avec le Raiju et je '
#                          'cible Argus avec son déclenchement à l’attaque. '
#                          'Quand la capacité d’Agrus se déclenche car il a été '
#                          'ciblé, je paye le coût. Après que toutes les '
#                          'capacités déclenchées se soient résolues, combien de '
#                          'blessures le Raiju a-t-il infligées à chaque '
#                          'adversaire ?[/Q]\n'
#                          '\n'
#                          '[A=R :] La réponse est “entre 15 et 19 blessures”, '
#                          'cela dépend du moment où tu fais se résoudre la '
#                          'capacité déclenchée qui cible le Raiju lui-même.\n'
#                          '\n'
#                          'Quand la capacité d’Agrus se résout, elle crée 5 '
#                          'copies de la capacité du Raiju (une pour chaque '
#                          'Ourson et une pour le Raiju). Ce qui fait un total '
#                          'de 6 déclenchements du Raiju. Le dernier à se '
#                          'résoudre sera celui qui cible Argus, mais les 5 '
#                          'autres se résolvent dans l’ordre de ton choix.\n'
#                          '\n'
#                          'Pour notre premier exemple, on va faire se résoudre '
#                          'le déclenchement ciblant le Raiju en premier, puis '
#                          'les quatre ciblant les Oursons, et finalement celui '
#                          'ciblant Agrus.\n'
#                          '\n'
#                          'Raiju gagne un marqueur +1/+1, aucune blessure n’est '
#                          'infligée car le Raiju ne compte que les créatures '
#                          'modifiées autres que lui-même. Blessures totales : '
#                          '0.\n'
#                          'Ours #1 gagne un marqueur  +1/+1, 1 blessure est '
#                          'infligée (vu qu’il y a une seule créature modifiée '
#                          'autre que le Raiju). Blessures totales : 1.\n'
#                          'Ours #2 gagne un marqueur +1/+1, 2 blessures sont '
#                          'infligées (vu qu’il y a maintenant 2 créatures '
#                          'modifiées). Blessures totales : 3.\n'
#                          'Ours #3 gagne un marqueur +1/+1, 3 blessures sont '
#                          'infligées (3 créatures modifiées). Blessures totales '
#                          ': 6.\n'
#                          'Ours #4 gagne un marqueur, 4 blessures sont '
#                          'infligées. Blessures totales : 10.\n'
#                          'Agrus gagne un marqueur, 5 blessures sont infligées. '
#                          'Blessures totales : 15.\n'
#                          '\n'
#                          'Maintenant, laissons d’abord se résoudre les 4 '
#                          'capacités pour les Oursons en premier, puis Raiju, '
#                          'et enfin Agrus.\n'
#                          'Ours #1, 1 blessure est infligée. Blessures totales '
#                          ': 1.\n'
#                          'Ours #2, 2 blessures sont infligées. Blessures '
#                          'totales : 3.\n'
#                          'Ours #3, 3 blessures sont infligées. Blessures '
#                          'totales : 6.\n'
#                          'Ours #4, 4 blessures sont infligées. Blessures '
#                          'totales : 10.\n'
#                          'Raiju, 4 blessures sont infligées. Blessures totales '
#                          ': 14.\n'
#                          'Agrus, 5 blessures sont infligées. Blessures totales '
#                          ': 19.\n'
#                          '\n'
#                          'Plus le déclenchement ciblant le Raiju se résout '
#                          'tard, plus il y a de blessures au total.\n'
#                          ' [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          "[cleft=Grafdigger's Cage]Alex, la réponse est "
#                          '“Qu’utilise-t-on\n'
#                          'pour empêcher les morts de s’échapper de leur tombe '
#                          "?”[/cleft][Q=Q :] La [c=Grafdigger's Cage]Cage du "
#                          'fossoyeur de graf[/c] empêche-t-elle [c=Abhorrent '
#                          'Oculus]Oculus abject[/c]  de manifester l’effroi '
#                          '?[/Q]\n'
#                          '\n'
#                          '[A=R :] De la façon qui importe le plus, oui. On '
#                          'considère toujours que le joueur a “manifesté '
#                          'l’effroi”, mais certaines parties de l’action ne '
#                          'peuvent pas être complétées. Manifester l’effroi '
#                          'signifie “Regardez les deux cartes du dessus de '
#                          'votre bibliothèque. Manifestez l’une des deux, puis '
#                          'mettez toutes les cartes regardées qui n’ont pas été '
#                          'manifestées de cette façon dans votre cimetière”. Vu '
#                          'que tu ne peux pas mettre une créature de ta '
#                          'bibliothèque en jeu, les deux cartes regardées sont '
#                          'mises dans le cimetière.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Au dernier tour, mon adversaire a pris le '
#                          'contrôle de mon [c=Bear Cub]Ourson[/c] en lançant '
#                          '[c=Sower of Temptation]Semeuse de tentation[/c]. Je '
#                          'lance [c=Ovinize]Ovinisation[/c] en ciblant la '
#                          'Semeuse pour qu’elle perde toutes ses capacités et '
#                          'que je puisse ainsi récupérer mon Ourson. Mon '
#                          'adversaire me dit que ça ne marche pas. Est-ce vrai '
#                          '? [/Q]\n'
#                          '\n'
#                          '[A=R :] Ton adversaire a raison : retirer sa '
#                          'capacité d’arrivée sur le champ de bataille à la '
#                          'Semeuse après qu’elle s’est résolue ne l’empêche pas '
#                          'de fonctionner.\n'
#                          '\n'
#                          'En espérant que cela aide, voici un exemple d’une '
#                          'situation comparable, peut-être un peu plus '
#                          'intuitive : mon adversaire utilise [c=Rootwater '
#                          'Matriarch]Matriarche de Souchemer[/c] pour prendre '
#                          'le contrôle de mon [c=Hill Giant]Géant des '
#                          'collines[/c] enchanté par [c=Spirit Link]Liaison '
#                          'psychique[/c]. Tuer la Matriarche ne fera pas '
#                          'revenir le Géant sous mon contrôle même si cela '
#                          'détruit effectivement la source de la capacité qui a '
#                          'permis à mon adversaire de me la voler, car la durée '
#                          'de l’effet de changement de contrôle dépend du fait '
#                          'que le Géant soit enchanté ou non. \n'
#                          '\n'
#                          'Pour conclure sur la question d’origine, si tu '
#                          'souhaites récupérer ton Ourson, la seule solution '
#                          'dont tu disposes est de satisfaire la condition '
#                          'décrite dans la capacité déclenchée de la Semeuse : '
#                          'la retirer du champ de bataille.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] En reprenant la situation précédente, et si, '
#                          'au lieu d’utiliser [c=Ovinize]Ovinisation[/c] sur '
#                          '[c=Sower of Temptation]Semeuse de tentation[/c], je '
#                          'la faisais passer hors-phase avec [c=Reality '
#                          'Ripple]Ride de réalité[/c] ?[/Q]\n'
#                          '\n'
#                          '[A=R :] Tu regagnerais le contrôle de ta créature. '
#                          'En effet, si une créature passe hors-phase, elle '
#                          'n’est plus sur le champ de bataille. La condition de '
#                          'durée de l’effet de la Semeuse n’est plus satisfaite '
#                          'et sa capacité ne s’applique donc plus.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Je bloque l’[c=Bear Cub]Ourson[/c] de mon '
#                          'adversaire avec [c=Manor Gargoyle]Gargouille de '
#                          'manoir[/c]. Après la fin du combat, elle lance '
#                          '[c=Disfigure]Défiguration[/c] en ciblant ma '
#                          'Gargouille. Cette dernière est-elle détruite ?[/Q]\n'
#                          '\n'
#                          '[A=R :]Non, elle survit. Comme cela peut arriver à '
#                          'beaucoup de personnes qui commencent à jouer à '
#                          'Magic, ton adversaire pense sans doute que les '
#                          'blessures infligées aux créatures réduisent leur '
#                          'endurance mais ce n’est pas le cas. Dans ta '
#                          'situation, tu finis avec une Gargouille 2/2 qui a '
#                          'deux blessures sur elle, mais comme elle est '
#                          'indestructible, l’action basée sur un état qui '
#                          'cherche à la détruire car elle a un nombre de '
#                          'blessures égal à son endurance, ne fait rien. En fin '
#                          'de compte, si ton adversaire veut se débarrasser de '
#                          'ta Gargouille, elle devra trouver [c=Dismember]un '
#                          'moyen de réduire davantage son endurance[/c], ou de '
#                          'te [c=Diabolic Edict]forcer à la sacrifier[/c].[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] [c=Ragavan, Nimble Pilferer]Ragavan, habile '
#                          'chapardeur[/c] est mon commandant. Puis-je le lancer '
#                          'pour son coût de précipitation depuis la zone de '
#                          'commandement ?[/Q]\n'
#                          '\n'
#                          '[A=R :] Tout à fait. Le coût de précipitation d’une '
#                          'carte peut être payé de n’importe quelle zone depuis '
#                          'laquelle tu es normalement autorisée à lancer cette '
#                          'carte.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Pour approfondir la question précédente : '
#                          'dois-je payer la taxe de commandant si je lance mon '
#                          'commandant avec la précipitation ?[/Q]\n'
#                          '\n'
#                          '[A=R :] Oui : la taxe de commandant fonctionnera '
#                          'normalement. Ainsi, si tu souhaites lancer Ragavan '
#                          'une deuxième fois depuis la zone de commandement '
#                          'pour son coût de précipitation, cela te coûtera '
#                          '[m]3[/m][m]R[/m]. Une troisième fois dans les mêmes '
#                          'circonstances te coûtera [m]5[/m][m]R[/m] et ainsi '
#                          'de suite.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] J’ai 8 cartes en main. Je passe en étape de '
#                          'nettoyage et me défausse d’un [c=Blazing '
#                          'Rootwalla]Agame brûlant[/c] pour atteindre ma taille '
#                          'maximum de main. Puis-je alors lancer mon Agame, '
#                          'bien qu’on soit dans l’étape de nettoyage ?[/Q]\n'
#                          '\n'
#                          '[A=R :] Parfaitement. Il est vrai que la plupart du '
#                          'temps, personne n’acquiert la priorité pendant '
#                          'l’étape de nettoyage ; cependant, si une capacité se '
#                          'déclenche pendant cette étape, ou qu’une action '
#                          'basée sur un état est vérifiée à cet instant, alors '
#                          'le joueur ou la joueuse dont c’est le tour acquiert '
#                          'la priorité et peut en profiter pour lancer des '
#                          'sorts et/ou activer des capacités. \n'
#                          'La folie étant, en partie, une capacité déclenchée, '
#                          'elle peut rejoindre la pile même pendant l’étape de '
#                          'nettoyage et te permettre, à sa résolution, de '
#                          'lancer éventuellement ta carte.\n'
#                          'Si tu fais ainsi, ta carte rejoindra la pile et ton '
#                          'adversaire acquerra la priorité comme à '
#                          'l’accoutumée. Une fois ton sort complètement résolu '
#                          'et que toi et ton adversaire avez passé la priorité '
#                          'alors que la pile est vide, une nouvelle étape de '
#                          'nettoyage commencera. Ce n’est qu’une fois qu’une '
#                          'étape de nettoyage se terminera sans que personne '
#                          'n’acquiert la priorité que l’on passera '
#                          'immédiatement au début du tour suivant.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] En résolvant [c=Burning Inquiry]Requête '
#                          'brûlante[/c], j’ai défaussé [c=Basking '
#                          'Rootwalla]Agame pèlerin[/c] et deux '
#                          '[c=Mountain]Montagne[/c]s. Mon adversaire contrôle '
#                          '[c=Rest in Peace]Repose en paix[/c] et me dit que je '
#                          'ne peux pas lancer l’Agame pour son coût de folie '
#                          'car il a été exilé par Repose en paix au moment où '
#                          'je m’en suis défaussée. Est-ce vrai ?[/Q]\n'
#                          '\n'
#                          '[A=R :] Non, ton adversaire fait une erreur et tu '
#                          'peux parfaitement lancer ton Agame pour son coût de '
#                          'folie. En effet, il est important de comprendre que '
#                          'si une carte avec la folie a été défaussée dans ta '
#                          'situation, tu pourras toujours l’exiler avec la '
#                          'folie au lieu de la mettre dans ton cimetière. Ce '
#                          'n’est qu’à partir de cet instant que, la prochaine '
#                          'fois que toi ou ton adversaire devrez acquérir la '
#                          'priorité, une capacité déclenchée autorisant à '
#                          'lancer la carte pour son coût de folie va rejoindre '
#                          'la pile. Si la carte n’est pas lancée à la '
#                          'résolution de cette capacité alors, à ce moment-là, '
#                          'elle sera exilée par Repose en paix.[/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Mon adversaire paie [m]3[/m][m]U[/m] pour '
#                          "atteindre le Niveau 2 de son [c=Stormchaser's "
#                          "Talent]Talent du chassorage[/c]. Avant qu'il ne "
#                          'devienne Niveau 2, je le renvoie dans sa main avec '
#                          '[c=Boomerang]Boomerang[/c]. Mon adversaire affirme '
#                          "qu'il peut quand même renvoyer un éphémère ou un "
#                          'rituel dans sa main, mais moi, je dis que non. Qui a '
#                          'raison ? [/Q]\n'
#                          '\n'
#                          '[A=R :] Tu as raison, il ne le peut pas. Gagner un '
#                          'Niveau est une capacité qui utilise la pile et à '
#                          'laquelle on peut répondre. La capacité de Niveau 2 '
#                          'de Stormchaser est une capacité déclenchée qui se '
#                          'déclenche lorsque la carte atteint le Niveau 2 et '
#                          'n’a lieu qu’après qu’elle soit devenue Niveau 2. Si '
#                          "elle n'est plus sur le champ de bataille lorsque sa "
#                          'capacité de Niveau 2 devrait se résoudre, alors il '
#                          'n’y a ni capacité à déclencher ni permanent pour '
#                          'devenir Niveau 2. [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[cright=Bear Cub]Alex la réponse est "Quel est\n'
#                          'l’autre nom de l’ourson Paddington ?"[/cright][Q=Q '
#                          ":] J'ai enchanté l'[c=Bear Cub]Ourson[/c] de mon "
#                          'adversaire avec [c=Sigil of Sleep]Sceau du '
#                          "Sommeil[/c]. Si l'Ourson attaque et n'est pas "
#                          'bloqué, qui choisit quelle créature que je contrôle '
#                          'est renvoyée dans la main de son propriétaire ? '
#                          '[/Q]\n'
#                          '\n'
#                          "[A=R :] C'est toi qui choisis, car tu contrôles le "
#                          'Sceau du Sommeil. [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          "[Q=Q :] J'attaque avec [c=Geist of Saint Traft]Geist "
#                          'de Saint Traft[/c] alors que je contrôle [c=Anointed '
#                          'Procession]Procession consécratrice[/c]. À la fin du '
#                          'combat, les deux jetons Ange sont-ils exilés ou '
#                          'puis-je en garder un ? [/Q]\n'
#                          '\n'
#                          '[A=R :] Les deux sont exilés. La capacité déclenchée '
#                          'de Saint Traft a bien créé les deux jetons et les '
#                          'suit pour les exiler à la fin du combat. Procession '
#                          'consécratrice ne crée pas de jetons, elle se '
#                          'contente de modifier combien de jetons sont créés '
#                          "par d'autres cartes et capacités. [/A]\n"
#                          '\n'
#                          '[hr]\n'
#                          "[Q=Q :] J'attaque avec [c=Geist of Saint Traft]Geist "
#                          'de Saint Traft[/c], mais avant l’étape des '
#                          'bloqueurs, je lance [c=Eyes in the Skies]Yeux des '
#                          'cieux[/c] en choisissant de peupler le jeton Ange. À '
#                          'la fin du combat, les deux jetons Ange sont-ils '
#                          'exilés, ou puis-je en garder un ? [/Q]\n'
#                          '\n'
#                          '[A=R :] Tu peux garder celui créé par Yeux des '
#                          'cieux. Contrairement à Procession consécratrice dans '
#                          'la question précédente, Yeux des cieux crée '
#                          "directement un jeton, qui n'a donc aucun lien avec "
#                          'la capacité qui a créé le premier jeton Ange. Cela '
#                          "signifie aussi que ce deuxième Ange n'est pas "
#                          "attaquant, n'est pas engagé et ne sera pas exilé à "
#                          'la fin du combat. [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Je ne comprends pas contre quoi [c=Emrakul, '
#                          'the World Anew]Emrakul, le Monde Renouvelé[/c] a la '
#                          'protection. Pouvez-vous clarifier cela ? [/Q]\n'
#                          '\n'
#                          '[A=R :] Emrakul a la protection contre les sorts et '
#                          'les permanents lancés "ce tour-ci". "Ce tour-ci" '
#                          'fait toujours référence au tour en cours, même si '
#                          "plusieurs tours se sont écoulés depuis qu'Emrakul a "
#                          'été lancée.\n'
#                          '\n'
#                          'Par exemple, si je lance [c=Visara the '
#                          'Dreadful]Visara la redoutable[/c] et que je l’équipe '
#                          "de [c=Lightning Greaves]Jambières d'éclair[/c] "
#                          'durant le même tour, elle ne pourra pas cibler et '
#                          'détruire Emrakul ce tour-là. Cependant, si on passe '
#                          'au tour de mon adversaire, Visara pourra alors tuer '
#                          "Emrakul, car ce n'est plus le tour où Visara a été "
#                          "lancée. Si j'utilise [c=Goryo's Vengeance]Vengeance "
#                          'selon Goryo[/c] pour réanimer Visara, alors elle '
#                          "pourra tuer Emrakul immédiatement, car Visara n'a "
#                          'pas été lancée, elle a juste été remise en jeu.\n'
#                          '\n'
#                          "La protection d'Emrakul fonctionne un peu comme une "
#                          'Protection contre les éphémères et les rituels. La '
#                          'plupart des éphémères et des rituels ne font leurs '
#                          'trucs que pendant le tour où ils sont lancés. '
#                          "Cependant, si un éphémère ou un rituel n'a pas été "
#                          'lancé (par exemple une copie), alors il pourra '
#                          "toujours cibler Emrakul. Par exemple, l'original de "
#                          '[c=Temporal Fissure]Fissure temporelle[/c] ne pourra '
#                          "pas la cibler, mais l'une de ses copies créées par "
#                          'le déluge le pourra.\n'
#                          '\n'
#                          "La protection d'Emrakul fonctionne aussi comme une "
#                          "Protection contre les auras. Lorsqu'une aura est "
#                          "lancée, elle cible ce qu'elle va enchanter. Donc "
#                          'Emrakul est protégée contre la plupart des auras. '
#                          'Cependant, une aura déjà en jeu peut être déplacée '
#                          'plus tard pour enchanter Emrakul. Par exemple, on '
#                          'peut déplacer le [c=Pacifism]Pacifisme[/c] d’un '
#                          'jeton gobelin 1/1 vers Emrakul en utilisant [c=Crown '
#                          'of the Ages]Couronne des temps anciens[/c]. [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Je lance [c=Season of Weaving]Saison du '
#                          'tissage[/c] en choisissant le mode à deux pattes '
#                          '(pour copier mon [c=Arcanis the Omnipotent]Arcanis '
#                          "l'Omnipotent[/c]) et le mode à trois pattes. "
#                          'Devrai-je mettre un des Arcanis dans mon cimetière à '
#                          'cause de la règle des légendes avant de renvoyer en '
#                          'main tous les permanents non-terrain et non-jeton ? '
#                          '[/Q]\n'
#                          '\n'
#                          '[A=R :] Non, et tu ne peux pas. La règle des '
#                          'légendes est une action basée sur un état. Elle '
#                          "n'est jamais vérifiée au milieu de la résolution "
#                          "d'un sort. Tu renverras l’Arcanis original dans ta "
#                          'main avant que Saison du tissage ne se résolve '
#                          "complètement. La règle des légendes n'entre pas en "
#                          'jeu dans cette situation. [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Je lance [c=Righteous Confluence]Confluence '
#                          'vertueuse[/c] en choisissant le deuxième mode une '
#                          'fois (pour exiler la [c=Leyline of Sanctity]Ligne '
#                          'ley de vertu[/c] de mon adversaire) et le troisième '
#                          'mode deux fois (pour gagner un total de 10 points de '
#                          'vie). Mon adversaire répond en renvoyant la Leyline '
#                          'dans sa main avec [c]Boomerang[/c]. Vais-je gagner '
#                          'quand même 10 points de vie ? [/Q]\n'
#                          '\n'
#                          "[A=R :] Non. Confluence vertueuse n'avait qu'une "
#                          'seule cible (Ligne ley de vertu), et cette cible a '
#                          'disparu. Si un sort perd toutes ses cibles avant de '
#                          'se résoudre, il est contrecarré par les règles du '
#                          'jeu et aucun de ses effets ne se produit. [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '[Q=Q :] Je viens de lancer [c=Cultivate]Culture[/c], '
#                          'mettant un [c=Swamp]Marais[/c] sur le champ de '
#                          'bataille et une [c=Forest]Forêt[/c] dans ma main. Je '
#                          "n'ai pas encore joué de terrain depuis ma main ce "
#                          'tour-ci. Puis-je toujours jouer la Forêt comme '
#                          'terrain de mon tour, ou bien le Marais a-t-il déjà '
#                          'compté pour mon terrain du tour ? [/Q]\n'
#                          '\n'
#                          '[A=R :] Tu peux quand même jouer la Forêt. Mettre un '
#                          'terrain sur le champ de bataille grâce à un sort ou '
#                          'une capacité ne compte pas comme ton terrain joué '
#                          'pour le tour. [/A]\n'
#                          '\n'
#                          '[hr]\n'
#                          '\n'
#                          'Chaque question de mon dernier article contenait une '
#                          'référence cachée à un cochon issu de la pop culture. '
#                          'Avec 10 questions différentes, il y avait donc 10 '
#                          'cochons différents. Le spoiler ci-dessous contient '
#                          'la clé de ces références.\n'
#                          '\n'
#                          '[spoiler]\n'
#                          'Question 1) Charlotte’s Web – Wilbur le cochon & '
#                          'Charlotte l’araignée\n'
#                          'Question 2) Les Muppets de Jim Henson – Miss Piggy, '
#                          'Kermit la grenouille, Fozzie l’ours\n'
#                          'Question 3) Les Trois Petits Cochons et le Grand '
#                          'Méchant Loup\n'
#                          'Question 4) Angry Birds (le jeu vidéo : oiseaux '
#                          'contre cochons)\n'
#                          'Question 5) Looney Tunes – Bugs Bunny, Porky Pig et '
#                          'Daffy Duck\n'
#                          'Question 6) Babe (film de 1995) – Babe le cochon, '
#                          'les moutons qu’il garde, et le fermier Arthur '
#                          'Hoggett\n'
#                          'Question 7) The Legend of Zelda – Link le guerrier '
#                          'elfe, Zelda la noble elfe, et Ganon (forme porcine '
#                          'de Ganondorf)\n'
#                          'Question 8) Le Roi Lion – Timon le suricate, Pumbaa '
#                          'le phacochère, et quelques hyènes à combattre\n'
#                          'Question 9) Toy Story – Woody le cow-boy, Buzz '
#                          'l’astronaute, Rex le T-Rex & Bayonne (Hamm) la '
#                          'tirelire-cochon\n'
#                          'Question 10) Winnie l’Ourson – Winnie l’ourson, '
#                          'Tigrou le tigre, et Porcinet le cochon\n'
#                          '[/spoiler]\n'
#                          '\n'
#                          '\n'
#                          '- Justin Hovdenes AKA Hovey\n'
#                          'Level 2 Magic Judge\n'
#                          'Rapid City, SD',
#          'article_title': 'Comme sur Jeopardy'}}]

# %% [markdown]
# Let's split the raw text by `[a]`or `[A]` or `[q]` or `[Q]` tags, to group them by questions/answers , one at a time:

# %%
from IPython.display import display, Markdown
def print_markdown(text):
    display(Markdown(text))

print_markdown("# Example of a raw content in English:")
print_markdown(content_articles[0]['en']['article_text'][:1000])

print_markdown("# Example of a raw content in French:")
print_markdown(content_articles[0]['fr']['article_text'][:1000])
# Out:
# # Example of a raw content in English:
# [cright=Living Death]"Alex, the answer is "What would be an
# example of an oximoron?"[/cright]
#
# Today we have a collection of questions found on the IRC Chatroom #magicjudges-rules and the Facebook group Ask the Judge - [b]Magic[/b]: The Gathering Rules and Policy Questions. Feel free to join us in either or both groups.
#
# If you have any [b]Magic[/b] questions burning at the back of your brain, you can send them to us. We may even use them in a future article. If you have a short question, you can send it to us via our Twitter account at [url=https://twitter.com/CranialTweet]@CranialTweet[/url], and you can send us longer questions at [email]moko@cranialinsertion.com[/email].
#
# [hr]
# [Q] I have two [c]Squire[/c]s on the battlefield and I have [c]Custodi Soulbinders[/c] and four copies of [c]Bear Cub[/c] in my graveyard. If I cast [c]Living Death[/c], how many +1/+1 counters will Soulbinders enter with?[/Q]
#
# [A] Custodi Soulbinders will enter with zero +1/+1 counters. Souldbinders and the
# # Example of a raw content in French:
# [cright=Living Death]"Alex, la réponse est
# “Quel serait un bon exemple d’oxymore ?”[/cright]Aujourd’hui nous avons une collection de questions trouvées sur le salon de chat IRC #magicjudges-rules et le groupe Facebook “Ask the Judge - Magic: The Gathering Rules and Policy Questions”. N’hésitez pas à rejoindre ces espaces.
#
# Si vous avez une question [b]Magic[/b] qui vous turlupine, vous pouvez nous l’envoyer. Nous pourrions même l’utiliser dans un futur article. Si vous avez une question courte, vous pouvez l’envoyer à [email]moko@cranialinsertion.com[/email].
#
# (NDLT : Jeopardy est un jeu télévisé américain où on nous donne une réponse, et on doit trouver la question dont c'est la réponse.)
#
# [hr]
# [Q=Q :] Je contrôle deux [c=Squire]Écuyers[/c] sur le champ de bataille et j’ai [c=Custodi Soulbinders]Lieurs d'âme des Custodi[/c] et 4 copies d’[c=Bear Cub]Ourson[/c] dans mon cimetière. Si je lance [c=Living Death]Mort vivante[/c], avec combien de marqueurs +1/+1 arrivent les Lieurs sur le c

# %% [markdown]
# ### Now a difficult task: split the article content by sentences / paragraphs, and group them by pairs of correponding translated text
#
# I'm trying but it seems to be so hard...

# %%
# prompt: I have the content of a long text file in « content_article['en']['article_text'] » for the English version, and in « content_article['fr']['article_text'] » for the translated French version.
# I want to split both of these long text by sentences or paragraphs, but while being certain than each piece of the French text is associated with its corresponding piece in the English text.

import re

def split_text(text):
    # Split by sentence boundaries, handling various punctuation and abbreviations.
    # This regex is a basic example and might need refinement for specific cases.
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?|\!)\s', text)
    return [s for s in sentences if s]

# Split the English and French texts into sentences
english_sentences = split_text(content_articles[0]['en']['article_text'])
french_sentences = split_text(content_articles[0]['fr']['article_text'])

# Pair the sentences.  A more robust approach would handle differences in length.
paired_sentences = []
min_len = min(len(english_sentences), len(french_sentences))
for i in range(min_len):
  paired_sentences.append({'en': english_sentences[i], 'fr': french_sentences[i]})

# Example usage: print all the pairs
for i in range(len(paired_sentences)):
    print(f"# Pair {i+1}:")
    print(f"- English: {paired_sentences[i]['en']}")
    print(f"- French: {paired_sentences[i]['fr']}")
    print("---")
# Out:
# # Pair 1:
# - English: [cright=Living Death]"Alex, the answer is "What would be an
# example of an oximoron?"[/cright]
#
# Today we have a collection of questions found on the IRC Chatroom #magicjudges-rules and the Facebook group Ask the Judge - [b]Magic[/b]: The Gathering Rules and Policy Questions.
# - French: [cright=Living Death]"Alex, la réponse est
# “Quel serait un bon exemple d’oxymore ?”[/cright]Aujourd’hui nous avons une collection de questions trouvées sur le salon de chat IRC #magicjudges-rules et le groupe Facebook “Ask the Judge - Magic: The Gathering Rules and Policy Questions”.
# ---
# # Pair 2:
# - English: Feel free to join us in either or both groups.
# - French: N’hésitez pas à rejoindre ces espaces.
# ---
# # Pair 3:
# - English:
# If you have any [b]Magic[/b] questions burning at the back of your brain, you can send them to us.
# - French:
# Si vous avez une question [b]Magic[/b] qui vous turlupine, vous pouvez nous l’envoyer.
# ---
# # Pair 4:
# - English: We may even use them in a future article.
# - French: Nous pourrions même l’utiliser dans un futur article.
# ---
# # Pair 5:
# - English: If you have a short question, you can send it to us via our Twitter account at [url=https://twitter.com/CranialTweet]@CranialTweet[/url], and you can send us longer questions at [email]moko@cranialinsertion.com[/email].
# - French: Si vous avez une question courte, vous pouvez l’envoyer à [email]moko@cranialinsertion.com[/email].
# ---
# # Pair 6:
# - English:
# [hr]
# [Q] I have two [c]Squire[/c]s on the battlefield and I have [c]Custodi Soulbinders[/c] and four copies of [c]Bear Cub[/c] in my graveyard.
# - French:
# (NDLT : Jeopardy est un jeu télévisé américain où on nous donne une réponse, et on doit trouver la question dont c'est la réponse.)
#
# [hr]
# [Q=Q :] Je contrôle deux [c=Squire]Écuyers[/c] sur le champ de bataille et j’ai [c=Custodi Soulbinders]Lieurs d'âme des Custodi[/c] et 4 copies d’[c=Bear Cub]Ourson[/c] dans mon cimetière.
# ---
# # Pair 7:
# - English: If I cast [c]Living Death[/c], how many +1/+1 counters will Soulbinders enter with?[/Q]
#
# [A] Custodi Soulbinders will enter with zero +1/+1 counters.
# - French: Si je lance [c=Living Death]Mort vivante[/c], avec combien de marqueurs +1/+1 arrivent les Lieurs sur le champ de bataille ?[/Q]
#
# [A=R :] Lieurs d'âme des Custodi arrivera avec zéro marqueur +1/+1.
# ---
# # Pair 8:
# - English: Souldbinders and the Bears will enter simultaneously.
# - French: Ton Lieurs et tes Oursons vont arriver simultanément.
# ---
# # Pair 9:
# - English: Soulbinders' first ability is a replacement effect that checks to see how many creatures are on the battlefield just before it enters.
# - French: La première capacité de Lieurs génère un effet de remplacement, qui vérifie combien de créatures sont sur le champ de bataille juste avant qu’ils arrive.
# ---
# # Pair 10:
# - English: At that point there are no creatures on the board, so it gets no counters as it enters.[/A]
#
# [hr]
# [Q] My commander is [c]Grimgrin, Corpse-Born[/c].
# - French: À ce moment-là il n’y a aucune créature sur le champ de bataille, donc il ne reçoit aucun marqueur en arrivant.[/A]
#
# [hr]
# [Q=Q :] Mon commandant est [c=Grimgrin, Corpse-Born]Grimgrin, né des cadavres[/c].
# ---
# # Pair 11:
# - English: Grimgrin was [c]Murder[/c]ed last turn and I choose to move him to the command zone.
# - French: Grimgrin a été [c=Murder]Homicidé[/c] au dernier tour et j’ai choisi de le mettre dans la zone de commandement.
# ---
# # Pair 12:
# - English: I control [c]Rooftop Storm[/c].
# - French: Je contrôle [c=Rooftop Storm]Orage sur le toit[/c].
# ---
# # Pair 13:
# - English: If I try to cast Grimgrin from the command zone, will he cost [m]2[/m] or will he be free?[/Q]
#
# [A] He will cost [m]2[/m].
# - French: Si je tente de lancer Grimgrin depuis la zone de commandement, coûtera-t-il [m]2[/m] ou sera-t-il gratuit ?[/Q]
#
# [A=R :] Il coûtera [m]2[/m].
# ---
# # Pair 14:
# - English:
# Commander "tax" is an additional cost that must be paid in addition to the normal cost for casting your commander.
# - French: La “taxe de commandant” est un coût additionnel qui est payé en plus du coût normal de lancement de ton commandant.
# ---
# # Pair 15:
# - English: Rooftop Storm gives you the option of replacing the normal cost of casting your Zombies with [m]0[/m].
# - French: Orage sur le toit te donne l’option de remplacer le coût normal de lancement de tes zombies par [m]0[/m].
# ---
# # Pair 16:
# - English: This has no effect on additional costs.
# - French: Cela n’a aucun effet sur les coûts additionnels.
# ---
# # Pair 17:
# - English:  [/A]
#
# [hr]
# [Q] My opponent exiled [c]Wheel of Fate[/c] with [c]Reckless Impulse[/c].
# - French:  [/A]
#
# [hr]
# [Q=Q :] Mon adversaire a exilé [c=Wheel of Fate]Roue du destin[/c] avec [c=Reckless Impulse]Impulsion téméraire[/c].
# ---
# # Pair 18:
# - English: She now claims she can cast Wheel of Fate because it's in exile.
# - French: Elle prétend qu’elle peut lancer Roue du destin parce qu’elle est en exil.
# ---
# # Pair 19:
# - English: Is that true?[/Q]
#
# [A] Your opponent is wrong.
# - French: Est-ce vrai ?[/Q]
#
# [A=R :] Ton adversaire a tort.
# ---
# # Pair 20:
# - English: The part of suspend that lets you cast a card with no mana cost is casting it without paying its mana cost, not that it's casting it from exile.[/A]
#
# [hr]
# [Q] I control four [c]Bear Cub[/c]s, [c]Agrus Kos, Eternal Soldier[/c], and [c]Thundering Raiju[/c].
# - French: La partie de la suspension qui te permet de lancer une carte qui n’a pas de coût de mana n’est pas le fait que tu lances depuis l’exil, c’est la partie qui te fait lancer un sort sans payer son coût de mana qui le permet.[/A]
#
# [hr]
# [Q=Q :] Je contrôle quatre [c=Bear Cub]Oursons[/c], [c=Agrus Kos, Eternal Soldier]Agrus Kos, soldat éternel[/c], et [c=Thundering Raiju]Raiju fulminant[/c].
# ---
# # Pair 21:
# - English: None of my creatures are currently modified.
# - French: Aucune de mes créatures n’est actuellement modifiée.
# ---
# # Pair 22:
# - English: I attack with the Raiju and have its attack trigger target Agrus.
# - French: J’attaque avec le Raiju et je cible Argus avec son déclenchement à l’attaque.
# ---
# # Pair 23:
# - English: When Agrus's ability triggers because he became targeted, I pay the cost.
# - French: Quand la capacité d’Agrus se déclenche car il a été ciblé, je paye le coût.
# ---
# # Pair 24:
# - English: After all these triggers resolve, how much damage will Raiju deal to each opponent?[/Q]
#
# [A] The Answer is between 15-19 damage, depending on when you let the trigger targeting Raiju resolve.
# - French: Après que toutes les capacités déclenchées se soient résolues, combien de blessures le Raiju a-t-il infligées à chaque adversaire ?[/Q]
#
# [A=R :] La réponse est “entre 15 et 19 blessures”, cela dépend du moment où tu fais se résoudre la capacité déclenchée qui cible le Raiju lui-même.
# ---
# # Pair 25:
# - English:
# When Agrus's trigger resolves, it creates five copies of Raiju's trigger, one for each Bear and one for Raiju, making a total of six Raiju triggers.
# - French:
# Quand la capacité d’Agrus se résout, elle crée 5 copies de la capacité du Raiju (une pour chaque Ourson et une pour le Raiju).
# ---
# # Pair 26:
# - English: The last trigger to resolve has to be the one targeting Agrus, and the other five resolve before it in the order of your choosing.
# - French: Ce qui fait un total de 6 déclenchements du Raiju.
# ---
# # Pair 27:
# - English:
#
# For our first example, we will have the trigger targeting Raiju resolve first, then the four triggers targeting Bears, and finally the one targeting Agrus.
# - French: Le dernier à se résoudre sera celui qui cible Argus, mais les 5 autres se résolvent dans l’ordre de ton choix.
# ---
# # Pair 28:
# - English:
# Raiju gets a +1/+1 counter, no damage is dealt as Raiju only checks modified creatures other than himself.
# - French:
# Pour notre premier exemple, on va faire se résoudre le déclenchement ciblant le Raiju en premier, puis les quatre ciblant les Oursons, et finalement celui ciblant Agrus.
# ---
# # Pair 29:
# - English: Total damage 0.
# - French:
# Raiju gagne un marqueur +1/+1, aucune blessure n’est infligée car le Raiju ne compte que les créatures modifiées autres que lui-même.
# ---
# # Pair 30:
# - English: Bear #1 gets a +1/+1 counter, 1 damage is dealt as there is only one modified creature other than Raiju.
# - French: Blessures totales : 0.
# ---
# # Pair 31:
# - English: Total damage 1.
# - French: Ours #1 gagne un marqueur  +1/+1, 1 blessure est infligée (vu qu’il y a une seule créature modifiée autre que le Raiju).
# ---
# # Pair 32:
# - English: Bear #2 gets a +1/+1 counter, 2 damage is dealt as there are now two modified creatures.
# - French: Blessures totales : 1.
# ---
# # Pair 33:
# - English: Total damage 3.
# - French: Ours #2 gagne un marqueur +1/+1, 2 blessures sont infligées (vu qu’il y a maintenant 2 créatures modifiées).
# ---
# # Pair 34:
# - English: Bear #3 gets a +1/+1 counter, 3 damage is dealt.
# - French: Blessures totales : 3.
# ---
# # Pair 35:
# - English: Total damage 6.
# - French: Ours #3 gagne un marqueur +1/+1, 3 blessures sont infligées (3 créatures modifiées).
# ---
# # Pair 36:
# - English: Bear #4 gets a counter, 4 damage is dealt.
# - French: Blessures totales : 6.
# ---
# # Pair 37:
# - English: Total damage of 10.
# - French: Ours #4 gagne un marqueur, 4 blessures sont infligées.
# ---
# # Pair 38:
# - English: Agrus get a a counter, 5 damage is dealt.
# - French: Blessures totales : 10.
# ---
# # Pair 39:
# - English: Total damage of 15.
# - French: Agrus gagne un marqueur, 5 blessures sont infligées.
# ---
# # Pair 40:
# - English:
# Now let's have the four Bears' triggers resolve first, then Raiju, followed by Agrus.
# - French: Blessures totales : 15.
# ---
# # Pair 41:
# - English: Bear #1, 1 damage is dealt.
# - French:
# Maintenant, laissons d’abord se résoudre les 4 capacités pour les Oursons en premier, puis Raiju, et enfin Agrus.
# ---
# # Pair 42:
# - English: Total damage 1.
# - French: Ours #1, 1 blessure est infligée.
# ---
# # Pair 43:
# - English: Bear #2, 2 damage is dealt.
# - French: Blessures totales : 1.
# ---
# # Pair 44:
# - English: Total damage 3.
# - French: Ours #2, 2 blessures sont infligées.
# ---
# # Pair 45:
# - English: Bear #3, 3 damage id dealt.
# - French: Blessures totales : 3.
# ---
# # Pair 46:
# - English: Total damage 6.
# - French: Ours #3, 3 blessures sont infligées.
# ---
# # Pair 47:
# - English: Bear #4, 4 damage is dealt.
# - French: Blessures totales : 6.
# ---
# # Pair 48:
# - English: Total damage is 10.
# - French: Ours #4, 4 blessures sont infligées.
# ---
# # Pair 49:
# - English: Raiju, 4 damage is dealt.
# - French: Blessures totales : 10.
# ---
# # Pair 50:
# - English: Total damage is 14.
# - French: Raiju, 4 blessures sont infligées.
# ---
# # Pair 51:
# - English: Agrus, 5 damage is dealt.
# - French: Blessures totales : 14.
# ---
# # Pair 52:
# - English: Total damage is 19.
# - French: Agrus, 5 blessures sont infligées.
# ---
# # Pair 53:
# - English:
# The later the trigger targeting Raiju resolves, the more the total damage.
# - French: Blessures totales : 19.
# ---
# # Pair 54:
# - English:  [/A]
#
# [hr]
# [cleft=Grafdigger's Cage]Alex, the answer is "What is used to
# keep the dead from escaping their graves?"[/cleft][Q] Does [c]Grafdigger's Cage[/c] stop [c]Abhorrent Oculus[/c] from manifest-dreading?[/Q]
#
# [A] Well, in the important ways, yes.
# - French:
# Plus le déclenchement ciblant le Raiju se résout tard, plus il y a de blessures au total.
# ---
# # Pair 55:
# - English: They still "manifest dread", but some parts they can't complete.
# - French:  [/A]
#
# [hr]
# [cleft=Grafdigger's Cage]Alex, la réponse est “Qu’utilise-t-on
# pour empêcher les morts de s’échapper de leur tombe ?”[/cleft][Q=Q :] La [c=Grafdigger's Cage]Cage du fossoyeur de graf[/c] empêche-t-elle [c=Abhorrent Oculus]Oculus abject[/c]  de manifester l’effroi ?[/Q]
#
# [A=R :] De la façon qui importe le plus, oui.
# ---
# # Pair 56:
# - English: Manifest Dread is "Look at the top two cards of your library.
# - French: On considère toujours que le joueur a “manifesté l’effroi”, mais certaines parties de l’action ne peuvent pas être complétées.
# ---
# # Pair 57:
# - English: Manifest one of them, then put the cards you looked at that were not manifested this way into your graveyard." Since you can't put a creature from your library into play, both cards looked at are put into the graveyard.[/A]
#
# [hr]
# [Q] Last turn my opponent stole my [c]Bear Cub[/c] by casting [c]Sower of Temptation[/c].
# - French: Manifester l’effroi signifie “Regardez les deux cartes du dessus de votre bibliothèque.
# ---
# # Pair 58:
# - English: This turn I used [c]Ovinize[/c] to make the Sower lose all its abilities.
# - French: Manifestez l’une des deux, puis mettez toutes les cartes regardées qui n’ont pas été manifestées de cette façon dans votre cimetière”.
# ---
# # Pair 59:
# - English: I did this because I think I'll get my Bear Cub back, since the Sower no longer has the "steal your creature" ability.
# - French: Vu que tu ne peux pas mettre une créature de ta bibliothèque en jeu, les deux cartes regardées sont mises dans le cimetière.[/A]
#
# [hr]
# [Q=Q :] Au dernier tour, mon adversaire a pris le contrôle de mon [c=Bear Cub]Ourson[/c] en lançant [c=Sower of Temptation]Semeuse de tentation[/c].
# ---
# # Pair 60:
# - English: My opponent disagrees.
# - French: Je lance [c=Ovinize]Ovinisation[/c] en ciblant la Semeuse pour qu’elle perde toutes ses capacités et que je puisse ainsi récupérer mon Ourson.
# ---
# # Pair 61:
# - English: Who is right?[/Q]
#
# [A] Your opponent is correct.
# - French: Mon adversaire me dit que ça ne marche pas.
# ---
# # Pair 62:
# - English: Removing the enters ability (that creates an effect with a duration) after the ability has resolved, doesn't stop it from functioning.
# - French: Est-ce vrai ?
# ---
# # Pair 63:
# - English:
# If it helps, an example that seems more intuitive would be the following: My opponent used [c]Rootwater Matriarch[/c] to steel my [c]Hill Giant[/c] enchanted with [c]Spirit Link[/c].
# - French: [/Q]
#
# [A=R :] Ton adversaire a raison : retirer sa capacité d’arrivée sur le champ de bataille à la Semeuse après qu’elle s’est résolue ne l’empêche pas de fonctionner.
# ---
# # Pair 64:
# - English: Killing the Matriarch won't get the Hill Giant back, even though that removes where the steal ability came from.
# - French:
# En espérant que cela aide, voici un exemple d’une situation comparable, peut-être un peu plus intuitive : mon adversaire utilise [c=Rootwater Matriarch]Matriarche de Souchemer[/c] pour prendre le contrôle de mon [c=Hill Giant]Géant des collines[/c] enchanté par [c=Spirit Link]Liaison psychique[/c].
# ---
# # Pair 65:
# - English: The duration is based on whether or not the Hill Giant is still enchanted.
# - French: Tuer la Matriarche ne fera pas revenir le Géant sous mon contrôle même si cela détruit effectivement la source de la capacité qui a permis à mon adversaire de me la voler, car la durée de l’effet de changement de contrôle dépend du fait que le Géant soit enchanté ou non.
# ---
# # Pair 66:
# - English:
# So with the original question, removing Sower's abilities doesn't stop the steal effect.
# - French:
#
# Pour conclure sur la question d’origine, si tu souhaites récupérer ton Ourson, la seule solution dont tu disposes est de satisfaire la condition décrite dans la capacité déclenchée de la Semeuse : la retirer du champ de bataille.[/A]
#
# [hr]
# [Q=Q :] En reprenant la situation précédente, et si, au lieu d’utiliser [c=Ovinize]Ovinisation[/c] sur [c=Sower of Temptation]Semeuse de tentation[/c], je la faisais passer hors-phase avec [c=Reality Ripple]Ride de réalité[/c] ?[/Q]
#
# [A=R :] Tu regagnerais le contrôle de ta créature.
# ---
# # Pair 67:
# - English: You have to remove the Sower to gain the creature back because that ends the duration of the effect.[/A]
#
# [hr]
# [Q] So continuing with the last question, what if instead of [c]Ovinize[/c]ing the [c]Sower of Temptation[/c] I phased it out with [c]Reality Ripple[/c]?[/Q]
#
# [A] You would get your creature back.
# - French: En effet, si une créature passe hors-phase, elle n’est plus sur le champ de bataille.
# ---
# # Pair 68:
# - English: If a creature phases out, it's treated as though it's no longer on the battlefield.
# - French: La condition de durée de l’effet de la Semeuse n’est plus satisfaite et sa capacité ne s’applique donc plus.[/A]
#
# [hr]
# [Q=Q :] Je bloque l’[c=Bear Cub]Ourson[/c] de mon adversaire avec [c=Manor Gargoyle]Gargouille de manoir[/c].
# ---
# # Pair 69:
# - English: The duration of its effect has been met, so the effect ends and the stolen creature returns to its last controller, usually its owner.[/A]
#
# [hr]
# [Q] I block my opponent's attacking [c]Bear Cub[/c] with [c]Manor Gargoyle[/c].
# - French: Après la fin du combat, elle lance [c=Disfigure]Défiguration[/c] en ciblant ma Gargouille.
# ---
# # Pair 70:
# - English: After combat ends, the opponent then casts [c]Disfigure[/c] targeting my Gargoyle.
# - French: Cette dernière est-elle détruite ?[/Q]
#
# [A=R :]Non, elle survit.
# ---
# # Pair 71:
# - English: They claim they just killed my Gargoyle.
# - French: Comme cela peut arriver à beaucoup de personnes qui commencent à jouer à Magic, ton adversaire pense sans doute que les blessures infligées aux créatures réduisent leur endurance mais ce n’est pas le cas.
# ---
# # Pair 72:
# - English: Is this true?[/Q]
#
# [A] It is not true, your Gargoyle lives through this.
# - French: Dans ta situation, tu finis avec une Gargouille 2/2 qui a deux blessures sur elle, mais comme elle est indestructible, l’action basée sur un état qui cherche à la détruire car elle a un nombre de blessures égal à son endurance, ne fait rien.
# ---
# # Pair 73:
# - English: Many new players make this same wrong assumption.
# - French: En fin de compte, si ton adversaire veut se débarrasser de ta Gargouille, elle devra trouver [c=Dismember]un moyen de réduire davantage son endurance[/c], ou de te [c=Diabolic Edict]forcer à la sacrifier[/c].[/A]
#
# [hr]
# [Q=Q :] [c=Ragavan, Nimble Pilferer]Ragavan, habile chapardeur[/c] est mon commandant.
# ---
# # Pair 74:
# - English: Damage doesn't reduce toughness.
# - French: Puis-je le lancer pour son coût de précipitation depuis la zone de commandement ?[/Q]
#
# [A=R :] Tout à fait.
# ---
# # Pair 75:
# - English: You have a 2/2 Gargoyle with 2 damage marked on it.
# - French: Le coût de précipitation d’une carte peut être payé de n’importe quelle zone depuis laquelle tu es normalement autorisée à lancer cette carte.[/A]
#
# [hr]
# [Q=Q :] Pour approfondir la question précédente : dois-je payer la taxe de commandant si je lance mon commandant avec la précipitation ?[/Q]
#
# [A=R :] Oui : la taxe de commandant fonctionnera normalement.
# ---
# # Pair 76:
# - English: Because it's indestructible, the state based action that tries to destroy it for having equal or more damage than it has toughness fails to do anything.
# - French: Ainsi, si tu souhaites lancer Ragavan une deuxième fois depuis la zone de commandement pour son coût de précipitation, cela te coûtera [m]3[/m][m]R[/m].
# ---
# # Pair 77:
# - English: If they want to get your Gargoyle into the graveyard, they need to give it enough [c=Dismember]-X/-X to make its toughness 0 or less[/c], or force you to [c=Diabolic Edict]sacrifice it[/c].[/A]
#
# [hr]
# [Q] If [c]Ragavan, Nimble Pilferer[/c] is my commander, can I cast him for his dash cost from the command zone?[/Q]
#
# [A] Yes, you can.
# - French: Une troisième fois dans les mêmes circonstances te coûtera [m]5[/m][m]R[/m] et ainsi de suite.[/A]
#
# [hr]
# [Q=Q :] J’ai 8 cartes en main.
# ---
# # Pair 78:
# - English: Dash can be used from any zone, so long as you are allowed to cast that card from that same zone normally.
# - French: Je passe en étape de nettoyage et me défausse d’un [c=Blazing Rootwalla]Agame brûlant[/c] pour atteindre ma taille maximum de main.
# ---
# # Pair 79:
# - English: [/A]
#
# [hr]
# [Q] Following up with the last question, do I have to pay commander tax if I dash out my commander?[/Q]
#
# [A] Yes, you do.
# - French: Puis-je alors lancer mon Agame, bien qu’on soit dans l’étape de nettoyage ?[/Q]
#
# [A=R :] Parfaitement.
# ---
# # Pair 80:
# - English: Suppose you cast Ragavan normally on turn one, then later he died and returned to the command zone.
# - French: Il est vrai que la plupart du temps, personne n’acquiert la priorité pendant l’étape de nettoyage ; cependant, si une capacité se déclenche pendant cette étape, ou qu’une action basée sur un état est vérifiée à cet instant, alors le joueur ou la joueuse dont c’est le tour acquiert la priorité et peut en profiter pour lancer des sorts et/ou activer des capacités.
# ---
# # Pair 81:
# - English: When you go to dash him he now costs [m]3[/m][m]R[/m] to dash.
# - French:
# La folie étant, en partie, une capacité déclenchée, elle peut rejoindre la pile même pendant l’étape de nettoyage et te permettre, à sa résolution, de lancer éventuellement ta carte.
# ---
# # Pair 82:
# - English: Then if he dies again and returns to the command zone, the next time you go to cast him he costs either [m]4[/m][m]R[/m] to cast normally or [m]5[/m][m]R[/m] to dash.[/A]
#
# [hr]
# [Q] I have eight cards in my hand.
# - French: Si tu fais ainsi, ta carte rejoindra la pile et ton adversaire acquerra la priorité comme à l’accoutumée.
# ---
# # Pair 83:
# - English: I go to my cleanup step and discard [c]Blazing Rootwalla[/c] to get down to maximum hand size.
# - French: Une fois ton sort complètement résolu et que toi et ton adversaire avez passé la priorité alors que la pile est vide, une nouvelle étape de nettoyage commencera.
# ---
# # Pair 84:
# - English: Can I cast the Rootwalla even though I'm in my cleanup step?[/Q]
#
# [A] Yes, you can.
# - French: Ce n’est qu’une fois qu’une étape de nettoyage se terminera sans que personne n’acquiert la priorité que l’on passera immédiatement au début du tour suivant.[/A]
#
# [hr]
# [Q=Q :] En résolvant [c=Burning Inquiry]Requête brûlante[/c], j’ai défaussé [c=Basking Rootwalla]Agame pèlerin[/c] et deux [c=Mountain]Montagne[/c]s.
# ---
# # Pair 85:
# - English: During most cleanup steps, no players get priority.
# - French: Mon adversaire contrôle [c=Rest in Peace]Repose en paix[/c] et me dit que je ne peux pas lancer l’Agame pour son coût de folie car il a été exilé par Repose en paix au moment où je m’en suis défaussée.
# ---
# # Pair 86:
# - English: However, if an ability triggers during the cleanup step, or a state based action applies during a cleanup step, then the active player gains priority and may cast spells and activate abilities.
# - French: Est-ce vrai ?[/Q]
#
# [A=R :] Non, ton adversaire fait une erreur et tu peux parfaitement lancer ton Agame pour son coût de folie.
# ---
# # Pair 87:
# - English:
#
# This is when you can cast the Rootwalla, as discarding it to madness puts a trigger on the stack.
# - French: En effet, il est important de comprendre que si une carte avec la folie a été défaussée dans ta situation, tu pourras toujours l’exiler avec la folie au lieu de la mettre dans ton cimetière.
# ---
# # Pair 88:
# - English:
# A normal priority pass will begin from here and until all players pass in succession with an empty stack, players may add new items to the stack when they have priority.
# - French: Ce n’est qu’à partir de cet instant que, la prochaine fois que toi ou ton adversaire devrez acquérir la priorité, une capacité déclenchée autorisant à lancer la carte pour son coût de folie va rejoindre la pile.
# ---
# # Pair 89:
# - English: Once all players pass with an empty stack, this cleanup step ends and a new one begins.
# - French: Si la carte n’est pas lancée à la résolution de cette capacité alors, à ce moment-là, elle sera exilée par Repose en paix.[/A]
#
# [hr]
# [Q=Q :] Mon adversaire paie [m]3[/m][m]U[/m] pour atteindre le Niveau 2 de son [c=Stormchaser's Talent]Talent du chassorage[/c].
# ---
# # Pair 90:
# - English: If that new cleanup ends normally, then the game will move on to the next player's turn.[/A]
#
# [hr]
# [Q] While resolving [c]Burning Inquiry[/c] I discarded [c]Basking Rootwalla[/c] and two [c]Mountain[/c]s.
# - French: Avant qu'il ne devienne Niveau 2, je le renvoie dans sa main avec [c=Boomerang]Boomerang[/c].
# ---
# # Pair 91:
# - English: My opponent controls a [c]Rest in Peace[/c].
# - French: Mon adversaire affirme qu'il peut quand même renvoyer un éphémère ou un rituel dans sa main, mais moi, je dis que non.
# ---
# # Pair 92:
# - English: My opponent claims I can't cast the Rootwalla for its Madness cost as it got exiled by Rest in Peace when I discarded it.
# - French: Qui a raison ?
# ---
# # Pair 93:
# - English: Is this true?[/Q]
#
# [A] Your opponent is wrong.
# - French: [/Q]
#
# [A=R :] Tu as raison, il ne le peut pas.
# ---
# # Pair 94:
# - English: You can cast your Rootwalla for its madness cost.
# - French: Gagner un Niveau est une capacité qui utilise la pile et à laquelle on peut répondre.
# ---
# # Pair 95:
# - English: The Rootwalla hasn't been exiled by Rest in Peace yet.
# - French: La capacité de Niveau 2 de Stormchaser est une capacité déclenchée qui se déclenche lorsque la carte atteint le Niveau 2 et n’a lieu qu’après qu’elle soit devenue Niveau 2.
# ---
# # Pair 96:
# - English: This is because madness doesn't quite work the way most people think it does.
# - French: Si elle n'est plus sur le champ de bataille lorsque sa capacité de Niveau 2 devrait se résoudre, alors il n’y a ni capacité à déclencher ni permanent pour devenir Niveau 2.
# ---
# # Pair 97:
# - English: If a card with madness gets discarded, it goes to exile instead of being put into its owner's graveyard.
# - French: [/A]
#
# [hr]
# [cright=Bear Cub]Alex la réponse est "Quel est
# l’autre nom de l’ourson Paddington ?"[/cright][Q=Q :] J'ai enchanté l'[c=Bear Cub]Ourson[/c] de mon adversaire avec [c=Sigil of Sleep]Sceau du Sommeil[/c].
# ---
# # Pair 98:
# - English: Then the next time a player would get priority, a trigger allowing its owner to cast it for its madness cost is put on the stack.
# - French: Si l'Ourson attaque et n'est pas bloqué, qui choisit quelle créature que je contrôle est renvoyée dans la main de son propriétaire ?
# ---
# # Pair 99:
# - English: When this trigger resolves, the owner may cast the card, but if they don't then the card is put into their graveyard.
# - French: [/Q]
#
# [A=R :] C'est toi qui choisis, car tu contrôles le Sceau du Sommeil.
# ---
# # Pair 100:
# - English:
#
# To get back to the original question, Rest in Peace can only exile a discarded Madness card after the owner has decided not to cast it for madness and choses to let it go to the graveyard.
# - French: [/A]
#
# [hr]
# [Q=Q :] J'attaque avec [c=Geist of Saint Traft]Geist de Saint Traft[/c] alors que je contrôle [c=Anointed Procession]Procession consécratrice[/c].
# ---
# # Pair 101:
# - English: [/A]
#
# [hr]
# [Q] My opponent pays [m]3[/m][m]U[/m] to gain level 2 on their [c]Stormchaser's Talent[/c].
# - French: À la fin du combat, les deux jetons Ange sont-ils exilés ou puis-je en garder un ?
# ---
# # Pair 102:
# - English: Before it becomes level 2, I [c]Boomerang[/c] it to their hand.
# - French: [/Q]
#
# [A=R :] Les deux sont exilés.
# ---
# # Pair 103:
# - English: The opponent says they still get to return an instant or sorcery to their hand, I say they don't, who is right?[/Q]
#
# [A] You are correct, they do not.
# - French: La capacité déclenchée de Saint Traft a bien créé les deux jetons et les suit pour les exiler à la fin du combat.
# ---
# # Pair 104:
# - English: Gaining a level is an ability that uses the stack and can be responded to.
# - French: Procession consécratrice ne crée pas de jetons, elle se contente de modifier combien de jetons sont créés par d'autres cartes et capacités.
# ---
# # Pair 105:
# - English: Stormchaser's level 2 ability is a trigger that triggers upon it becoming level 2 and happens only after it becomes level 2.
# - French: [/A]
#
# [hr]
# [Q=Q :] J'attaque avec [c=Geist of Saint Traft]Geist de Saint Traft[/c], mais avant l’étape des bloqueurs, je lance [c=Eyes in the Skies]Yeux des cieux[/c] en choisissant de peupler le jeton Ange.
# ---
# # Pair 106:
# - English: If it's not on the battlefield when its level 2 ability resolves, there is no ability to trigger (nor a permanent to become level 2).
# - French: À la fin du combat, les deux jetons Ange sont-ils exilés, ou puis-je en garder un ?
# ---
# # Pair 107:
# - English: [/A]
#
# [hr]
# [cright=Bear Cub|PO2]Alex, the answer is "What is another
# name for Ursine Child?"[/cright][Q] I enchanted my opponent's [c]Bear Cub[/c] with my [c]Sigil of Sleep[/c].
# - French: [/Q]
#
# [A=R :] Tu peux garder celui créé par Yeux des cieux.
# ---
# # Pair 108:
# - English: If the Bear Cub goes unblocked attacking me, who chooses which creature I control gets returned to its owner's hand?[/Q]
#
# [A] You get to choose as you control the Sigil of Sleep.[/A]
#
# [hr]
# [Q] I attack with [c]Geist of Saint Traft[/c] while I control [c]Anointed Procession[/c].
# - French: Contrairement à Procession consécratrice dans la question précédente, Yeux des cieux crée directement un jeton, qui n'a donc aucun lien avec la capacité qui a créé le premier jeton Ange.
# ---
# # Pair 109:
# - English: When combat ends, will both Angel tokens get exiled or do I get to keep one?[/Q]
#
# [A] Both still get exiled.
# - French: Cela signifie aussi que ce deuxième Ange n'est pas attaquant, n'est pas engagé et ne sera pas exilé à la fin du combat.
# ---
# # Pair 110:
# - English: Saint Traft's triggered ability still made both tokens and tracks them to be exiled at the end of combat.
# - French: [/A]
#
# [hr]
# [Q=Q :] Je ne comprends pas contre quoi [c=Emrakul, the World Anew]Emrakul, le Monde Renouvelé[/c] a la protection.
# ---
# # Pair 111:
# - English: Procession doesn't make tokens, it just changes how many tokens other cards and abilities make.[/A]
#
# [hr]
# [Q] I attack with [c]Geist of Saint Traft[/c], but before blocks, I cast [c]Eyes in the Skies[/c] choosing to populate the Angel token.
# - French: Pouvez-vous clarifier cela ?
# ---
# # Pair 112:
# - English: When combat ends, will both Angel tokens get exiled or do I get to keep one?[/Q]
#
# [A] You get to keep the one made by Eyes in the Skies.
# - French: [/Q]
#
# [A=R :] Emrakul a la protection contre les sorts et les permanents lancés "ce tour-ci".
# ---
# # Pair 113:
# - English: Unlike Anointed Procession from the last question, Eyes in the Skies makes the token and the token has no link to the ability that made the original Angel token.
# - French: "Ce tour-ci" fait toujours référence au tour en cours, même si plusieurs tours se sont écoulés depuis qu'Emrakul a été lancée.
# ---
# # Pair 114:
# - English: This includes that the second Angel token is not attacking, is not tapped, and it won't get exiled at the end of combat.[/A]
#
# [hr]
# [Q] I don't understand what [c]Emrakul, the World Anew[/c] has protection from.
# - French:
# Par exemple, si je lance [c=Visara the Dreadful]Visara la redoutable[/c] et que je l’équipe de [c=Lightning Greaves]Jambières d'éclair[/c] durant le même tour, elle ne pourra pas cibler et détruire Emrakul ce tour-là.
# ---
# # Pair 115:
# - English: Can you clarify this?[/Q]
#
# [A] Emrakul has protection from spells and separately protection from permanents cast "this turn".
# - French: Cependant, si on passe au tour de mon adversaire, Visara pourra alors tuer Emrakul, car ce n'est plus le tour où Visara a été lancée.
# ---
# # Pair 116:
# - English: This turn is whichever turn it currently is, even if it's been many turns since Emrakul herself was cast.
# - French: Si j'utilise [c=Goryo's Vengeance]Vengeance selon Goryo[/c] pour réanimer Visara, alors elle pourra tuer Emrakul immédiatement, car Visara n'a pas été lancée, elle a juste été remise en jeu.
# ---
# # Pair 117:
# - English:
#
# So for example, if I cast [c]Visara the Dreadful[/c] and gave her some [c]Lightning Greaves[/c] the same turn I cast her, she can't target and destroy Emrakul that turn.
# - French:
# La protection d'Emrakul fonctionne un peu comme une Protection contre les éphémères et les rituels.
# ---
# # Pair 118:
# - English: However, if I pass to my opponent's turn, Visara can now kill Emrakul as it's no longer the same turn Visara was cast.
# - French: La plupart des éphémères et des rituels ne font leurs trucs que pendant le tour où ils sont lancés.
# ---
# # Pair 119:
# - English: If I used [c]Goryo's Vengeance[/c] to reanimate Visara, then Visara could kill Emrakul that same turn as Visara wasn't cast at all.
# - French: Cependant, si un éphémère ou un rituel n'a pas été lancé (par exemple une copie), alors il pourra toujours cibler Emrakul.
# ---
# # Pair 120:
# - English:
# Emrakul's protection ability acts similar to having protection from Auras.
# - French: Par exemple, l'original de [c=Temporal Fissure]Fissure temporelle[/c] ne pourra pas la cibler, mais l'une de ses copies créées par le déluge le pourra.
# ---
# # Pair 121:
# - English: Auras when cast target what they will enchant, so Emrakul is safe from most Auras.
# - French:
# La protection d'Emrakul fonctionne aussi comme une Protection contre les auras.
# ---
# # Pair 122:
# - English: However, on later turns, an Aura could be moved from its original target, to enchant Emrakul.
# - French: Lorsqu'une aura est lancée, elle cible ce qu'elle va enchanter.
# ---
# # Pair 123:
# - English: For example, you could move [c]Pacifism[/c] from a 1/1 Goblin token to Emrakul using [c]Crown of the Ages[/c].
# - French: Donc Emrakul est protégée contre la plupart des auras.
# ---
# # Pair 124:
# - English:
# [/A]
#
# [hr]
# [Q] I cast [c]Season of Weaving[/c] choosing the two paws mode (to copy my [c]Arcanis the Omnipotent[/c]) and the three paws mode.
# - French: Cependant, une aura déjà en jeu peut être déplacée plus tard pour enchanter Emrakul.
# ---
# # Pair 125:
# - English: Will I have to put one Arcanis into my graveyard due to the legend rule before bouncing all nonland and nontoken permanents?[/Q]
#
# [A] You will not and you can not.
# - French: Par exemple, on peut déplacer le [c=Pacifism]Pacifisme[/c] d’un jeton gobelin 1/1 vers Emrakul en utilisant [c=Crown of the Ages]Couronne des temps anciens[/c].
# ---
# # Pair 126:
# - English: The legend rule is a state based action.
# - French: [/A]
#
# [hr]
# [Q=Q :] Je lance [c=Season of Weaving]Saison du tissage[/c] en choisissant le mode à deux pattes (pour copier mon [c=Arcanis the Omnipotent]Arcanis l'Omnipotent[/c]) et le mode à trois pattes.
# ---
# # Pair 127:
# - English: It's never checked in the middle of resolving a spell.
# - French: Devrai-je mettre un des Arcanis dans mon cimetière à cause de la règle des légendes avant de renvoyer en main tous les permanents non-terrain et non-jeton ?
# ---
# # Pair 128:
# - English: You will put the original Arcanis into your hand before Season of Weaving fully resolves.
# - French: [/Q]
#
# [A=R :] Non, et tu ne peux pas.
# ---
# # Pair 129:
# - English: The legend rule doesn't come into play during this situation.[/A]
#
# [hr]
# [Q] If I cast [c]Righteous Confluence[/c] choosing mode two once to exile my opponent's [c]Leyline of Sanctity[/c] and mode three twice to gain 10 total life, and the opponent responds by [c]Boomerang[/c]ing the Leyline back to their hand, do I still gain 10 life?[/Q]
#
# [A] You do not.
# - French: La règle des légendes est une action basée sur un état.
# ---
# # Pair 130:
# - English: Righteous Confluence had only one target, Leyline of Sanctity, and that target has disappeared.
# - French: Elle n'est jamais vérifiée au milieu de la résolution d'un sort.
# ---
# # Pair 131:
# - English: If a spell loses all of its targets by the time it goes to resolve, it fizzles and none of its effects happen.
# - French: Tu renverras l’Arcanis original dans ta main avant que Saison du tissage ne se résolve complètement.
# ---
# # Pair 132:
# - English: [/A]
#
# [hr]
# [Q] I just cast [c]Cultivate[/c] putting a [c]Swamp[/c] onto the battlefield and a [c]Forest[/c] into my hand.
# - French: La règle des légendes n'entre pas en jeu dans cette situation.
# ---
# # Pair 133:
# - English: I haven't played a land from my hand yet this turn.
# - French: [/A]
#
# [hr]
# [Q=Q :] Je lance [c=Righteous Confluence]Confluence vertueuse[/c] en choisissant le deuxième mode une fois (pour exiler la [c=Leyline of Sanctity]Ligne ley de vertu[/c] de mon adversaire) et le troisième mode deux fois (pour gagner un total de 10 points de vie).
# ---
# # Pair 134:
# - English: Can I still play the Forest as my land drop for the turn, or did the Swamp use up my land drop for the turn?[/Q]
#
# [A] You may still play the Forest.
# - French: Mon adversaire répond en renvoyant la Leyline dans sa main avec [c]Boomerang[/c].
# ---
# # Pair 135:
# - English: Putting a land onto the battlefield with a spell or ability doesn't use up your one land drop per turn.[/A]
#
# [hr]
#
# Each Question in my last article had a hidden reference to a different pop-culture pig.
# - French: Vais-je gagner quand même 10 points de vie ?
# ---
# # Pair 136:
# - English: With ten different questions there were ten different pigs.
# - French: [/Q]
#
# [A=R :] Non.
# ---
# # Pair 137:
# - English: The spoiler below has the answer key to those references.
# - French: Confluence vertueuse n'avait qu'une seule cible (Ligne ley de vertu), et cette cible a disparu.
# ---
# # Pair 138:
# - English: [spoiler]
# Question 1) Charlotte's Web - Wilbur the Pig and Charlotte the Spider
# Question 2) Jim Henson's Muppets - Miss Piggy, Kermit the Frog, and Fozzie Bear.
# - French: Si un sort perd toutes ses cibles avant de se résoudre, il est contrecarré par les règles du jeu et aucun de ses effets ne se produit.
# ---
# # Pair 139:
# - English: Question 3) The Three Little Pigs and the Big Bad Wolf
# Question 4) Angry Birds Video Game (Birds vs Pigs)
# Question 5) Looney Tunes - Bugs Bunny, Porky Pig, and Daffy Duck
# Question 6) Babe the 1995 Movie - Babe the Pig, Sheep for Babe to herd, and Farmer Arthur Hoggett
# Question 7) Legend of Zelda - Link an Elf Warrior, Zelda an Elf Noble, and Ganon (pig form of Ganondorf)
# Question 8) The Lion King - Timon the Meerkat, Pumbaa the Warthog, and some Hyenas for them to fight.
# - French: [/A]
#
# [hr]
# [Q=Q :] Je viens de lancer [c=Cultivate]Culture[/c], mettant un [c=Swamp]Marais[/c] sur le champ de bataille et une [c=Forest]Forêt[/c] dans ma main.
# ---
# # Pair 140:
# - English: Question 9) Toy Story - Woody the Cowboy, Buzz the Spaceman, Rex the T-Rex, and Hamm the Piggy Bank.
# - French: Je n'ai pas encore joué de terrain depuis ma main ce tour-ci.
# ---
# # Pair 141:
# - English: Question 10) Winnie the Pooh - Pooh the Bear, Tigger the Tiger, and Piglet the Pig.[/spoiler]
#
# - Justin Hovdenes AKA Hovey
# Level 2 Magic Judge
# Rapid City, SD
# - French: Puis-je toujours jouer la Forêt comme terrain de mon tour, ou bien le Marais a-t-il déjà compté pour mon terrain du tour ?
# ---

# %%
all_pairs_of_paragraphs = []

for content_article in content_articles:
    pairs_of_paragraphs = []
    paragraphs_en = content_article['en']['article_text'].split('\n\n')
    paragraphs_fr = content_article['fr']['article_text'].split('\n\n')
    for i, paragraph_en in enumerate(paragraphs_en):
        paragraph_fr = paragraphs_fr[i]
        pair_of_paragraphs = {
            'en': paragraph_en,
            'fr': paragraph_fr,
        }
        pprint(pair_of_paragraphs)
        pairs_of_paragraphs.append(pair_of_paragraphs)

    all_pairs_of_paragraphs.append(pairs_of_paragraphs)
# Out:
# {'en': '[cright=Living Death]"Alex, the answer is "What would be an\n'
#        'example of an oximoron?"[/cright]',
#  'fr': '[cright=Living Death]"Alex, la réponse est\n'
#        '“Quel serait un bon exemple d’oxymore ?”[/cright]Aujourd’hui nous '
#        'avons une collection de questions trouvées sur le salon de chat IRC '
#        '#magicjudges-rules et le groupe Facebook “Ask the Judge - Magic: The '
#        'Gathering Rules and Policy Questions”. N’hésitez pas à rejoindre ces '
#        'espaces.'}
# {'en': 'Today we have a collection of questions found on the IRC Chatroom '
#        '#magicjudges-rules and the Facebook group Ask the Judge - '
#        '[b]Magic[/b]: The Gathering Rules and Policy Questions. Feel free to '
#        'join us in either or both groups.',
#  'fr': 'Si vous avez une question [b]Magic[/b] qui vous turlupine, vous pouvez '
#        'nous l’envoyer. Nous pourrions même l’utiliser dans un futur article. '
#        'Si vous avez une question courte, vous pouvez l’envoyer à '
#        '[email]moko@cranialinsertion.com[/email].'}
# {'en': 'If you have any [b]Magic[/b] questions burning at the back of your '
#        'brain, you can send them to us. We may even use them in a future '
#        'article. If you have a short question, you can send it to us via our '
#        'Twitter account at '
#        '[url=https://twitter.com/CranialTweet]@CranialTweet[/url], and you can '
#        'send us longer questions at [email]moko@cranialinsertion.com[/email].',
#  'fr': '(NDLT : Jeopardy est un jeu télévisé américain où on nous donne une '
#        "réponse, et on doit trouver la question dont c'est la réponse.)"}
# {'en': '[hr]\n'
#        '[Q] I have two [c]Squire[/c]s on the battlefield and I have [c]Custodi '
#        'Soulbinders[/c] and four copies of [c]Bear Cub[/c] in my graveyard. If '
#        'I cast [c]Living Death[/c], how many +1/+1 counters will Soulbinders '
#        'enter with?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Je contrôle deux [c=Squire]Écuyers[/c] sur le champ de '
#        "bataille et j’ai [c=Custodi Soulbinders]Lieurs d'âme des Custodi[/c] "
#        'et 4 copies d’[c=Bear Cub]Ourson[/c] dans mon cimetière. Si je lance '
#        '[c=Living Death]Mort vivante[/c], avec combien de marqueurs +1/+1 '
#        'arrivent les Lieurs sur le champ de bataille ?[/Q]'}
# {'en': '[A] Custodi Soulbinders will enter with zero +1/+1 counters. '
#        "Souldbinders and the Bears will enter simultaneously. Soulbinders' "
#        'first ability is a replacement effect that checks to see how many '
#        'creatures are on the battlefield just before it enters. At that point '
#        'there are no creatures on the board, so it gets no counters as it '
#        'enters.[/A]',
#  'fr': "[A=R :] Lieurs d'âme des Custodi arrivera avec zéro marqueur +1/+1. "
#        'Ton Lieurs et tes Oursons vont arriver simultanément. La première '
#        'capacité de Lieurs génère un effet de remplacement, qui vérifie '
#        'combien de créatures sont sur le champ de bataille juste avant qu’ils '
#        'arrive. À ce moment-là il n’y a aucune créature sur le champ de '
#        'bataille, donc il ne reçoit aucun marqueur en arrivant.[/A]'}
# {'en': '[hr]\n'
#        '[Q] My commander is [c]Grimgrin, Corpse-Born[/c]. Grimgrin was '
#        '[c]Murder[/c]ed last turn and I choose to move him to the command '
#        'zone. I control [c]Rooftop Storm[/c]. If I try to cast Grimgrin from '
#        'the command zone, will he cost [m]2[/m] or will he be free?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Mon commandant est [c=Grimgrin, Corpse-Born]Grimgrin, né des '
#        'cadavres[/c]. Grimgrin a été [c=Murder]Homicidé[/c] au dernier tour et '
#        'j’ai choisi de le mettre dans la zone de commandement. Je contrôle '
#        '[c=Rooftop Storm]Orage sur le toit[/c]. Si je tente de lancer Grimgrin '
#        'depuis la zone de commandement, coûtera-t-il [m]2[/m] ou sera-t-il '
#        'gratuit ?[/Q]'}
# {'en': '[A] He will cost [m]2[/m]. \n'
#        'Commander "tax" is an additional cost that must be paid in addition to '
#        'the normal cost for casting your commander. Rooftop Storm gives you '
#        'the option of replacing the normal cost of casting your Zombies with '
#        '[m]0[/m]. This has no effect on additional costs.  [/A]',
#  'fr': '[A=R :] Il coûtera [m]2[/m].\n'
#        'La “taxe de commandant” est un coût additionnel qui est payé en plus '
#        'du coût normal de lancement de ton commandant. Orage sur le toit te '
#        'donne l’option de remplacer le coût normal de lancement de tes zombies '
#        'par [m]0[/m]. Cela n’a aucun effet sur les coûts additionnels.  [/A]'}
# {'en': '[hr]\n'
#        '[Q] My opponent exiled [c]Wheel of Fate[/c] with [c]Reckless '
#        "Impulse[/c]. She now claims she can cast Wheel of Fate because it's in "
#        'exile. Is that true?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Mon adversaire a exilé [c=Wheel of Fate]Roue du destin[/c] '
#        'avec [c=Reckless Impulse]Impulsion téméraire[/c]. Elle prétend qu’elle '
#        'peut lancer Roue du destin parce qu’elle est en exil. Est-ce vrai '
#        '?[/Q]'}
# {'en': '[A] Your opponent is wrong. The part of suspend that lets you cast a '
#        'card with no mana cost is casting it without paying its mana cost, not '
#        "that it's casting it from exile.[/A]",
#  'fr': '[A=R :] Ton adversaire a tort. La partie de la suspension qui te '
#        'permet de lancer une carte qui n’a pas de coût de mana n’est pas le '
#        'fait que tu lances depuis l’exil, c’est la partie qui te fait lancer '
#        'un sort sans payer son coût de mana qui le permet.[/A]'}
# {'en': '[hr]\n'
#        '[Q] I control four [c]Bear Cub[/c]s, [c]Agrus Kos, Eternal '
#        'Soldier[/c], and [c]Thundering Raiju[/c]. None of my creatures are '
#        'currently modified. I attack with the Raiju and have its attack '
#        "trigger target Agrus. When Agrus's ability triggers because he became "
#        'targeted, I pay the cost. After all these triggers resolve, how much '
#        'damage will Raiju deal to each opponent?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Je contrôle quatre [c=Bear Cub]Oursons[/c], [c=Agrus Kos, '
#        'Eternal Soldier]Agrus Kos, soldat éternel[/c], et [c=Thundering '
#        'Raiju]Raiju fulminant[/c]. Aucune de mes créatures n’est actuellement '
#        'modifiée. J’attaque avec le Raiju et je cible Argus avec son '
#        'déclenchement à l’attaque. Quand la capacité d’Agrus se déclenche car '
#        'il a été ciblé, je paye le coût. Après que toutes les capacités '
#        'déclenchées se soient résolues, combien de blessures le Raiju a-t-il '
#        'infligées à chaque adversaire ?[/Q]'}
# {'en': '[A] The Answer is between 15-19 damage, depending on when you let the '
#        'trigger targeting Raiju resolve.',
#  'fr': '[A=R :] La réponse est “entre 15 et 19 blessures”, cela dépend du '
#        'moment où tu fais se résoudre la capacité déclenchée qui cible le '
#        'Raiju lui-même.'}
# {'en': "When Agrus's trigger resolves, it creates five copies of Raiju's "
#        'trigger, one for each Bear and one for Raiju, making a total of six '
#        'Raiju triggers. The last trigger to resolve has to be the one '
#        'targeting Agrus, and the other five resolve before it in the order of '
#        'your choosing. ',
#  'fr': 'Quand la capacité d’Agrus se résout, elle crée 5 copies de la capacité '
#        'du Raiju (une pour chaque Ourson et une pour le Raiju). Ce qui fait un '
#        'total de 6 déclenchements du Raiju. Le dernier à se résoudre sera '
#        'celui qui cible Argus, mais les 5 autres se résolvent dans l’ordre de '
#        'ton choix.'}
# {'en': 'For our first example, we will have the trigger targeting Raiju '
#        'resolve first, then the four triggers targeting Bears, and finally the '
#        'one targeting Agrus.',
#  'fr': 'Pour notre premier exemple, on va faire se résoudre le déclenchement '
#        'ciblant le Raiju en premier, puis les quatre ciblant les Oursons, et '
#        'finalement celui ciblant Agrus.'}
# {'en': 'Raiju gets a +1/+1 counter, no damage is dealt as Raiju only checks '
#        'modified creatures other than himself. Total damage 0.\n'
#        'Bear #1 gets a +1/+1 counter, 1 damage is dealt as there is only one '
#        'modified creature other than Raiju. Total damage 1.\n'
#        'Bear #2 gets a +1/+1 counter, 2 damage is dealt as there are now two '
#        'modified creatures. Total damage 3.\n'
#        'Bear #3 gets a +1/+1 counter, 3 damage is dealt. Total damage 6.\n'
#        'Bear #4 gets a counter, 4 damage is dealt. Total damage of 10.\n'
#        'Agrus get a a counter, 5 damage is dealt. Total damage of 15.',
#  'fr': 'Raiju gagne un marqueur +1/+1, aucune blessure n’est infligée car le '
#        'Raiju ne compte que les créatures modifiées autres que lui-même. '
#        'Blessures totales : 0.\n'
#        'Ours #1 gagne un marqueur  +1/+1, 1 blessure est infligée (vu qu’il y '
#        'a une seule créature modifiée autre que le Raiju). Blessures totales : '
#        '1.\n'
#        'Ours #2 gagne un marqueur +1/+1, 2 blessures sont infligées (vu qu’il '
#        'y a maintenant 2 créatures modifiées). Blessures totales : 3.\n'
#        'Ours #3 gagne un marqueur +1/+1, 3 blessures sont infligées (3 '
#        'créatures modifiées). Blessures totales : 6.\n'
#        'Ours #4 gagne un marqueur, 4 blessures sont infligées. Blessures '
#        'totales : 10.\n'
#        'Agrus gagne un marqueur, 5 blessures sont infligées. Blessures totales '
#        ': 15.'}
# {'en': "Now let's have the four Bears' triggers resolve first, then Raiju, "
#        'followed by Agrus.\n'
#        'Bear #1, 1 damage is dealt. Total damage 1.\n'
#        'Bear #2, 2 damage is dealt. Total damage 3.\n'
#        'Bear #3, 3 damage id dealt. Total damage 6.\n'
#        'Bear #4, 4 damage is dealt. Total damage is 10.\n'
#        'Raiju, 4 damage is dealt. Total damage is 14.\n'
#        'Agrus, 5 damage is dealt. Total damage is 19.',
#  'fr': 'Maintenant, laissons d’abord se résoudre les 4 capacités pour les '
#        'Oursons en premier, puis Raiju, et enfin Agrus.\n'
#        'Ours #1, 1 blessure est infligée. Blessures totales : 1.\n'
#        'Ours #2, 2 blessures sont infligées. Blessures totales : 3.\n'
#        'Ours #3, 3 blessures sont infligées. Blessures totales : 6.\n'
#        'Ours #4, 4 blessures sont infligées. Blessures totales : 10.\n'
#        'Raiju, 4 blessures sont infligées. Blessures totales : 14.\n'
#        'Agrus, 5 blessures sont infligées. Blessures totales : 19.'}
# {'en': 'The later the trigger targeting Raiju resolves, the more the total '
#        'damage.\n'
#        ' [/A]',
#  'fr': 'Plus le déclenchement ciblant le Raiju se résout tard, plus il y a de '
#        'blessures au total.\n'
#        ' [/A]'}
# {'en': '[hr]\n'
#        '[cleft=Grafdigger\'s Cage]Alex, the answer is "What is used to \n'
#        'keep the dead from escaping their graves?"[/cleft][Q] Does '
#        "[c]Grafdigger's Cage[/c] stop [c]Abhorrent Oculus[/c] from "
#        'manifest-dreading?[/Q]',
#  'fr': '[hr]\n'
#        "[cleft=Grafdigger's Cage]Alex, la réponse est “Qu’utilise-t-on\n"
#        'pour empêcher les morts de s’échapper de leur tombe ?”[/cleft][Q=Q :] '
#        "La [c=Grafdigger's Cage]Cage du fossoyeur de graf[/c] empêche-t-elle "
#        '[c=Abhorrent Oculus]Oculus abject[/c]  de manifester l’effroi ?[/Q]'}
# {'en': '[A] Well, in the important ways, yes. They still "manifest dread", but '
#        'some parts they can\'t complete. Manifest Dread is "Look at the top '
#        'two cards of your library. Manifest one of them, then put the cards '
#        'you looked at that were not manifested this way into your graveyard." '
#        "Since you can't put a creature from your library into play, both cards "
#        'looked at are put into the graveyard.[/A]',
#  'fr': '[A=R :] De la façon qui importe le plus, oui. On considère toujours '
#        'que le joueur a “manifesté l’effroi”, mais certaines parties de '
#        'l’action ne peuvent pas être complétées. Manifester l’effroi signifie '
#        '“Regardez les deux cartes du dessus de votre bibliothèque. Manifestez '
#        'l’une des deux, puis mettez toutes les cartes regardées qui n’ont pas '
#        'été manifestées de cette façon dans votre cimetière”. Vu que tu ne '
#        'peux pas mettre une créature de ta bibliothèque en jeu, les deux '
#        'cartes regardées sont mises dans le cimetière.[/A]'}
# {'en': '[hr]\n'
#        '[Q] Last turn my opponent stole my [c]Bear Cub[/c] by casting [c]Sower '
#        'of Temptation[/c]. This turn I used [c]Ovinize[/c] to make the Sower '
#        "lose all its abilities. I did this because I think I'll get my Bear "
#        'Cub back, since the Sower no longer has the "steal your creature" '
#        'ability. My opponent disagrees. Who is right?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Au dernier tour, mon adversaire a pris le contrôle de mon '
#        '[c=Bear Cub]Ourson[/c] en lançant [c=Sower of Temptation]Semeuse de '
#        'tentation[/c]. Je lance [c=Ovinize]Ovinisation[/c] en ciblant la '
#        'Semeuse pour qu’elle perde toutes ses capacités et que je puisse ainsi '
#        'récupérer mon Ourson. Mon adversaire me dit que ça ne marche pas. '
#        'Est-ce vrai ? [/Q]'}
# {'en': '[A] Your opponent is correct. Removing the enters ability (that '
#        'creates an effect with a duration) after the ability has resolved, '
#        "doesn't stop it from functioning.",
#  'fr': '[A=R :] Ton adversaire a raison : retirer sa capacité d’arrivée sur le '
#        'champ de bataille à la Semeuse après qu’elle s’est résolue ne '
#        'l’empêche pas de fonctionner.'}
# {'en': 'If it helps, an example that seems more intuitive would be the '
#        'following: My opponent used [c]Rootwater Matriarch[/c] to steel my '
#        '[c]Hill Giant[/c] enchanted with [c]Spirit Link[/c]. Killing the '
#        "Matriarch won't get the Hill Giant back, even though that removes "
#        'where the steal ability came from. The duration is based on whether or '
#        'not the Hill Giant is still enchanted.',
#  'fr': 'En espérant que cela aide, voici un exemple d’une situation '
#        'comparable, peut-être un peu plus intuitive : mon adversaire utilise '
#        '[c=Rootwater Matriarch]Matriarche de Souchemer[/c] pour prendre le '
#        'contrôle de mon [c=Hill Giant]Géant des collines[/c] enchanté par '
#        '[c=Spirit Link]Liaison psychique[/c]. Tuer la Matriarche ne fera pas '
#        'revenir le Géant sous mon contrôle même si cela détruit effectivement '
#        'la source de la capacité qui a permis à mon adversaire de me la voler, '
#        'car la durée de l’effet de changement de contrôle dépend du fait que '
#        'le Géant soit enchanté ou non. '}
# {'en': "So with the original question, removing Sower's abilities doesn't stop "
#        'the steal effect. You have to remove the Sower to gain the creature '
#        'back because that ends the duration of the effect.[/A]',
#  'fr': 'Pour conclure sur la question d’origine, si tu souhaites récupérer ton '
#        'Ourson, la seule solution dont tu disposes est de satisfaire la '
#        'condition décrite dans la capacité déclenchée de la Semeuse : la '
#        'retirer du champ de bataille.[/A]'}
# {'en': '[hr]\n'
#        '[Q] So continuing with the last question, what if instead of '
#        '[c]Ovinize[/c]ing the [c]Sower of Temptation[/c] I phased it out with '
#        '[c]Reality Ripple[/c]?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] En reprenant la situation précédente, et si, au lieu '
#        'd’utiliser [c=Ovinize]Ovinisation[/c] sur [c=Sower of '
#        'Temptation]Semeuse de tentation[/c], je la faisais passer hors-phase '
#        'avec [c=Reality Ripple]Ride de réalité[/c] ?[/Q]'}
# {'en': "[A] You would get your creature back. If a creature phases out, it's "
#        "treated as though it's no longer on the battlefield. The duration of "
#        'its effect has been met, so the effect ends and the stolen creature '
#        'returns to its last controller, usually its owner.[/A]',
#  'fr': '[A=R :] Tu regagnerais le contrôle de ta créature. En effet, si une '
#        'créature passe hors-phase, elle n’est plus sur le champ de bataille. '
#        'La condition de durée de l’effet de la Semeuse n’est plus satisfaite '
#        'et sa capacité ne s’applique donc plus.[/A]'}
# {'en': '[hr]\n'
#        "[Q] I block my opponent's attacking [c]Bear Cub[/c] with [c]Manor "
#        'Gargoyle[/c]. After combat ends, the opponent then casts '
#        '[c]Disfigure[/c] targeting my Gargoyle. They claim they just killed my '
#        'Gargoyle. Is this true?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Je bloque l’[c=Bear Cub]Ourson[/c] de mon adversaire avec '
#        '[c=Manor Gargoyle]Gargouille de manoir[/c]. Après la fin du combat, '
#        'elle lance [c=Disfigure]Défiguration[/c] en ciblant ma Gargouille. '
#        'Cette dernière est-elle détruite ?[/Q]'}
# {'en': '[A] It is not true, your Gargoyle lives through this. Many new players '
#        "make this same wrong assumption. Damage doesn't reduce toughness. You "
#        "have a 2/2 Gargoyle with 2 damage marked on it. Because it's "
#        'indestructible, the state based action that tries to destroy it for '
#        'having equal or more damage than it has toughness fails to do '
#        'anything. If they want to get your Gargoyle into the graveyard, they '
#        'need to give it enough [c=Dismember]-X/-X to make its toughness 0 or '
#        'less[/c], or force you to [c=Diabolic Edict]sacrifice it[/c].[/A]',
#  'fr': '[A=R :]Non, elle survit. Comme cela peut arriver à beaucoup de '
#        'personnes qui commencent à jouer à Magic, ton adversaire pense sans '
#        'doute que les blessures infligées aux créatures réduisent leur '
#        'endurance mais ce n’est pas le cas. Dans ta situation, tu finis avec '
#        'une Gargouille 2/2 qui a deux blessures sur elle, mais comme elle est '
#        'indestructible, l’action basée sur un état qui cherche à la détruire '
#        'car elle a un nombre de blessures égal à son endurance, ne fait rien. '
#        'En fin de compte, si ton adversaire veut se débarrasser de ta '
#        'Gargouille, elle devra trouver [c=Dismember]un moyen de réduire '
#        'davantage son endurance[/c], ou de te [c=Diabolic Edict]forcer à la '
#        'sacrifier[/c].[/A]'}
# {'en': '[hr]\n'
#        '[Q] If [c]Ragavan, Nimble Pilferer[/c] is my commander, can I cast him '
#        'for his dash cost from the command zone?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] [c=Ragavan, Nimble Pilferer]Ragavan, habile chapardeur[/c] est '
#        'mon commandant. Puis-je le lancer pour son coût de précipitation '
#        'depuis la zone de commandement ?[/Q]'}
# {'en': '[A] Yes, you can. Dash can be used from any zone, so long as you are '
#        'allowed to cast that card from that same zone normally. [/A]',
#  'fr': '[A=R :] Tout à fait. Le coût de précipitation d’une carte peut être '
#        'payé de n’importe quelle zone depuis laquelle tu es normalement '
#        'autorisée à lancer cette carte.[/A]'}
# {'en': '[hr]\n'
#        '[Q] Following up with the last question, do I have to pay commander '
#        'tax if I dash out my commander?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Pour approfondir la question précédente : dois-je payer la '
#        'taxe de commandant si je lance mon commandant avec la précipitation '
#        '?[/Q]'}
# {'en': '[A] Yes, you do. Suppose you cast Ragavan normally on turn one, then '
#        'later he died and returned to the command zone. When you go to dash '
#        'him he now costs [m]3[/m][m]R[/m] to dash. Then if he dies again and '
#        'returns to the command zone, the next time you go to cast him he costs '
#        'either [m]4[/m][m]R[/m] to cast normally or [m]5[/m][m]R[/m] to '
#        'dash.[/A]',
#  'fr': '[A=R :] Oui : la taxe de commandant fonctionnera normalement. Ainsi, '
#        'si tu souhaites lancer Ragavan une deuxième fois depuis la zone de '
#        'commandement pour son coût de précipitation, cela te coûtera '
#        '[m]3[/m][m]R[/m]. Une troisième fois dans les mêmes circonstances te '
#        'coûtera [m]5[/m][m]R[/m] et ainsi de suite.[/A]'}
# {'en': '[hr]\n'
#        '[Q] I have eight cards in my hand. I go to my cleanup step and discard '
#        '[c]Blazing Rootwalla[/c] to get down to maximum hand size. Can I cast '
#        "the Rootwalla even though I'm in my cleanup step?[/Q]",
#  'fr': '[hr]\n'
#        '[Q=Q :] J’ai 8 cartes en main. Je passe en étape de nettoyage et me '
#        'défausse d’un [c=Blazing Rootwalla]Agame brûlant[/c] pour atteindre ma '
#        'taille maximum de main. Puis-je alors lancer mon Agame, bien qu’on '
#        'soit dans l’étape de nettoyage ?[/Q]'}
# {'en': '[A] Yes, you can. During most cleanup steps, no players get priority. '
#        'However, if an ability triggers during the cleanup step, or a state '
#        'based action applies during a cleanup step, then the active player '
#        'gains priority and may cast spells and activate abilities. ',
#  'fr': '[A=R :] Parfaitement. Il est vrai que la plupart du temps, personne '
#        'n’acquiert la priorité pendant l’étape de nettoyage ; cependant, si '
#        'une capacité se déclenche pendant cette étape, ou qu’une action basée '
#        'sur un état est vérifiée à cet instant, alors le joueur ou la joueuse '
#        'dont c’est le tour acquiert la priorité et peut en profiter pour '
#        'lancer des sorts et/ou activer des capacités. \n'
#        'La folie étant, en partie, une capacité déclenchée, elle peut '
#        'rejoindre la pile même pendant l’étape de nettoyage et te permettre, à '
#        'sa résolution, de lancer éventuellement ta carte.\n'
#        'Si tu fais ainsi, ta carte rejoindra la pile et ton adversaire '
#        'acquerra la priorité comme à l’accoutumée. Une fois ton sort '
#        'complètement résolu et que toi et ton adversaire avez passé la '
#        'priorité alors que la pile est vide, une nouvelle étape de nettoyage '
#        'commencera. Ce n’est qu’une fois qu’une étape de nettoyage se '
#        'terminera sans que personne n’acquiert la priorité que l’on passera '
#        'immédiatement au début du tour suivant.[/A]'}
# {'en': 'This is when you can cast the Rootwalla, as discarding it to madness '
#        'puts a trigger on the stack.',
#  'fr': '[hr]\n'
#        '[Q=Q :] En résolvant [c=Burning Inquiry]Requête brûlante[/c], j’ai '
#        'défaussé [c=Basking Rootwalla]Agame pèlerin[/c] et deux '
#        '[c=Mountain]Montagne[/c]s. Mon adversaire contrôle [c=Rest in '
#        'Peace]Repose en paix[/c] et me dit que je ne peux pas lancer l’Agame '
#        'pour son coût de folie car il a été exilé par Repose en paix au moment '
#        'où je m’en suis défaussée. Est-ce vrai ?[/Q]'}
# {'en': 'A normal priority pass will begin from here and until all players pass '
#        'in succession with an empty stack, players may add new items to the '
#        'stack when they have priority. Once all players pass with an empty '
#        'stack, this cleanup step ends and a new one begins. If that new '
#        "cleanup ends normally, then the game will move on to the next player's "
#        'turn.[/A]',
#  'fr': '[A=R :] Non, ton adversaire fait une erreur et tu peux parfaitement '
#        'lancer ton Agame pour son coût de folie. En effet, il est important de '
#        'comprendre que si une carte avec la folie a été défaussée dans ta '
#        'situation, tu pourras toujours l’exiler avec la folie au lieu de la '
#        'mettre dans ton cimetière. Ce n’est qu’à partir de cet instant que, la '
#        'prochaine fois que toi ou ton adversaire devrez acquérir la priorité, '
#        'une capacité déclenchée autorisant à lancer la carte pour son coût de '
#        'folie va rejoindre la pile. Si la carte n’est pas lancée à la '
#        'résolution de cette capacité alors, à ce moment-là, elle sera exilée '
#        'par Repose en paix.[/A]'}
# {'en': '[hr]\n'
#        '[Q] While resolving [c]Burning Inquiry[/c] I discarded [c]Basking '
#        'Rootwalla[/c] and two [c]Mountain[/c]s. My opponent controls a [c]Rest '
#        "in Peace[/c]. My opponent claims I can't cast the Rootwalla for its "
#        'Madness cost as it got exiled by Rest in Peace when I discarded it. Is '
#        'this true?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Mon adversaire paie [m]3[/m][m]U[/m] pour atteindre le Niveau '
#        "2 de son [c=Stormchaser's Talent]Talent du chassorage[/c]. Avant qu'il "
#        'ne devienne Niveau 2, je le renvoie dans sa main avec '
#        "[c=Boomerang]Boomerang[/c]. Mon adversaire affirme qu'il peut quand "
#        'même renvoyer un éphémère ou un rituel dans sa main, mais moi, je dis '
#        'que non. Qui a raison ? [/Q]'}
# {'en': '[A] Your opponent is wrong. You can cast your Rootwalla for its '
#        "madness cost. The Rootwalla hasn't been exiled by Rest in Peace yet. "
#        "This is because madness doesn't quite work the way most people think "
#        'it does. If a card with madness gets discarded, it goes to exile '
#        "instead of being put into its owner's graveyard. Then the next time a "
#        'player would get priority, a trigger allowing its owner to cast it for '
#        'its madness cost is put on the stack. When this trigger resolves, the '
#        "owner may cast the card, but if they don't then the card is put into "
#        'their graveyard. ',
#  'fr': '[A=R :] Tu as raison, il ne le peut pas. Gagner un Niveau est une '
#        'capacité qui utilise la pile et à laquelle on peut répondre. La '
#        'capacité de Niveau 2 de Stormchaser est une capacité déclenchée qui se '
#        'déclenche lorsque la carte atteint le Niveau 2 et n’a lieu qu’après '
#        "qu’elle soit devenue Niveau 2. Si elle n'est plus sur le champ de "
#        'bataille lorsque sa capacité de Niveau 2 devrait se résoudre, alors il '
#        'n’y a ni capacité à déclencher ni permanent pour devenir Niveau 2. '
#        '[/A]'}
# {'en': 'To get back to the original question, Rest in Peace can only exile a '
#        'discarded Madness card after the owner has decided not to cast it for '
#        'madness and choses to let it go to the graveyard.\n'
#        '[/A]',
#  'fr': '[hr]\n'
#        '[cright=Bear Cub]Alex la réponse est "Quel est\n'
#        'l’autre nom de l’ourson Paddington ?"[/cright][Q=Q :] J\'ai enchanté '
#        "l'[c=Bear Cub]Ourson[/c] de mon adversaire avec [c=Sigil of "
#        "Sleep]Sceau du Sommeil[/c]. Si l'Ourson attaque et n'est pas bloqué, "
#        'qui choisit quelle créature que je contrôle est renvoyée dans la main '
#        'de son propriétaire ? [/Q]'}
# {'en': '[hr]\n'
#        '[Q] My opponent pays [m]3[/m][m]U[/m] to gain level 2 on their '
#        "[c]Stormchaser's Talent[/c]. Before it becomes level 2, I "
#        '[c]Boomerang[/c] it to their hand. The opponent says they still get to '
#        "return an instant or sorcery to their hand, I say they don't, who is "
#        'right?[/Q]',
#  'fr': "[A=R :] C'est toi qui choisis, car tu contrôles le Sceau du Sommeil. "
#        '[/A]'}
# {'en': '[A] You are correct, they do not. Gaining a level is an ability that '
#        "uses the stack and can be responded to. Stormchaser's level 2 ability "
#        'is a trigger that triggers upon it becoming level 2 and happens only '
#        "after it becomes level 2. If it's not on the battlefield when its "
#        'level 2 ability resolves, there is no ability to trigger (nor a '
#        'permanent to become level 2). [/A]',
#  'fr': '[hr]\n'
#        "[Q=Q :] J'attaque avec [c=Geist of Saint Traft]Geist de Saint "
#        'Traft[/c] alors que je contrôle [c=Anointed Procession]Procession '
#        'consécratrice[/c]. À la fin du combat, les deux jetons Ange sont-ils '
#        'exilés ou puis-je en garder un ? [/Q]'}
# {'en': '[hr]\n'
#        '[cright=Bear Cub|PO2]Alex, the answer is "What is another\n'
#        'name for Ursine Child?"[/cright][Q] I enchanted my opponent\'s [c]Bear '
#        'Cub[/c] with my [c]Sigil of Sleep[/c]. If the Bear Cub goes unblocked '
#        'attacking me, who chooses which creature I control gets returned to '
#        "its owner's hand?[/Q]",
#  'fr': '[A=R :] Les deux sont exilés. La capacité déclenchée de Saint Traft a '
#        'bien créé les deux jetons et les suit pour les exiler à la fin du '
#        'combat. Procession consécratrice ne crée pas de jetons, elle se '
#        "contente de modifier combien de jetons sont créés par d'autres cartes "
#        'et capacités. [/A]'}
# {'en': '[A] You get to choose as you control the Sigil of Sleep.[/A]',
#  'fr': '[hr]\n'
#        "[Q=Q :] J'attaque avec [c=Geist of Saint Traft]Geist de Saint "
#        'Traft[/c], mais avant l’étape des bloqueurs, je lance [c=Eyes in the '
#        'Skies]Yeux des cieux[/c] en choisissant de peupler le jeton Ange. À la '
#        'fin du combat, les deux jetons Ange sont-ils exilés, ou puis-je en '
#        'garder un ? [/Q]'}
# {'en': '[hr]\n'
#        '[Q] I attack with [c]Geist of Saint Traft[/c] while I control '
#        '[c]Anointed Procession[/c]. When combat ends, will both Angel tokens '
#        'get exiled or do I get to keep one?[/Q]',
#  'fr': '[A=R :] Tu peux garder celui créé par Yeux des cieux. Contrairement à '
#        'Procession consécratrice dans la question précédente, Yeux des cieux '
#        "crée directement un jeton, qui n'a donc aucun lien avec la capacité "
#        'qui a créé le premier jeton Ange. Cela signifie aussi que ce deuxième '
#        "Ange n'est pas attaquant, n'est pas engagé et ne sera pas exilé à la "
#        'fin du combat. [/A]'}
# {'en': "[A] Both still get exiled. Saint Traft's triggered ability still made "
#        'both tokens and tracks them to be exiled at the end of combat. '
#        "Procession doesn't make tokens, it just changes how many tokens other "
#        'cards and abilities make.[/A]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Je ne comprends pas contre quoi [c=Emrakul, the World '
#        'Anew]Emrakul, le Monde Renouvelé[/c] a la protection. Pouvez-vous '
#        'clarifier cela ? [/Q]'}
# {'en': '[hr]\n'
#        '[Q] I attack with [c]Geist of Saint Traft[/c], but before blocks, I '
#        'cast [c]Eyes in the Skies[/c] choosing to populate the Angel token. '
#        'When combat ends, will both Angel tokens get exiled or do I get to '
#        'keep one?[/Q]',
#  'fr': '[A=R :] Emrakul a la protection contre les sorts et les permanents '
#        'lancés "ce tour-ci". "Ce tour-ci" fait toujours référence au tour en '
#        "cours, même si plusieurs tours se sont écoulés depuis qu'Emrakul a été "
#        'lancée.'}
# {'en': '[A] You get to keep the one made by Eyes in the Skies. Unlike Anointed '
#        'Procession from the last question, Eyes in the Skies makes the token '
#        'and the token has no link to the ability that made the original Angel '
#        'token. This includes that the second Angel token is not attacking, is '
#        "not tapped, and it won't get exiled at the end of combat.[/A]",
#  'fr': 'Par exemple, si je lance [c=Visara the Dreadful]Visara la '
#        'redoutable[/c] et que je l’équipe de [c=Lightning Greaves]Jambières '
#        "d'éclair[/c] durant le même tour, elle ne pourra pas cibler et "
#        'détruire Emrakul ce tour-là. Cependant, si on passe au tour de mon '
#        "adversaire, Visara pourra alors tuer Emrakul, car ce n'est plus le "
#        "tour où Visara a été lancée. Si j'utilise [c=Goryo's "
#        'Vengeance]Vengeance selon Goryo[/c] pour réanimer Visara, alors elle '
#        "pourra tuer Emrakul immédiatement, car Visara n'a pas été lancée, elle "
#        'a juste été remise en jeu.'}
# {'en': '[hr]\n'
#        "[Q] I don't understand what [c]Emrakul, the World Anew[/c] has "
#        'protection from. Can you clarify this?[/Q]',
#  'fr': "La protection d'Emrakul fonctionne un peu comme une Protection contre "
#        'les éphémères et les rituels. La plupart des éphémères et des rituels '
#        'ne font leurs trucs que pendant le tour où ils sont lancés. Cependant, '
#        "si un éphémère ou un rituel n'a pas été lancé (par exemple une copie), "
#        "alors il pourra toujours cibler Emrakul. Par exemple, l'original de "
#        '[c=Temporal Fissure]Fissure temporelle[/c] ne pourra pas la cibler, '
#        "mais l'une de ses copies créées par le déluge le pourra."}
# {'en': '[A] Emrakul has protection from spells and separately protection from '
#        'permanents cast "this turn". This turn is whichever turn it currently '
#        "is, even if it's been many turns since Emrakul herself was cast. ",
#  'fr': "La protection d'Emrakul fonctionne aussi comme une Protection contre "
#        "les auras. Lorsqu'une aura est lancée, elle cible ce qu'elle va "
#        'enchanter. Donc Emrakul est protégée contre la plupart des auras. '
#        'Cependant, une aura déjà en jeu peut être déplacée plus tard pour '
#        'enchanter Emrakul. Par exemple, on peut déplacer le '
#        '[c=Pacifism]Pacifisme[/c] d’un jeton gobelin 1/1 vers Emrakul en '
#        'utilisant [c=Crown of the Ages]Couronne des temps anciens[/c]. [/A]'}
# {'en': 'So for example, if I cast [c]Visara the Dreadful[/c] and gave her some '
#        "[c]Lightning Greaves[/c] the same turn I cast her, she can't target "
#        "and destroy Emrakul that turn. However, if I pass to my opponent's "
#        "turn, Visara can now kill Emrakul as it's no longer the same turn "
#        "Visara was cast. If I used [c]Goryo's Vengeance[/c] to reanimate "
#        "Visara, then Visara could kill Emrakul that same turn as Visara wasn't "
#        'cast at all.',
#  'fr': '[hr]\n'
#        '[Q=Q :] Je lance [c=Season of Weaving]Saison du tissage[/c] en '
#        'choisissant le mode à deux pattes (pour copier mon [c=Arcanis the '
#        "Omnipotent]Arcanis l'Omnipotent[/c]) et le mode à trois pattes. "
#        'Devrai-je mettre un des Arcanis dans mon cimetière à cause de la règle '
#        'des légendes avant de renvoyer en main tous les permanents non-terrain '
#        'et non-jeton ? [/Q]'}
# {'en': "Emrakul's protection ability acts similar to having protection from "
#        'Auras. Auras when cast target what they will enchant, so Emrakul is '
#        'safe from most Auras. However, on later turns, an Aura could be moved '
#        'from its original target, to enchant Emrakul. For example, you could '
#        'move [c]Pacifism[/c] from a 1/1 Goblin token to Emrakul using [c]Crown '
#        'of the Ages[/c]. \n'
#        '[/A]',
#  'fr': '[A=R :] Non, et tu ne peux pas. La règle des légendes est une action '
#        "basée sur un état. Elle n'est jamais vérifiée au milieu de la "
#        "résolution d'un sort. Tu renverras l’Arcanis original dans ta main "
#        'avant que Saison du tissage ne se résolve complètement. La règle des '
#        "légendes n'entre pas en jeu dans cette situation. [/A]"}
# {'en': '[hr]\n'
#        '[Q] I cast [c]Season of Weaving[/c] choosing the two paws mode (to '
#        'copy my [c]Arcanis the Omnipotent[/c]) and the three paws mode. Will I '
#        'have to put one Arcanis into my graveyard due to the legend rule '
#        'before bouncing all nonland and nontoken permanents?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Je lance [c=Righteous Confluence]Confluence vertueuse[/c] en '
#        'choisissant le deuxième mode une fois (pour exiler la [c=Leyline of '
#        'Sanctity]Ligne ley de vertu[/c] de mon adversaire) et le troisième '
#        'mode deux fois (pour gagner un total de 10 points de vie). Mon '
#        'adversaire répond en renvoyant la Leyline dans sa main avec '
#        '[c]Boomerang[/c]. Vais-je gagner quand même 10 points de vie ? [/Q]'}
# {'en': '[A] You will not and you can not. The legend rule is a state based '
#        "action. It's never checked in the middle of resolving a spell. You "
#        'will put the original Arcanis into your hand before Season of Weaving '
#        "fully resolves. The legend rule doesn't come into play during this "
#        'situation.[/A]',
#  'fr': "[A=R :] Non. Confluence vertueuse n'avait qu'une seule cible (Ligne "
#        'ley de vertu), et cette cible a disparu. Si un sort perd toutes ses '
#        'cibles avant de se résoudre, il est contrecarré par les règles du jeu '
#        'et aucun de ses effets ne se produit. [/A]'}
# {'en': '[hr]\n'
#        '[Q] If I cast [c]Righteous Confluence[/c] choosing mode two once to '
#        "exile my opponent's [c]Leyline of Sanctity[/c] and mode three twice to "
#        'gain 10 total life, and the opponent responds by [c]Boomerang[/c]ing '
#        'the Leyline back to their hand, do I still gain 10 life?[/Q]',
#  'fr': '[hr]\n'
#        '[Q=Q :] Je viens de lancer [c=Cultivate]Culture[/c], mettant un '
#        '[c=Swamp]Marais[/c] sur le champ de bataille et une '
#        "[c=Forest]Forêt[/c] dans ma main. Je n'ai pas encore joué de terrain "
#        'depuis ma main ce tour-ci. Puis-je toujours jouer la Forêt comme '
#        'terrain de mon tour, ou bien le Marais a-t-il déjà compté pour mon '
#        'terrain du tour ? [/Q]'}
# {'en': '[A] You do not. Righteous Confluence had only one target, Leyline of '
#        'Sanctity, and that target has disappeared. If a spell loses all of its '
#        'targets by the time it goes to resolve, it fizzles and none of its '
#        'effects happen. [/A]',
#  'fr': '[A=R :] Tu peux quand même jouer la Forêt. Mettre un terrain sur le '
#        'champ de bataille grâce à un sort ou une capacité ne compte pas comme '
#        'ton terrain joué pour le tour. [/A]'}
# {'en': '[hr]\n'
#        '[Q] I just cast [c]Cultivate[/c] putting a [c]Swamp[/c] onto the '
#        "battlefield and a [c]Forest[/c] into my hand. I haven't played a land "
#        'from my hand yet this turn. Can I still play the Forest as my land '
#        'drop for the turn, or did the Swamp use up my land drop for the '
#        'turn?[/Q]',
#  'fr': '[hr]'}
# {'en': '[A] You may still play the Forest. Putting a land onto the battlefield '
#        "with a spell or ability doesn't use up your one land drop per "
#        'turn.[/A]',
#  'fr': 'Chaque question de mon dernier article contenait une référence cachée '
#        'à un cochon issu de la pop culture. Avec 10 questions différentes, il '
#        'y avait donc 10 cochons différents. Le spoiler ci-dessous contient la '
#        'clé de ces références.'}
# {'en': '[hr]',
#  'fr': '[spoiler]\n'
#        'Question 1) Charlotte’s Web – Wilbur le cochon & Charlotte l’araignée\n'
#        'Question 2) Les Muppets de Jim Henson – Miss Piggy, Kermit la '
#        'grenouille, Fozzie l’ours\n'
#        'Question 3) Les Trois Petits Cochons et le Grand Méchant Loup\n'
#        'Question 4) Angry Birds (le jeu vidéo : oiseaux contre cochons)\n'
#        'Question 5) Looney Tunes – Bugs Bunny, Porky Pig et Daffy Duck\n'
#        'Question 6) Babe (film de 1995) – Babe le cochon, les moutons qu’il '
#        'garde, et le fermier Arthur Hoggett\n'
#        'Question 7) The Legend of Zelda – Link le guerrier elfe, Zelda la '
#        'noble elfe, et Ganon (forme porcine de Ganondorf)\n'
#        'Question 8) Le Roi Lion – Timon le suricate, Pumbaa le phacochère, et '
#        'quelques hyènes à combattre\n'
#        'Question 9) Toy Story – Woody le cow-boy, Buzz l’astronaute, Rex le '
#        'T-Rex & Bayonne (Hamm) la tirelire-cochon\n'
#        'Question 10) Winnie l’Ourson – Winnie l’ourson, Tigrou le tigre, et '
#        'Porcinet le cochon\n'
#        '[/spoiler]'}
# {'en': 'Each Question in my last article had a hidden reference to a different '
#        'pop-culture pig. With ten different questions there were ten different '
#        'pigs. The spoiler below has the answer key to those references.\n'
#        '[spoiler]\n'
#        "Question 1) Charlotte's Web - Wilbur the Pig and Charlotte the Spider\n"
#        "Question 2) Jim Henson's Muppets - Miss Piggy, Kermit the Frog, and "
#        'Fozzie Bear.\n'
#        'Question 3) The Three Little Pigs and the Big Bad Wolf\n'
#        'Question 4) Angry Birds Video Game (Birds vs Pigs)\n'
#        'Question 5) Looney Tunes - Bugs Bunny, Porky Pig, and Daffy Duck\n'
#        'Question 6) Babe the 1995 Movie - Babe the Pig, Sheep for Babe to '
#        'herd, and Farmer Arthur Hoggett\n'
#        'Question 7) Legend of Zelda - Link an Elf Warrior, Zelda an Elf Noble, '
#        'and Ganon (pig form of Ganondorf)\n'
#        'Question 8) The Lion King - Timon the Meerkat, Pumbaa the Warthog, and '
#        'some Hyenas for them to fight.\n'
#        'Question 9) Toy Story - Woody the Cowboy, Buzz the Spaceman, Rex the '
#        'T-Rex, and Hamm the Piggy Bank.\n'
#        'Question 10) Winnie the Pooh - Pooh the Bear, Tigger the Tiger, and '
#        'Piglet the Pig.[/spoiler]',
#  'fr': '\n- Justin Hovdenes AKA Hovey\nLevel 2 Magic Judge\nRapid City, SD'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-cde73155331e> in <cell line: 0>()
#       6     paragraphs_fr = content_article['fr']['article_text'].split('\n\n')
#       7     for i, paragraph_en in enumerate(paragraphs_en):
# ----> 8         paragraph_fr = paragraphs_fr[i]
#       9         pair_of_paragraphs = {
#      10             'en': paragraph_en,
#
# IndexError: list index out of range
